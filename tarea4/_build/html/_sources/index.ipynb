# %% [markdown]
# <img src="https://i.imgur.com/6U6q5jQ.png"/>
#
# <a target="_blank" href="https://colab.research.google.com/github/SocialAnalytics-StrategicIntelligence/introTextData/blob/main/index.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>
#
# # Text as Data
#
# Let me get use some old tweets from Donald Trump:

# %%
import pandas as pd
import os

trumpFile = r"/workspaces/Tarea-4_ASIES/tarea4/trumps.csv"
allTweets = pd.read_csv(trumpFile)
allTweets
# Out:
#               created_at                                               text  \
# 0    2020-08-13 23:26:50  .@DonYoungAK really produces for Alaska. He is...
# 1    2020-08-13 23:23:26  ...She will be a great Senator, and has my Com...
# 2    2020-08-13 23:23:25  .@CynthiaMLummis is a friend of mine and a gre...
# 3    2020-08-13 21:27:36  LIVE: President @realDonaldTrump holds a news ...
# 4    2020-08-13 18:59:29                            https://t.co/ymvtIzQqoR
# ..                   ...                                                ...
# 194  2020-08-04 23:00:40  Reopening Our Schools: @realDonaldTrump says s...
# 195  2020-08-04 23:00:38  Reopening America: President @realDonaldTrump ...
# 196  2020-08-04 23:00:15  We have far and away the most robust testing c...
# 197  2020-08-04 22:48:35  "As we shelter those at high risk, we are also...
# 198  2020-08-04 22:46:07  "Thanks to our major advances in treatment, we...
#
#      is_retweet  favorite_count  retweet_count  Hour  Day        Date
# 0         False           18714           5305    23    5  2020-08-13
# 1         False           14946           3490    23    5  2020-08-13
# 2         False           32586           8584    23    5  2020-08-13
# 3          True               0           5917    21    5  2020-08-13
# 4         False           20131           5303    18    5  2020-08-13
# ..          ...             ...            ...   ...  ...         ...
# 194        True               0           7205    23    3  2020-08-04
# 195        True               0           7603    23    3  2020-08-04
# 196        True               0           5717    23    3  2020-08-04
# 197        True               0           5414    22    3  2020-08-04
# 198        True               0           5626    22    3  2020-08-04
#
# [199 rows x 8 columns]

# %% [markdown]
# Let me subset the dataframe, just to keep the non retweets:

# %%
DTtweets=allTweets[~allTweets.is_retweet]
DTtweets.reset_index(drop=True,inplace=True)

# %% [markdown]
# ## Tokenization
#
# A key step for text analytics is tokenization: where the text is broken into smaller pieces.
#
# We can use:
#
# - NLTK library:

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /home/codespace/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk
from nltk.tokenize import word_tokenize

DTtweets['text'].apply(nltk.word_tokenize)
# Out:
# 0      [., @, DonYoungAK, really, produces, for, Alas...
# 1      [..., She, will, be, a, great, Senator, ,, and...
# 2      [., @, CynthiaMLummis, is, a, friend, of, mine...
# 3                          [https, :, //t.co/ymvtIzQqoR]
# 4                          [https, :, //t.co/BY6PrMRmqJ]
#                              ...
# 116    [For, those, that, thought, I, wasn, ’, t, int...
# 117    [A, great, race, run, by, Roger, against, a, v...
# 118    [There, is, TREMENDOUS, Lawlessness, in, Ameri...
# 119                        [https, :, //t.co/JDS4zUXXJG]
# 120    [Great, meeting, today, with, the, CoronaVirus...
# Name: text, Length: 121, dtype: object

# %% [markdown]
# * Pandas string functions:

# %%
DTtweets.text.str.split('\s')
# Out:
# 0      [.@DonYoungAK, really, produces, for, Alaska.,...
# 1      [...She, will, be, a, great, Senator,, and, ha...
# 2      [.@CynthiaMLummis, is, a, friend, of, mine, an...
# 3                              [https://t.co/ymvtIzQqoR]
# 4                              [https://t.co/BY6PrMRmqJ]
#                              ...
# 116    [For, those, that, thought, I, wasn’t, into, t...
# 117    [A, great, race, run, by, Roger, against, a, v...
# 118    [There, is, TREMENDOUS, Lawlessness, in, Ameri...
# 119                            [https://t.co/JDS4zUXXJG]
# 120    [Great, meeting, today, with, the, CoronaVirus...
# Name: text, Length: 121, dtype: object

# %% [markdown]
# The basic Pandas seems more convenient. Then, we simply create a series where each cell is a token (word):

# %%
import numpy as np

wordInSeries=pd.Series(np.concatenate(DTtweets.text.str.split('\s')))
wordInSeries
# Out:
# 0                   .@DonYoungAK
# 1                         really
# 2                       produces
# 3                            for
# 4                        Alaska.
#                   ...
# 2915                        Stay
# 2916                    informed
# 2917                         at:
# 2918    https://t.co/p9j7kZsD7b.
# 2919     https://t.co/nnnUHCzOLV
# Length: 2920, dtype: object

# %% [markdown]
# ### Cleaning the tokens

# %%
wordInSeries=wordInSeries[~wordInSeries.str.startswith('http')].reset_index(drop=True)
wordInSeries
# Out:
# 0       .@DonYoungAK
# 1             really
# 2           produces
# 3                for
# 4            Alaska.
#             ...
# 2861            Oval
# 2862         Office.
# 2863            Stay
# 2864        informed
# 2865             at:
# Length: 2866, dtype: object

# %%
wordInSeries=wordInSeries.str.replace('[^\x01-\x7F]','')
wordInSeries=wordInSeries.str.replace('&amp;','and')
wordInSeries=wordInSeries.str.replace('&lt;|&gt;','')
wordInSeries
# Out:
# 0       .@DonYoungAK
# 1             really
# 2           produces
# 3                for
# 4            Alaska.
#             ...
# 2861            Oval
# 2862         Office.
# 2863            Stay
# 2864        informed
# 2865             at:
# Length: 2866, dtype: object

# %%
# punctuation
import string
PUNCs=string.punctuation # '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'
wordInSeries=wordInSeries.str.replace('['+PUNCs+']', '',regex=True)

# all to lower case
wordInSeries=wordInSeries.str.lower()
wordInSeries
# Out:
# 0       donyoungak
# 1           really
# 2         produces
# 3              for
# 4           alaska
#            ...
# 2861          oval
# 2862        office
# 2863          stay
# 2864      informed
# 2865            at
# Length: 2866, dtype: object

# %% [markdown]
# ### Relevant tokens
#
# It is difficult to know what tokens should not be analyzed. Let's count the current ones:

# %%
wordInSeries.value_counts()
# Out:
# the          136
# and           91
# to            79
# in            67
# of            58
#             ...
# playing        1
# game           1
# sources        1
# “sources”      1
# pure           1
# Name: count, Length: 1027, dtype: int64

# %% [markdown]
# We could agree that simple sintactic components like determinatives, conjunctions, or prepositions do carry much information. Most of these elements are known as **STOPWORDS**.  We use them to reduce our tokens:

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/codespace/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.corpus import stopwords
STOPS = stopwords.words('english')


wordInSeries=wordInSeries[~wordInSeries.isin(STOPS)].reset_index(drop=True)
wordInSeries
# Out:
# 0       donyoungak
# 1           really
# 2         produces
# 3           alaska
# 4       incredible
#            ...
# 1681         force
# 1682          oval
# 1683        office
# 1684          stay
# 1685      informed
# Length: 1686, dtype: object

# %% [markdown]
# ## Word Frequency
#
# We could keep prepare a frequency with the words remaining:

# %%
wordInSeries.value_counts()
# Out:
# great       27
# bus         20
# people      18
# usdot       17
# big         15
#             ..
# men          1
# women        1
# fighting     1
# plague       1
# stock        1
# Name: count, Length: 927, dtype: int64

# %% [markdown]
# Let's see the distribution of counts:

# %%
wordInSeries.value_counts().plot(logy=True, kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
FrequencyTrumpTokens=wordInSeries.value_counts()[wordInSeries.value_counts()>5]
FrequencyTrumpTokens
# Out:
# great              27
# bus                20
# people             18
# usdot              17
# big                15
# infrastructure     14
# service            14
# support            13
# complete           12
# news               12
# state              12
# endorsement        11
# federal            11
# joe                10
# total              10
# funds              10
# congratulations     9
#                     8
# thank               8
# biden               8
# improvements        8
# second              7
# first               7
# president           7
# happy               7
# good                7
# states              7
# new                 7
# fake                7
# vets                6
# one                 6
# strong              6
# congressman         6
# would               6
# amendment           6
# win                 6
# way                 6
# funding             6
# Name: count, dtype: int64

# %% [markdown]
# We have series, let me have a dict:

# %%
FrequencyTrumpTokens.to_dict()
# Out:
# {'great': 27,
#  'bus': 20,
#  'people': 18,
#  'usdot': 17,
#  'big': 15,
#  'infrastructure': 14,
#  'service': 14,
#  'support': 13,
#  'complete': 12,
#  'news': 12,
#  'state': 12,
#  'endorsement': 11,
#  'federal': 11,
#  'joe': 10,
#  'total': 10,
#  'funds': 10,
#  'congratulations': 9,
#  '': 8,
#  'thank': 8,
#  'biden': 8,
#  'improvements': 8,
#  'second': 7,
#  'first': 7,
#  'president': 7,
#  'happy': 7,
#  'good': 7,
#  'states': 7,
#  'new': 7,
#  'fake': 7,
#  'vets': 6,
#  'one': 6,
#  'strong': 6,
#  'congressman': 6,
#  'would': 6,
#  'amendment': 6,
#  'win': 6,
#  'way': 6,
#  'funding': 6}

# %% [markdown]
# ### Plotting

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

import matplotlib.pyplot as plt
from wordcloud import WordCloud

wc1 = WordCloud(background_color='white')
wc1.generate_from_frequencies(frequencies=FrequencyTrumpTokens.to_dict())
plt.figure()
plt.imshow(wc1, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
wc2 = WordCloud(background_color='white',
                colormap="Reds")
wc2.generate_from_frequencies(frequencies=FrequencyTrumpTokens.to_dict())
plt.figure()
plt.imshow(wc2, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# ## Bigrams
#
# We can do the same with pairs of words (bigrams). Let me open a text file:

# %%
f = open("/workspaces/Tarea-4_ASIES/tarea4/sometext.txt", "r")


textFile = r"/workspaces/Tarea-4_ASIES/tarea4/sometext.txt"
allText=pd.read_table(textFile,header=None)

#see the text
allText
# Out:
#                                                     0
# 0   Seattle is under siege. Over the past five yea...
# 1   At the same time, according to the Puget Sound...
# 2   Over the past year, I’ve spent time at city co...
# 3   Seattle has long been known as one of America’...
# 4   On the surface, this argument has its own inte...
# 5   Even in a pricey city like Seattle, most worki...
# 6   Using homelessness as a symbol of “capitalism’...
# 7   What the socialists won’t, or can’t, see is th...
# 8   The stubborn reality is that Seattle is expens...
# 9   “What the socialists won’t, or can’t, see is t...
# 10  The compassion brigades are the moral crusader...
# 11  O’Brien and his supporters have constructed an...
# 12  The second key myth is that the homeless are “...
# 13  The third myth: O’Brien and his allies argue t...
# 14  The homeless mythology is not merely anti-fact...
# 15  Yet the compassion advocates man the barricade...
# 16  With more than $1 billion spent on homelessnes...
# 17  It wasn’t always this way. When I spoke with E...
# 18  The deeper problem is that social policies hav...
# 19  Their latest scheme in Seattle is to build cit...
# 20  Even worse, SHARE, which runs the Licton Sprin...
# 21  Ultimately, the homeless-industrial complex is...
# 22  Despite repeated warnings from Seattle’s own h...
# 23  What I call the addiction evangelists make up ...
# 24  Their leading proponent is Shilo Murphy, a her...
# 25  Incredibly, Murphy has become a player in Seat...
# 26  Harm reduction has had notable success in coun...
# 27  “What I call the addiction evangelists include...
# 28  The question almost never asked about harm red...
# 29  In Seattle, the influx has already begun. Acco...
# 30  Yet the addiction evangelists are making gains...
# 31  In 2005, the top experts in Seattle and King C...
# 32  Unfortunately, Adrienne Quinn, the new boss of...
# 33  The problem is not Seattle’s alone: the United...
# 34  Homelessness is a condition of disengagement f...
# 35  The best way to prevent homelessness isn’t to ...
# 36  In the near term, cities like Seattle, Portlan...
# 37  Representing homelessness as a symbol of capit...
# 38  Representing homelessness as a symbol of capit...
# 39  Encouragingly, citizens and local governments ...
# 40  In Seattle, Mayor Jenny Durkan, who made her r...
# 41  In San Diego, for instance, city officials and...
# 42  In Houston, local leaders have reduced homeles...
# 43  Seattle and King County currently spend nearly...
# 44  Seattle must break up its homeless-industrial ...
# 45  Ultimately, the success or failure of local go...

# %% [markdown]
# Let's normalize the text to lowercase:

# %%
type(allText)
# Out:
# pandas.core.frame.DataFrame

# %%
allText[0]=allText[0].str.lower()
allText[0]=allText[0].str.replace('['+PUNCs+']', '',regex=True)

# %% [markdown]
# Let me create the bigrams:

# %%
from nltk import bigrams

theBigrams=[bigrams(eachTW.split()) for eachTW in allText[0]]


# list of all bigrams
from itertools import chain

pairWords = list(chain(*theBigrams))

pairWords
# Out:
# [('seattle', 'is'),
#  ('is', 'under'),
#  ('under', 'siege'),
#  ('siege', 'over'),
#  ('over', 'the'),
#  ('the', 'past'),
#  ('past', 'five'),
#  ('five', 'years'),
#  ('years', 'the'),
#  ('the', 'emerald'),
#  ('emerald', 'city'),
#  ('city', 'has'),
#  ('has', 'seen'),
#  ('seen', 'an'),
#  ('an', 'explosion'),
#  ('explosion', 'of'),
#  ('of', 'homelessness'),
#  ('homelessness', 'crime'),
#  ('crime', 'and'),
#  ('and', 'addiction'),
#  ('addiction', 'in'),
#  ('in', 'its'),
#  ('its', '2017'),
#  ('2017', 'pointintime'),
#  ('pointintime', 'count'),
#  ('count', 'of'),
#  ('of', 'the'),
#  ('the', 'homeless'),
#  ('homeless', 'king'),
#  ('king', 'county'),
#  ('county', 'socialservices'),
#  ('socialservices', 'agency'),
#  ('agency', 'all'),
#  ('all', 'home'),
#  ('home', 'found'),
#  ('found', '11643'),
#  ('11643', 'people'),
#  ('people', 'sleeping'),
#  ('sleeping', 'in'),
#  ('in', 'tents'),
#  ('tents', 'cars'),
#  ('cars', 'and'),
#  ('and', 'emergency'),
#  ('emergency', 'shelters'),
#  ('shelters', 'property'),
#  ('property', 'crime'),
#  ('crime', 'has'),
#  ('has', 'risen'),
#  ('risen', 'to'),
#  ('to', 'a'),
#  ('a', 'rate'),
#  ('rate', 'two'),
#  ('two', 'and'),
#  ('and', 'a'),
#  ('a', 'half'),
#  ('half', 'times'),
#  ('times', 'higher'),
#  ('higher', 'than'),
#  ('than', 'los'),
#  ('los', 'angeles’s'),
#  ('angeles’s', 'and'),
#  ('and', 'four'),
#  ('four', 'times'),
#  ('times', 'higher'),
#  ('higher', 'than'),
#  ('than', 'new'),
#  ('new', 'york'),
#  ('york', 'city’s'),
#  ('city’s', 'cleanup'),
#  ('cleanup', 'crews'),
#  ('crews', 'pick'),
#  ('pick', 'up'),
#  ('up', 'tens'),
#  ('tens', 'of'),
#  ('of', 'thousands'),
#  ('thousands', 'of'),
#  ('of', 'dirty'),
#  ('dirty', 'needles'),
#  ('needles', 'from'),
#  ('from', 'city'),
#  ('city', 'streets'),
#  ('streets', 'and'),
#  ('and', 'parks'),
#  ('parks', 'every'),
#  ('every', 'year'),
#  ('at', 'the'),
#  ('the', 'same'),
#  ('same', 'time'),
#  ('time', 'according'),
#  ('according', 'to'),
#  ('to', 'the'),
#  ('the', 'puget'),
#  ('puget', 'sound'),
#  ('sound', 'business'),
#  ('business', 'journal'),
#  ('journal', 'the'),
#  ('the', 'seattle'),
#  ('seattle', 'metro'),
#  ('metro', 'area'),
#  ('area', 'spends'),
#  ('spends', 'more'),
#  ('more', 'than'),
#  ('than', '1'),
#  ('1', 'billion'),
#  ('billion', 'fighting'),
#  ('fighting', 'homelessness'),
#  ('homelessness', 'every'),
#  ('every', 'year'),
#  ('year', 'that’s'),
#  ('that’s', 'nearly'),
#  ('nearly', '100000'),
#  ('100000', 'for'),
#  ('for', 'every'),
#  ('every', 'homeless'),
#  ('homeless', 'man'),
#  ('man', 'woman'),
#  ('woman', 'and'),
#  ('and', 'child'),
#  ('child', 'in'),
#  ('in', 'king'),
#  ('king', 'county'),
#  ('county', 'yet'),
#  ('yet', 'the'),
#  ('the', 'crisis'),
#  ('crisis', 'seems'),
#  ('seems', 'only'),
#  ('only', 'to'),
#  ('to', 'have'),
#  ('have', 'deepened'),
#  ('deepened', 'with'),
#  ('with', 'more'),
#  ('more', 'addiction'),
#  ('addiction', 'more'),
#  ('more', 'crime'),
#  ('crime', 'and'),
#  ('and', 'more'),
#  ('more', 'tent'),
#  ('tent', 'encampments'),
#  ('encampments', 'in'),
#  ('in', 'residential'),
#  ('residential', 'neighborhoods'),
#  ('neighborhoods', 'by'),
#  ('by', 'any'),
#  ('any', 'measure'),
#  ('measure', 'the'),
#  ('the', 'city’s'),
#  ('city’s', 'efforts'),
#  ('efforts', 'are'),
#  ('are', 'not'),
#  ('not', 'working'),
#  ('over', 'the'),
#  ('the', 'past'),
#  ('past', 'year'),
#  ('year', 'i’ve'),
#  ('i’ve', 'spent'),
#  ('spent', 'time'),
#  ('time', 'at'),
#  ('at', 'city'),
#  ('city', 'council'),
#  ('council', 'meetings'),
#  ('meetings', 'political'),
#  ('political', 'rallies'),
#  ('rallies', 'homeless'),
#  ('homeless', 'encampments'),
#  ('encampments', 'and'),
#  ('and', 'rehabilitation'),
#  ('rehabilitation', 'facilities'),
#  ('facilities', 'trying'),
#  ('trying', 'to'),
#  ('to', 'understand'),
#  ('understand', 'how'),
#  ('how', 'the'),
#  ('the', 'government'),
#  ('government', 'can'),
#  ('can', 'spend'),
#  ('spend', 'so'),
#  ('so', 'much'),
#  ('much', 'money'),
#  ('money', 'with'),
#  ('with', 'so'),
#  ('so', 'little'),
#  ('little', 'effect'),
#  ('effect', 'while'),
#  ('while', 'most'),
#  ('most', 'of'),
#  ('of', 'the'),
#  ('the', 'debate'),
#  ('debate', 'has'),
#  ('has', 'focused'),
#  ('focused', 'on'),
#  ('on', 'tactical'),
#  ('tactical', 'policy'),
#  ('policy', 'questions'),
#  ('questions', 'build'),
#  ('build', 'more'),
#  ('more', 'shelters'),
#  ('shelters', 'open'),
#  ('open', 'supervised'),
#  ('supervised', 'injection'),
#  ('injection', 'sites'),
#  ('sites', 'the'),
#  ('the', 'real'),
#  ('real', 'battle'),
#  ('battle', 'isn’t'),
#  ('isn’t', 'being'),
#  ('being', 'waged'),
#  ('waged', 'in'),
#  ('in', 'the'),
#  ('the', 'tents'),
#  ('tents', 'under'),
#  ('under', 'the'),
#  ('the', 'bridges'),
#  ('bridges', 'or'),
#  ('or', 'in'),
#  ('in', 'the'),
#  ('the', 'corridors'),
#  ('corridors', 'of'),
#  ('of', 'city'),
#  ('city', 'hall'),
#  ('hall', 'but'),
#  ('but', 'in'),
#  ('in', 'the'),
#  ('the', 'realm'),
#  ('realm', 'of'),
#  ('of', 'ideas'),
#  ('ideas', 'where'),
#  ('where', 'for'),
#  ('for', 'now'),
#  ('now', 'four'),
#  ('four', 'ideological'),
#  ('ideological', 'power'),
#  ('power', 'centers'),
#  ('centers', 'frame'),
#  ('frame', 'seattle’s'),
#  ('seattle’s', 'homelessness'),
#  ('homelessness', 'debate'),
#  ('debate', 'i’ll'),
#  ('i’ll', 'identify'),
#  ('identify', 'them'),
#  ('them', 'as'),
#  ('as', 'the'),
#  ('the', 'socialists'),
#  ('socialists', 'the'),
#  ('the', 'compassion'),
#  ('compassion', 'brigades'),
#  ('brigades', 'the'),
#  ('the', 'homelessindustrial'),
#  ('homelessindustrial', 'complex'),
#  ('complex', 'and'),
#  ('and', 'the'),
#  ('the', 'addiction'),
#  ('addiction', 'evangelists'),
#  ('evangelists', 'together'),
#  ('together', 'they'),
#  ('they', 'have'),
#  ('have', 'dominated'),
#  ('dominated', 'the'),
#  ('the', 'local'),
#  ('local', 'policy'),
#  ('policy', 'discussion'),
#  ('discussion', 'diverted'),
#  ('diverted', 'hundreds'),
#  ('hundreds', 'of'),
#  ('of', 'millions'),
#  ('millions', 'of'),
#  ('of', 'dollars'),
#  ('dollars', 'toward'),
#  ('toward', 'favored'),
#  ('favored', 'projects'),
#  ('projects', 'and'),
#  ('and', 'converted'),
#  ('converted', 'many'),
#  ('many', 'wellintentioned'),
#  ('wellintentioned', 'voters'),
#  ('voters', 'to'),
#  ('to', 'the'),
#  ('the', 'politics'),
#  ('politics', 'of'),
#  ('of', 'unlimited'),
#  ('unlimited', 'compassion'),
#  ('compassion', 'if'),
#  ('if', 'we'),
#  ('we', 'want'),
#  ('want', 'to'),
#  ('to', 'break'),
#  ('break', 'through'),
#  ('through', 'the'),
#  ('the', 'failed'),
#  ('failed', 'status'),
#  ('status', 'quo'),
#  ('quo', 'on'),
#  ('on', 'homelessness'),
#  ('homelessness', 'in'),
#  ('in', 'places'),
#  ('places', 'like'),
#  ('like', 'seattle—and'),
#  ('seattle—and', 'in'),
#  ('in', 'portland'),
#  ('portland', 'san'),
#  ('san', 'francisco'),
#  ('francisco', 'and'),
#  ('and', 'los'),
#  ('los', 'angeles'),
#  ('angeles', 'too—we'),
#  ('too—we', 'must'),
#  ('must', 'first'),
#  ('first', 'map'),
#  ('map', 'the'),
#  ('the', 'ideological'),
#  ('ideological', 'battlefield'),
#  ('battlefield', 'identify'),
#  ('identify', 'the'),
#  ('the', 'flaws'),
#  ('flaws', 'in'),
#  ('in', 'our'),
#  ('our', 'current'),
#  ('current', 'policies'),
#  ('policies', 'and'),
#  ('and', 'rethink'),
#  ('rethink', 'our'),
#  ('our', 'assumptions'),
#  ('seattle', 'has'),
#  ('has', 'long'),
#  ('long', 'been'),
#  ('been', 'known'),
#  ('known', 'as'),
#  ('as', 'one'),
#  ('one', 'of'),
#  ('of', 'america’s'),
#  ('america’s', 'most'),
#  ('most', 'liberal'),
#  ('liberal', 'locales'),
#  ('locales', 'but'),
#  ('but', 'in'),
#  ('in', 'recent'),
#  ('recent', 'years'),
#  ('years', 'the'),
#  ('the', 'city'),
#  ('city', 'has'),
#  ('has', 'marched'),
#  ('marched', 'even'),
#  ('even', 'further'),
#  ('further', 'left'),
#  ('left', 'as'),
#  ('as', 'socialists'),
#  ('socialists', 'once'),
#  ('once', 'relegated'),
#  ('relegated', 'to'),
#  ('to', 'the'),
#  ('the', 'margins'),
#  ('margins', 'have'),
#  ('have', 'declared'),
#  ('declared', 'war'),
#  ('war', 'on'),
#  ('on', 'the'),
#  ('the', 'democratic'),
#  ('democratic', 'establishment'),
#  ('establishment', 'socialist'),
#  ('socialist', 'alternative'),
#  ('alternative', 'city'),
#  ('city', 'councilwoman'),
#  ('councilwoman', 'kshama'),
#  ('kshama', 'sawant'),
#  ('sawant', 'claims'),
#  ('claims', 'that'),
#  ('that', 'the'),
#  ('the', 'city’s'),
#  ('city’s', 'homelessness'),
#  ('homelessness', 'crisis'),
#  ('crisis', 'is'),
#  ('is', 'the'),
#  ('the', 'inevitable'),
#  ('inevitable', 'result'),
#  ('result', 'of'),
#  ('of', 'the'),
#  ('the', 'amazon'),
#  ('amazon', 'boom'),
#  ('boom', 'greedy'),
#  ('greedy', 'landlords'),
#  ('landlords', 'and'),
#  ('and', 'rapidly'),
#  ('rapidly', 'increasing'),
#  ('increasing', 'rents'),
#  ('rents', 'as'),
#  ('as', 'she'),
#  ('she', 'told'),
#  ('told', 'street'),
#  ('street', 'roots'),
#  ('roots', 'news'),
#  ('news', '“the'),
#  ('“the', 'explosion'),
#  ('explosion', 'of'),
#  ('of', 'the'),
#  ('the', 'homelessness'),
#  ('homelessness', 'crisis'),
#  ('crisis', 'is'),
#  ('is', 'a'),
#  ('a', 'symptom'),
#  ('symptom', 'of'),
#  ('of', 'how'),
#  ('how', 'deeply'),
#  ('deeply', 'dysfunctional'),
#  ('dysfunctional', 'capitalism'),
#  ('capitalism', 'is'),
#  ('is', 'and'),
#  ('and', 'also'),
#  ('also', 'how'),
#  ('how', 'much'),
#  ('much', 'worse'),
#  ('worse', 'living'),
#  ('living', 'standards'),
#  ('standards', 'have'),
#  ('have', 'gotten'),
#  ('gotten', 'with'),
#  ('with', 'the'),
#  ('the', 'last'),
#  ('last', 'several'),
#  ('several', 'decades”'),
#  ('decades”', 'the'),
#  ('the', 'capitalists'),
#  ('capitalists', 'of'),
#  ('of', 'amazon'),
#  ('amazon', 'starbucks'),
#  ('starbucks', 'microsoft'),
#  ('microsoft', 'and'),
#  ('and', 'boeing'),
#  ('boeing', 'in'),
#  ('in', 'her'),
#  ('her', 'marxian'),
#  ('marxian', 'optic'),
#  ('optic', 'generate'),
#  ('generate', 'enormous'),
#  ('enormous', 'wealth'),
#  ('wealth', 'for'),
#  ('for', 'themselves'),
#  ('themselves', 'drive'),
#  ('drive', 'up'),
#  ('up', 'housing'),
#  ('housing', 'prices'),
#  ('prices', 'and'),
#  ('and', 'push'),
#  ('push', 'the'),
#  ('the', 'working'),
#  ('working', 'class'),
#  ('class', 'toward'),
#  ('toward', 'poverty'),
#  ('poverty', 'and'),
#  ('and', 'despair—and'),
#  ('despair—and', 'too'),
#  ('too', 'often'),
#  ('often', 'onto'),
#  ('onto', 'the'),
#  ('the', 'streets'),
#  ('on', 'the'),
#  ('the', 'surface'),
#  ('surface', 'this'),
#  ('this', 'argument'),
#  ('argument', 'has'),
#  ('has', 'its'),
#  ('its', 'own'),
#  ('own', 'internal'),
#  ('internal', 'logic'),
#  ('logic', 'advocates'),
#  ('advocates', 'point'),
#  ('point', 'to'),
#  ('to', 'zillow'),
#  ('zillow', 'and'),
#  ('and', 'mckinsey'),
#  ('mckinsey', 'studies'),
#  ('studies', 'that'),
#  ('that', 'show'),
#  ('show', 'a'),
#  ('a', 'high'),
#  ('high', 'correlation'),
#  ('correlation', 'between'),
#  ('between', 'rent'),
#  ('rent', 'hikes'),
#  ('hikes', 'and'),
#  ('and', 'homelessness'),
#  ('homelessness', 'in'),
#  ('in', 'seattle'),
#  ('seattle', 'for'),
#  ('for', 'example'),
#  ('example', 'but'),
#  ('but', 'correlation'),
#  ('correlation', 'is'),
#  ('is', 'not'),
#  ('not', 'causation'),
#  ('causation', 'and'),
#  ('and', 'the'),
#  ('the', 'survey'),
#  ('survey', 'data'),
#  ('data', 'paint'),
#  ('paint', 'a'),
#  ('a', 'remarkably'),
#  ('remarkably', 'different'),
#  ('different', 'picture'),
#  ('picture', 'according'),
#  ('according', 'to'),
#  ('to', 'king'),
#  ('king', 'county’s'),
#  ('county’s', 'pointintime'),
#  ('pointintime', 'study'),
#  ('study', 'only'),
#  ('only', '6'),
#  ('6', 'percent'),
#  ('percent', 'of'),
#  ('of', 'homeless'),
#  ('homeless', 'people'),
#  ('people', 'surveyed'),
#  ('surveyed', 'cited'),
#  ('cited', '“could'),
#  ('“could', 'not'),
#  ('not', 'afford'),
#  ('afford', 'rent'),
#  ('rent', 'increase”'),
#  ('increase”', 'as'),
#  ('as', 'the'),
#  ('the', 'precipitating'),
#  ('precipitating', 'cause'),
#  ('cause', 'of'),
#  ('of', 'their'),
#  ('their', 'situation'),
#  ('situation', 'pointing'),
#  ('pointing', 'instead'),
#  ('instead', 'to'),
#  ('to', 'a'),
#  ('a', 'wide'),
#  ('wide', 'range'),
#  ('range', 'of'),
#  ('of', 'other'),
#  ('other', 'problems—domestic'),
#  ('problems—domestic', 'violence'),
#  ('violence', 'incarceration'),
#  ('incarceration', 'mental'),
#  ('mental', 'illness'),
#  ('illness', 'family'),
#  ('family', 'conflict'),
#  ('conflict', 'medical'),
#  ('medical', 'conditions'),
#  ('conditions', 'breakups'),
#  ('breakups', 'eviction'),
#  ('eviction', 'addiction'),
#  ('addiction', 'and'),
#  ('and', 'job'),
#  ('job', 'loss—as'),
#  ('loss—as', 'bigger'),
#  ('bigger', 'factors'),
#  ('factors', 'further'),
#  ('further', 'while'),
#  ('while', 'the'),
#  ('the', 'zillow'),
#  ('zillow', 'study'),
#  ('study', 'did'),
#  ('did', 'find'),
#  ('find', 'correlation'),
#  ('correlation', 'between'),
#  ('between', 'rising'),
#  ('rising', 'rents'),
#  ('rents', 'and'),
#  ('and', 'homelessness'),
#  ('homelessness', 'in'),
#  ('in', 'four'),
#  ('four', 'major'),
#  ('major', 'markets—seattle'),
#  ('markets—seattle', 'los'),
#  ('los', 'angeles'),
#  ('angeles', 'new'),
#  ('new', 'york'),
#  ('york', 'and'),
#  ('and', 'washington'),
#  ('washington', 'dc—it'),
#  ('dc—it', 'also'),
#  ('also', 'found'),
#  ('found', 'that'),
#  ('that', 'homelessness'),
#  ('homelessness', 'decreased'),
#  ('decreased', 'despite'),
#  ('despite', 'rising'),
#  ('rising', 'rents'),
#  ('rents', 'in'),
#  ('in', 'houston'),
#  ('houston', 'tampa'),
#  ('tampa', 'chicago'),
#  ('chicago', 'phoenix'),
#  ('phoenix', 'st'),
#  ('st', 'louis'),
#  ('louis', 'san'),
#  ('san', 'diego'),
#  ('diego', 'portland'),
#  ('portland', 'detroit'),
#  ('detroit', 'baltimore'),
#  ('baltimore', 'atlanta'),
#  ('atlanta', 'charlotte'),
#  ('charlotte', 'and'),
#  ('and', 'riverside'),
#  ('riverside', 'rent'),
#  ('rent', 'increases'),
#  ('increases', 'are'),
#  ('are', 'a'),
#  ('a', 'real'),
#  ('real', 'burden'),
#  ('burden', 'for'),
#  ('for', 'the'),
#  ('the', 'working'),
#  ('working', 'poor'),
#  ('poor', 'but'),
#  ('but', 'the'),
#  ('the', 'evidence'),
#  ('evidence', 'suggests'),
#  ('suggests', 'that'),
#  ('that', 'higher'),
#  ('higher', 'rents'),
#  ('rents', 'alone'),
#  ('alone', 'don’t'),
#  ('don’t', 'push'),
#  ('push', 'people'),
#  ('people', 'onto'),
#  ('onto', 'the'),
#  ('the', 'streets'),
#  ('even', 'in'),
#  ('in', 'a'),
#  ('a', 'pricey'),
#  ('pricey', 'city'),
#  ('city', 'like'),
#  ('like', 'seattle'),
#  ('seattle', 'most'),
#  ('most', 'working'),
#  ('working', 'and'),
#  ('and', 'middleclass'),
#  ('middleclass', 'residents'),
#  ('residents', 'respond'),
#  ('respond', 'to'),
#  ('to', 'economic'),
#  ('economic', 'incentives'),
#  ('incentives', 'in'),
#  ('in', 'logical'),
#  ('logical', 'ways'),
#  ('ways', 'relocating'),
#  ('relocating', 'to'),
#  ('to', 'less'),
#  ('less', 'expensive'),
#  ('expensive', 'neighborhoods'),
#  ('neighborhoods', 'downsizing'),
#  ('downsizing', 'to'),
#  ('to', 'smaller'),
#  ('smaller', 'apartments'),
#  ('apartments', 'taking'),
#  ('taking', 'in'),
#  ('in', 'roommates'),
#  ('roommates', 'moving'),
#  ('moving', 'in'),
#  ('in', 'with'),
#  ('with', 'family'),
#  ('family', 'or'),
#  ('or', 'leaving'),
#  ('leaving', 'the'),
#  ('the', 'city'),
#  ('city', 'altogether'),
#  ('altogether', 'king'),
#  ('king', 'county'),
#  ('county', 'is'),
#  ('is', 'home'),
#  ('home', 'to'),
#  ('to', 'more'),
#  ('more', 'than'),
#  ('than', '1'),
#  ('1', 'million'),
#  ('million', 'residents'),
#  ('residents', 'earning'),
#  ('earning', 'below'),
#  ('below', 'the'),
#  ('the', 'median'),
#  ('median', 'income'),
#  ('income', 'and'),
#  ('and', '99'),
#  ('99', 'percent'),
#  ('percent', 'of'),
#  ('of', 'them'),
#  ('them', 'manage'),
#  ('manage', 'to'),
#  ('to', 'find'),
#  ('find', 'a'),
#  ('a', 'place'),
#  ('place', 'to'),
#  ('to', 'live'),
#  ('live', 'and'),
#  ('and', 'pay'),
#  ('pay', 'the'),
#  ('the', 'rent'),
#  ('rent', 'on'),
#  ('on', 'time'),
#  ('time', 'the'),
#  ('the', 'aggregatelevel'),
#  ('aggregatelevel', 'analyses'),
#  ('analyses', 'from'),
#  ('from', 'zillow'),
#  ('zillow', 'and'),
#  ('and', 'mckinsey'),
#  ('mckinsey', 'don’t'),
#  ('don’t', 'take'),
#  ('take', 'into'),
#  ('into', 'account'),
#  ('account', 'the'),
#  ('the', 'vast'),
#  ('vast', 'number'),
#  ('number', 'of'),
#  ('of', 'options'),
#  ('options', 'available'),
#  ('available', 'even'),
#  ('even', 'to'),
#  ('to', 'the'),
#  ('the', 'poorest'),
#  ('poorest', 'families'),
#  ('families', 'for'),
#  ('for', 'the'),
#  ('the', 'socialists'),
#  ('socialists', '“the'),
#  ('“the', 'rent'),
#  ('rent', 'is'),
#  ('is', 'too'),
#  ('too', 'damn'),
#  ('damn', 'high”'),
#  ('high”', 'explains'),
#  ('explains', 'everything'),
#  ('using', 'homelessness'),
#  ('homelessness', 'as'),
#  ('as', 'a'),
#  ('a', 'symbol'),
#  ('symbol', 'of'),
#  ('of', '“capitalism’s'),
#  ('“capitalism’s', 'moral'),
#  ('moral', 'failure”'),
#  ('failure”', 'the'),
#  ('the', 'socialists'),
#  ('socialists', 'hope'),
#  ('hope', 'to'),
#  ('to', 'build'),
#  ('build', 'support'),
#  ('support', 'for'),
#  ('for', 'their'),
#  ('their', 'agenda'),
#  ('agenda', 'of'),
#  ('of', 'rent'),
#  ('rent', 'control'),
#  ('control', 'public'),
#  ('public', 'housing'),
#  ('housing', 'minimumwage'),
#  ('minimumwage', 'hikes'),
#  ('hikes', 'and'),
#  ('and', 'punitive'),
#  ('punitive', 'corporate'),
#  ('corporate', 'taxation'),
#  ('taxation', 'one'),
#  ('one', 'might'),
#  ('might', 'dismiss'),
#  ('dismiss', 'sawant'),
#  ('sawant', 'as'),
#  ('as', 'cartoonish'),
#  ('cartoonish', 'but'),
#  ('but', 'she'),
#  ('she', 'has'),
#  ('has', 'been'),
#  ('been', 'remarkably'),
#  ('remarkably', 'successful'),
#  ('successful', 'in'),
#  ('in', 'stoking'),
#  ('stoking', 'resentment'),
#  ('resentment', 'against'),
#  ('against', '“amazon'),
#  ('“amazon', 'tech'),
#  ('tech', 'bros”'),
#  ('bros”', 'and'),
#  ('and', 'building'),
#  ('building', 'public'),
#  ('public', 'support'),
#  ('support', 'for'),
#  ('for', 'punishing'),
#  ('punishing', 'the'),
#  ('the', '“billionaire'),
#  ('“billionaire', 'class”'),
#  ('class”', 'with'),
#  ('with', 'new'),
#  ('new', 'taxes'),
#  ('what', 'the'),
#  ('the', 'socialists'),
#  ('socialists', 'won’t'),
#  ('won’t', 'or'),
#  ('or', 'can’t'),
#  ('can’t', 'see'),
#  ('see', 'is'),
#  ('is', 'that'),
#  ('that', 'their'),
#  ('their', 'agenda'),
#  ('agenda', 'cannot'),
#  ('cannot', 'solve'),
#  ('solve', 'the'),
#  ('the', 'homelessness'),
#  ('homelessness', 'crisis'),
#  ('crisis', 'even'),
#  ('even', 'if'),
#  ('if', 'the'),
#  ('the', 'sawantchampioned'),
#  ('sawantchampioned', '“head'),
#  ('“head', 'tax”'),
#  ('tax”', 'on'),
#  ('on', 'big'),
#  ('big', 'employers'),
#  ('employers', 'had'),
#  ('had', 'stayed'),
#  ('stayed', 'in'),
#  ('in', 'force—it'),
#  ('force—it', 'was'),
#  ('was', 'repealed'),
#  ('repealed', 'in'),
#  ('in', 'june—the'),
#  ('june—the', 'city'),
#  ('city', 'would'),
#  ('would', 'have'),
#  ('have', 'built'),
#  ('built', 'at'),
#  ('at', 'most'),
#  ('most', 'only'),
#  ('only', '187'),
#  ('187', 'subsidized'),
#  ('subsidized', 'housing'),
#  ('housing', 'units'),
#  ('units', 'per'),
#  ('per', 'year'),
#  ('year', 'which'),
#  ('which', 'means'),
#  ('means', 'that'),
#  ('that', 'it'),
#  ('it', 'would'),
#  ('would', 'take'),
#  ('take', 'at'),
#  ('at', 'least'),
#  ('least', '60'),
#  ('60', 'years'),
#  ('years', 'to'),
#  ('to', 'provide'),
#  ('provide', 'housing'),
#  ('housing', 'for'),
#  ('for', 'all'),
#  ('all', 'those'),
#  ('those', 'currently'),
#  ('currently', 'homeless'),
#  ('homeless', 'sawant’s'),
#  ('sawant’s', 'real'),
#  ('real', 'passion'),
#  ('passion', 'it'),
#  ('it', 'seems'),
#  ('seems', 'is'),
#  ('is', 'not'),
#  ('not', 'to'),
#  ('to', 'build'),
#  ('build', 'houses'),
#  ('houses', 'for'),
#  ('for', 'the'),
#  ('the', 'poor'),
#  ('poor', 'but'),
#  ('but', 'to'),
#  ('to', 'tear'),
#  ('tear', 'down'),
#  ('down', 'the'),
#  ('the', 'houses'),
#  ('houses', 'of'),
#  ('of', 'the'),
#  ('the', 'rich'),
#  ('rich', 'when'),
#  ('when', 'her'),
#  ('her', 'ideas'),
#  ('ideas', 'fail'),
#  ('fail', 'to'),
#  ('to', 'usher'),
#  ('usher', 'in'),
#  ('in', 'a'),
#  ('a', 'socialist'),
#  ('socialist', 'utopia'),
#  ('utopia', 'she’ll'),
#  ('she’ll', 'find'),
#  ('find', 'new'),
#  ('new', 'scapegoats—corporations'),
#  ('scapegoats—corporations', 'realestate'),
#  ('realestate', 'developers'),
#  ('developers', 'tech'),
#  ('tech', 'workers'),
#  ('workers', 'police—and'),
#  ('police—and', 'start'),
#  ('start', 'over'),
#  ('the', 'stubborn'),
#  ('stubborn', 'reality'),
#  ('reality', 'is'),
#  ('is', 'that'),
#  ('that', 'seattle'),
#  ('seattle', 'is'),
#  ('is', 'expensive'),
#  ('expensive', 'the'),
#  ('the', 'local'),
#  ('local', 'government'),
#  ('government', 'should'),
#  ('should', 'encourage'),
#  ('encourage', 'the'),
#  ('the', 'creation'),
#  ('creation', 'of'),
#  ('of', 'more'),
#  ('more', 'affordable'),
#  ('affordable', 'marketrate'),
#  ('marketrate', 'housing'),
#  ('housing', 'by'),
#  ('by', 'increasing'),
#  ('increasing', 'density'),
#  ('density', 'and'),
#  ('and', 'changing'),
#  ('changing', 'zoning'),
#  ('zoning', 'laws'),
#  ('laws', 'but'),
#  ('but', 'for'),
#  ('for', 'those'),
#  ('those', 'not'),
#  ('not', 'employed'),
#  ('employed', 'fulltime—and'),
#  ('fulltime—and', 'that'),
#  ('that', 'describes'),
#  ('describes', '925'),
#  ('925', 'percent'),
#  ('percent', 'of'),
#  ('of', 'the'),
#  ('the', 'homeless—it’s'),
#  ('homeless—it’s', 'utopian'),
#  ('utopian', 'to'),
#  ('to', 'imagine'),
#  ('imagine', 'that'),
#  ('that', 'seattle'),
#  ('seattle', 'will'),
#  ('will', 'become'),
#  ('become', 'the'),
#  ('the', 'city'),
#  ('city', 'of'),
#  ('of', 'housing'),
#  ('housing', 'for'),
#  ('for', 'all'),
#  ('all', 'no'),
#  ('no', 'matter'),
#  ('matter', 'how'),
#  ('how', 'many'),
#  ('many', 'promises'),
#  ('promises', 'the'),
#  ('the', 'socialists'),
#  ('socialists', 'make'),
#  ('make', 'they'),
#  ('they', 'will'),
#  ('will', 'eventually'),
#  ('eventually', 'run'),
#  ('run', 'out'),
#  ('out', 'of'),
#  ('of', 'other'),
#  ('other', 'people’s'),
#  ('people’s', 'money'),
#  ('money', 'the'),
#  ('the', 'scapegoats'),
#  ('scapegoats', 'silent'),
#  ('silent', 'up'),
#  ('up', 'to'),
#  ('to', 'now'),
#  ('now', 'will'),
#  ('will', 'start'),
#  ('start', 'fighting'),
#  ('fighting', 'back'),
#  ('back', 'and'),
#  ('and', 'amazon'),
#  ('amazon', 'the'),
#  ('the', 'greatest'),
#  ('greatest', 'wealth'),
#  ('wealth', 'generator'),
#  ('generator', 'in'),
#  ('in', 'the'),
#  ('the', 'city’s'),
#  ('city’s', 'history'),
#  ('history', 'will'),
#  ('will', 'simply'),
#  ('simply', 'leave'),
#  ('leave', 'town'),
#  ('“what', 'the'),
#  ('the', 'socialists'),
#  ('socialists', 'won’t'),
#  ('won’t', 'or'),
#  ('or', 'can’t'),
#  ('can’t', 'see'),
#  ('see', 'is'),
#  ('is', 'that'),
#  ('that', 'their'),
#  ('their', 'agenda'),
#  ('agenda', 'cannot'),
#  ('cannot', 'solve'),
#  ('solve', 'the'),
#  ('the', 'homelessness'),
#  ('homelessness', 'crisis”'),
#  ('the', 'compassion'),
#  ('compassion', 'brigades'),
#  ...]

# %% [markdown]
# I will also use the **stopwords** here. I will get rid of any pair of words that include at least one of the **stopwords**:

# %%
pairWords_clean = [gram for gram in pairWords if not any(stop in gram for stop in STOPS)]
print(pairWords_clean)
# Out:
# [('past', 'five'), ('five', 'years'), ('emerald', 'city'), ('homelessness', 'crime'), ('2017', 'pointintime'), ('pointintime', 'count'), ('homeless', 'king'), ('king', 'county'), ('county', 'socialservices'), ('socialservices', 'agency'), ('home', 'found'), ('found', '11643'), ('11643', 'people'), ('people', 'sleeping'), ('tents', 'cars'), ('emergency', 'shelters'), ('shelters', 'property'), ('property', 'crime'), ('rate', 'two'), ('half', 'times'), ('times', 'higher'), ('los', 'angeles’s'), ('four', 'times'), ('times', 'higher'), ('new', 'york'), ('york', 'city’s'), ('city’s', 'cleanup'), ('cleanup', 'crews'), ('crews', 'pick'), ('dirty', 'needles'), ('city', 'streets'), ('parks', 'every'), ('every', 'year'), ('time', 'according'), ('puget', 'sound'), ('sound', 'business'), ('business', 'journal'), ('seattle', 'metro'), ('metro', 'area'), ('area', 'spends'), ('1', 'billion'), ('billion', 'fighting'), ('fighting', 'homelessness'), ('homelessness', 'every'), ('every', 'year'), ('year', 'that’s'), ('that’s', 'nearly'), ('nearly', '100000'), ('every', 'homeless'), ('homeless', 'man'), ('man', 'woman'), ('king', 'county'), ('county', 'yet'), ('crisis', 'seems'), ('tent', 'encampments'), ('residential', 'neighborhoods'), ('city’s', 'efforts'), ('past', 'year'), ('year', 'i’ve'), ('i’ve', 'spent'), ('spent', 'time'), ('city', 'council'), ('council', 'meetings'), ('meetings', 'political'), ('political', 'rallies'), ('rallies', 'homeless'), ('homeless', 'encampments'), ('rehabilitation', 'facilities'), ('facilities', 'trying'), ('much', 'money'), ('little', 'effect'), ('tactical', 'policy'), ('policy', 'questions'), ('questions', 'build'), ('shelters', 'open'), ('open', 'supervised'), ('supervised', 'injection'), ('injection', 'sites'), ('real', 'battle'), ('battle', 'isn’t'), ('city', 'hall'), ('four', 'ideological'), ('ideological', 'power'), ('power', 'centers'), ('centers', 'frame'), ('frame', 'seattle’s'), ('seattle’s', 'homelessness'), ('homelessness', 'debate'), ('debate', 'i’ll'), ('i’ll', 'identify'), ('compassion', 'brigades'), ('homelessindustrial', 'complex'), ('addiction', 'evangelists'), ('evangelists', 'together'), ('local', 'policy'), ('policy', 'discussion'), ('discussion', 'diverted'), ('diverted', 'hundreds'), ('dollars', 'toward'), ('toward', 'favored'), ('favored', 'projects'), ('converted', 'many'), ('many', 'wellintentioned'), ('wellintentioned', 'voters'), ('unlimited', 'compassion'), ('failed', 'status'), ('status', 'quo'), ('places', 'like'), ('like', 'seattle—and'), ('portland', 'san'), ('san', 'francisco'), ('los', 'angeles'), ('angeles', 'too—we'), ('too—we', 'must'), ('must', 'first'), ('first', 'map'), ('ideological', 'battlefield'), ('battlefield', 'identify'), ('current', 'policies'), ('liberal', 'locales'), ('recent', 'years'), ('marched', 'even'), ('declared', 'war'), ('democratic', 'establishment'), ('establishment', 'socialist'), ('socialist', 'alternative'), ('alternative', 'city'), ('city', 'councilwoman'), ('councilwoman', 'kshama'), ('kshama', 'sawant'), ('sawant', 'claims'), ('city’s', 'homelessness'), ('homelessness', 'crisis'), ('inevitable', 'result'), ('amazon', 'boom'), ('boom', 'greedy'), ('greedy', 'landlords'), ('rapidly', 'increasing'), ('increasing', 'rents'), ('told', 'street'), ('street', 'roots'), ('roots', 'news'), ('news', '“the'), ('“the', 'explosion'), ('homelessness', 'crisis'), ('deeply', 'dysfunctional'), ('dysfunctional', 'capitalism'), ('much', 'worse'), ('worse', 'living'), ('living', 'standards'), ('last', 'several'), ('several', 'decades”'), ('amazon', 'starbucks'), ('starbucks', 'microsoft'), ('marxian', 'optic'), ('optic', 'generate'), ('generate', 'enormous'), ('enormous', 'wealth'), ('housing', 'prices'), ('working', 'class'), ('class', 'toward'), ('toward', 'poverty'), ('often', 'onto'), ('internal', 'logic'), ('logic', 'advocates'), ('advocates', 'point'), ('mckinsey', 'studies'), ('high', 'correlation'), ('rent', 'hikes'), ('survey', 'data'), ('data', 'paint'),  ...

# %% [markdown]
# At this stage, let me create a frequency table of the bigrams:

# %%
from collections import Counter

bigramsCount_dict = Counter(pairWords_clean) #generate counter

# Turn bigramsCount_dict  into dataframe, naming columns
bigramsCount = pd.DataFrame(bigramsCount_dict.most_common(),
                        columns=['theBigram', 'weight'])
bigramsCount
# Out:
#                           theBigram  weight
# 0                    (king, county)       8
# 1          (addiction, evangelists)       7
# 2     (homelessindustrial, complex)       6
# 3                 (harm, reduction)       5
# 4           (homeless, encampments)       4
# ...                             ...     ...
# 1383                 (people, able)       1
# 1384                   (live, work)       1
# 1385     (flourishing, environment)       1
# 1386           (whether, political)       1
# 1387           (political, leaders)       1
#
# [1388 rows x 2 columns]

# %% [markdown]
# I need to create two columns from the tuples:

# %%
bigramsCount['word1'], bigramsCount['word2'] =zip(*bigramsCount['theBigram'])
bigramsCount
# Out:
#                           theBigram  weight               word1        word2
# 0                    (king, county)       8                king       county
# 1          (addiction, evangelists)       7           addiction  evangelists
# 2     (homelessindustrial, complex)       6  homelessindustrial      complex
# 3                 (harm, reduction)       5                harm    reduction
# 4           (homeless, encampments)       4            homeless  encampments
# ...                             ...     ...                 ...          ...
# 1383                 (people, able)       1              people         able
# 1384                   (live, work)       1                live         work
# 1385     (flourishing, environment)       1         flourishing  environment
# 1386           (whether, political)       1             whether    political
# 1387           (political, leaders)       1           political      leaders
#
# [1388 rows x 4 columns]

# %% [markdown]
# I will use those columns with networkx:

# %%
import networkx as nx

G_bigram=nx.from_pandas_edgelist(df=bigramsCount, source='word1',target= 'word2',edge_attr= ["weight"])

# %%
# plotting graph (default layout)
nx.draw_networkx(G_bigram)

# %% [markdown]
# I should subset:

# %%
#subsetting
bigramsCount_wgte_3=bigramsCount[bigramsCount['weight']>=3]

G_bigram_wgte_3=nx.from_pandas_edgelist(df=bigramsCount_wgte_3, source='word1',target= 'word2',edge_attr= ["weight"])

# %%
#plotting
fig, ax = plt.subplots(figsize=(10, 10))
pos = nx.spring_layout(G_bigram_wgte_3)

# Plot networks
nx.draw_networkx(G_bigram_wgte_3, pos,
                 edge_color='red',node_color='yellow',
                 node_size=100,with_labels = False,ax=ax)

# labels away from node
for word, freq in pos.items():
    x, y = freq[0]+.05, freq[1]+.03
    ax.text(x, y,s=word,horizontalalignment='center',
            fontsize=13,rotation=30)

plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 10))
pos = nx.spring_layout(G_bigram_wgte_3, weight='weight',k=0.6)
nx.draw_networkx(G_bigram_wgte_3, pos)

# labels away from node
for word, freq in pos.items():
    x, y = freq[0]+.05, freq[1]+.03
    ax.text(x, y,s=word,horizontalalignment='center',
            fontsize=13,rotation=30)

for edge in G_bigram_wgte_3.edges(data='weight'):
    nx.draw_networkx_edges(G_bigram_wgte_3, pos, edgelist=[edge], width=2*edge[2])

# %% [markdown]
# <div class="alert-success">
#
# <strong>Exercise</strong>
#
# 1. Create a GitHub repo.
# 2. Create a notebook in python, and do a wordcloud with a text in English. Use a file in txt.
# 3. Create a notebook in python, and do a bigram the previous txt file.
# 4. Publish the result as a webpage using GitHub
#
# </div>

# %% [markdown]
# <div class="alert alert-danger">
#   <strong>CHALLENGE!</strong>
#    <br> * Use the function [n-grams](https://tedboy.github.io/nlps/generated/generated/nltk.ngrams.html) from NLTK, for 3-grams and 4-grams. Use a text in Spanish.
# </div>

# %% [markdown]
# # Ejercicio con editoriales de El Comercio como data

# %%
import os
# Establecer el directorio de trabajo
os.chdir(r'/workspaces/Tarea-4_ASIES/tarea4/EC_12abril_2mayo')

# %%
# Lista para almacenar el contenido de los archivos
textos = []

# Leer cada archivo de texto en el directorio especificado
for archivo in os.listdir():
    if archivo.endswith('.txt'):
        with open(archivo, 'r', encoding='utf-8') as file:
            textos.append(file.read())

# 'textos' ahora contiene el contenido de cada archivo .txt

# %%
textos
# Out:
# ['La segunda vuelta no es un proceso de definiciones políticas que compromete solo a los dos candidatos que continúan compitiendo por acceder a la presidencia o a sus partidos. También los postulantes que quedaron fuera de carrera tras la votación del 11 de abril tienen responsabilidades que no deberían eludir. En la medida en que representaron a determinados sectores ciudadanos en la primera etapa de la contienda les corresponde, efectivamente, velar por lo que suceda con los intereses y valores de tales sectores en la segunda.\n\nAlgunos de ellos, sin embargo, dolidos por las noticias que les trajo el conteo de votos o temerosos de perjudicarse si se involucran demasiado en el respaldo o rechazo a las posiciones de los dos aspirantes todavía en liza, prefieren ignorar las demandas que la situación les plantea. No se trata, por cierto, de que forzosamente endosen una candidatura o la otra, sino de que señalen los riesgos que cada una de ellas entraña para orientar de esa manera a quienes confiaron en ellos en la primera vuelta. En eso consiste precisamente la tarea de un líder político: en liderar.\n\nEn ese sentido, el eventual respaldo a una de las dos opciones en disputa debería ser para los excandidatos un corolario y no una premisa. Lamentablemente, lo que estamos viendo en una mayoría de casos no se ajusta a esa descripción. O bien el endose se ha producido de manera sumaria y sin acompañarlo luego de una crítica a los asuntos en los que los votantes del expostulante que lo ha otorgado podrían sentirse defraudados; o bien la imposibilidad de renunciar al protagonismo alcanzado en la primera parte de la campaña se convierte en un obstáculo para que el expostulante ejerza eficazmente la crítica o el apoyo, según dicte la coherencia con las líneas generales de lo que le ofreció al país mientras era uno de los participantes del proceso.\n\nVerónika Mendoza es de hecho un buen ejemplo de lo primero, mientras que Hernando de Soto lo es de lo segundo.\n\nLa excandidata presidencial de Juntos por el Perú, como se sabe, anunció muy rápidamente que ella y la organización política que la postuló apoyarán en esta segunda vuelta a Pedro Castillo: una consecuencia previsible de la sintonía que guarda con los planes estatistas de Perú Libre y su simpatía por los regímenes totalitarios del continente. Frente a los anuncios de “desactivación” de la Defensoría del Pueblo o la ATU, o de intervención en la labor que viene llevando adelante la Sunedu, no obstante, Verónika Mendoza no ha dicho nada. ¿Debemos entender que está conforme con los planes de Castillo al respecto, o que sencillamente prefiere callar para no afectar las chances de la izquierda el 6 de junio?\n\nHernando de Soto, por otro lado, luce más interesado en tener un rol estelar en la segunda vuelta que en ayudar a sus antiguos adherentes a decidir qué hacer ahora con su voto. “Estoy proponiendo a la candidata Fujimori una fórmula para que su propuesta sea inclusiva y no mercantilista y al candidato Castillo, otra fórmula para que no se politice la economía dentro de un régimen comunista”, ha escrito en un comunicado divulgado ayer. ¿Debemos entender acaso que solo el que le dé la razón obtendrá la gracia de su voto?\n\nEn los predios de Avanza País, mientras tanto, parece existir la impresión de que las urgencias son otras, pues la mayoría de los congresistas elegidos en sus listas ya anunció que votará “contra el comunismo” y el canciller Francisco Tudela, hasta hace poco miembro de su “gabinete en la sombra”, se ha alejado del proyecto político conjunto argumentando que “en esta hora decisiva no se puede ser indeciso o esperar a ver quién gana”.\n\nUna severa llamada de atención, en fin, para quien, al igual que la señora Mendoza, parecería estar dispuesto a actuar como un convidado de piedra en esta segunda vuelta… a menos que le concedan el centro del escenario.\n\nTodo indica que el desencanto de los ciudadanos con sus líderes políticos tiene una explicación fácil, per ...
#  'En la peor de las condiciones posibles, con una pandemia que dificulta el contacto entre las personas, los peruanos acudimos ayer a las urnas para ejercer el más fundamental de nuestros derechos democráticos: elegir a quienes liderarán nuestro futuro por cinco años.\n\nLa jornada empezó de manera accidentada, particularmente en Lima, donde múltiples mesas demoraron en abrirse por la ausencia de sus miembros y con largas colas formándose en el exterior de los locales de sufragio. Aun así, para alrededor de las dos de la tarde, el 99,6% de las mesas ya se habían instalado, gracias a ciudadanos que se ofrecieron para suplir a los que habían sido asignados y no se presentaron.\n\nAsí las cosas, el proceso fluyó de forma ordenada y sin verdaderas sorpresas y, salvo por algunas pocas quejas cuya pertinencia tendrá que ser verificada, ajustado a la asepsia que todos esperábamos. Ello no evitó que, como suele ocurrir, algunos candidatos, como el señor Rafael López Aliaga, sugiriesen la existencia de irregularidades en su contra, sin ningún tipo de evidencia para sustentarlo.\n\nLos verdaderos sobresaltos recién llegaron por la noche, cuando los noticieros dieron a conocer primero el flash electoral a boca de urna y luego el conteo rápido de Ipsos. Como ya mostraban las encuestas que trascendían en la víspera, el candidato de Perú Libre, Pedro Castillo, consolidó su ascenso y habría alcanzado más votos que cualquier otro postulante, colocándose en el primer puesto con 18,1% del voto al 90% del conteo. Según la referida medición de Ipsos, lo siguen Keiko Fujimori (Fuerza Popular) con 14,4% y Rafael López Aliaga (Renovación Popular) con 12,4%. Hará falta esperar los resultados de la ONPE al 100% para saber el cuadro final de candidatos.\n\nTras una campaña marcada por la polarización –por la presencia de posiciones extremas– y la atomización –por lo pequeño del apoyo que recibió cada aspirante al sillón de Pizarro–, este desenlace solo augura aún más división en el camino a la segunda vuelta. El candidato de Perú Libre, por ejemplo, ostenta una posición de izquierda radical, partidaria de las nacionalizaciones y escéptica de las libertades individuales. La postulante de Fuerza Popular y el de Renovación Popular, por su parte, ofrecen una perspectiva más pegada a la derecha, que identifica en el sector privado la mejor vía para la creación de riqueza en el país.\n\nEn suma, es posible que en pocos meses los peruanos tengamos que tomar una decisión entre dos opciones diametralmente distintas. Ello no solo por las visiones divergentes que estas tendrán sobre cómo debe conducirse la economía, sino también por cómo conciben la democracia y el papel de los ciudadanos en ella. El señor Castillo, hay que decirlo, profesa perspectivas antojadizas de cómo este sistema político debe funcionar, con un discurso que invoca la disolución de instituciones importantes, como el Tribunal Constitucional y el Congreso (en caso no contribuya al cambio de Constitución: “Si el pueblo nos da la facultad, lo haremos”, ha dicho), y con un plan de gobierno abiertamente agresivo contra la libertad de prensa.\n\nSin embargo, más allá de la ideología de quien termine asumiendo las riendas del país, es claro que tendrá que lidiar con una representación parlamentaria fragmentada. Los resultados que se conocen hasta ahora confirman lo proyectado por los sondeos y la gobernanza dependerá, gane quien gane, del tino del nuevo jefe del Estado para alcanzar consensos.\n\nLa de ayer, en fin, ha sido una noche agitada para todos los peruanos. Cómo se termine por decantar esta carrera hacia Palacio de Gobierno dependerá de cómo trabajen los dos finalistas en los próximos meses y los endoses que consigan de quienes han quedado fuera de la contienda, lo que demandará acuerdos y conversaciones entre ellos. En ello se sustentará el futuro de nuestro país, nuestra economía, nuestra respuesta a la pandemia y, sobre todas las cosas, nuestra democracia.',
#  'Con las tensiones de segunda vuelta al alza mientras se aproxima el 6 de junio, de uno y otro lado se busca encontrar y ventilar supuestas conspiraciones en contra de la agrupación política de preferencia. Una de las que más ha calado en los últimos días ha sido la acusación al Banco Central de Reserva del Perú (BCRP) de manipulación del tipo de cambio para crear incertidumbre sobre los votantes o para generar ganancias indebidas entre especuladores financieros.\n\nLa excongresista Marisa Glave, cercana a las agrupaciones de izquierda que ha liderado la excandidata presidencial Verónika Mendoza, por ejemplo, señaló esta semana que “no estaría de más que salga información del BCRP sobre la elevación de precio del dólar... para evitar especulaciones (o para confirmarlas)”. Ella es solo una de diversas voces que en los últimos días han puesto en cuestionamiento la labor de la autoridad monetaria en la presente coyuntura.\n\nVale señalar que los recientes movimientos al alza del tipo de cambio sí son fuertes y claros: desde alrededor de S/3,60 por dólar poco antes de la primera vuelta hasta más de S/3,80 por dólar durante esta semana. Esa es, ciertamente, una depreciación de la moneda peruana mucho más marcada que la que el país ha vivido en procesos electorales anteriores.\n\nEl rol del BCRP, sin embargo, no es mantener el tipo de cambio fijo. De hecho, esa es la receta de control de precios que se ha ensayado en otras oportunidades con pésimas consecuencias. En situaciones como la actual, el BCRP debe intentar que las fluctuaciones del tipo de cambio sean menos marcadas –es decir, evitar incrementos o contracciones demasiado bruscas en poco tiempo–. Y es lo que ha hecho la institución.\n\nDe acuerdo con un reporte oficial publicado este jueves, “en las operaciones cambiarias en lo que va de abril, el BCRP tuvo una posición de ofertante neto en el mercado cambiario por US$1.674 millones para reducir la volatilidad del tipo de cambio”. En otras palabras, colocó una cantidad considerable de dólares en la economía local para que su precio suba menos. Sin embargo, ni el BCRP ni ninguna otra entidad pueden evitar que la incertidumbre que genera un eventual gobierno de Pedro Castillo, candidato por Perú Libre, tenga impactos inmediatos sobre los mercados financieros; tan solo atenuarlos.\n\nAlgunas acusaciones en contra del banco han señalado que la presencia de dos directores cercanos al fujimorismo, Rafael Rey y José Chlimper, hacen a la institución pasible de sospecha de participación política. Estas denuncias tienen poca solidez. Aun si estos directores quisieran dirigir la política cambiaria del BCRP –imputación para la que tampoco hay prueba–, no queda claro cómo lograrían que su posición prevalezca en un directorio de siete miembros que pone en marcha a un equipo de técnicos altamente calificados.\n\nArriesgar la reputación de la que posiblemente es la institución pública más sólida del Perú por motivaciones políticas es lamentable. Julio Velarde –cabeza del BCRP y distinguido como mejor banquero central del mundo–, junto con un sólido grupo de profesionales, han logrado a lo largo del tiempo la inflación más baja de Sudamérica y uno de los tipos de cambio más estables de la región. Los logros del BCRP hablan por sí mismos. Si se trata, en cualquier caso, de encontrar responsabilidades por el incremento del tipo de cambio, quizá sea más conveniente afinar la mira sobre aquello que hoy es causa de incertidumbre en los mercados y en el valor de la moneda local.',
#  'En abril, un peruano ha muerto cada cinco minutos a causa del COVID-19. Este mes ya se ha confirmado el fallecimiento de más de cinco mil compatriotas por este mal y las cifras hacen evidente que estamos pasando por el momento más letal de la pandemia, el corolario, según algunos expertos, de las salidas por Semana Santa y de la llegada de la variante brasileña al país. Los números que se manejan, además, serían apenas la punta del iceberg, toda vez que aún existen marcadas diferencias entre lo reportado por el Ministerio de Salud (Minsa) y lo contabilizado por otras instituciones.\n\nComo era de esperarse, con más de un año navegando esta crisis, el cansancio parece haberse instalado en todos los peruanos. A pesar de lo grave de la situación, muchas de las medidas aún vigentes para paliar la emergencia son tomadas a la ligera por muchos –más por necesidad que por desidia– y, hay que decirlo, el paso de los días parece demostrar que nuestras autoridades, en particular el Gobierno Central, no están muy seguras de qué acciones pueden tomarse para lidiar con el problema. Estamos en una especie de piloto automático, que coloca todas las esperanzas en un flemático proceso de vacunación y que hace difícil prever un cambio significativo en el estado de la curva epidemiológica y, en esa línea, en el número de personas que seguirán muriendo.\n\nEl presidente Francisco Sagasti ha sido claro al decir que “el Perú, como el resto del mundo, no está listo para un confinamiento total”. Y tiene razón. Una nueva cuarentena, tan severa como las que se han implementado en el pasado, solo agudizaría la insostenible crisis económica generada por más de doce meses de pandemia y, si nos basamos en cómo se han desarrollado este tipo de restricciones en el pasado, su eficacia no está garantizada. De hecho, dada la situación de la mayoría de las familias peruanas, lo más probable es que las prohibiciones sean letra muerta para una ciudadanía que simplemente no tiene cómo seguirse solventando.\n\nEl Colegio Médico del Perú ha cuestionado la labor del Ejecutivo y ha insistido en la necesidad de que se convoque al gremio para tomar mejores decisiones ante la crisis. El decano nacional Miguel Palacios Celi ha dicho, por ejemplo, que “los aforos tienen que ser supervisados. El Estado debe repartir mascarillas y protectores de manera masiva”. Acciones válidas que deberían complementarse con otras que puedan surgir de la evaluación conjunta que deben hacer los expertos en materia sanitaria con los encargados de las diferentes carteras ministeriales.\n\nLo que queda claro, sin embargo, es que, mientras el Gobierno tiene la obligación de descifrar cómo mejorar su desempeño ante esta emergencia, los candidatos que disputarán la segunda vuelta tienen que esmerarse por demostrar que tienen un plan concreto para que, luego del 28 de julio, no solo se siga enfrentando la pandemia, sino se definan las acciones que la derrotarán de una vez por todas. Tanto Pedro Castillo como Keiko Fujimori tienen que describir qué medidas tomarán para controlar los contagios y, asimismo, cómo garantizarán la vacunación masiva de todos los peruanos en el menor tiempo posible.\n\nNinguno de los dos, empero, ha dado cuenta de una estrategia clara y efectiva para lograr estas metas. Las palabras ‘COVID-19’ o ‘coronavirus’ no aparecen ni una sola vez en el manifiesto presentado al Jurado Nacional de Elecciones por Perú Libre y el plan de Fuerza Popular se queda en generalidades. Y, hagan lo que hagan, la hoja de ruta elegida tendrá que incluir un paquete de medidas macroeconómicamente sensatas y viables para evitar que nuestra economía permanezca así de perjudicada: hay que apuntalar nuestras fortalezas en lugar de, porfiadamente, buscar derrumbarlas.\n\nEl resto de nosotros, por el momento, tendremos que (aunque ya se ha convertido en un cliché decirlo) seguirnos cuidando. Para sobrevivir.',
#  'Si en algún momento había que decir que la pandemia está totalmente fuera de control en el Perú, ese momento es ahora. En los últimos ocho días, el registro de fallecidos diarios confirmados por COVID-19, de acuerdo con el Ministerio de Salud (Minsa), superó los 400 decesos en al menos cuatro ocasiones. Durante todo el año pasado, ni siquiera en el peor momento se llegó a 300. Según con las últimas estadísticas, un peruano muere cada cuatro minutos por la enfermedad.\n\nNo solo se trata del colapso casi total del sistema sanitario y de la inefectividad relativa de las políticas para prevenir nuevos contagios, sino también del avance lento de la campaña de vacunación. Más de dos meses luego de haber recibido el primer lote de vacunas, apenas 2,5% de la población tiene por lo menos la primera dosis. Esta proporción es el doble en Colombia, casi el cuádruple en México y unas 17 veces más en Chile –país que ya supera el 40% de inmunizados parciales o totales–, solo por mencionar a los pares de la Alianza del Pacífico.\n\nAnte esta realidad, miles de peruanos que tienen la posibilidad han decidido inmunizarse bajo sus propios medios. De acuerdo con un informe publicado en este Diario, si a inicios de año viajaban 10 mil peruanos por mes a EE.UU., para abril serían 40 mil, muchos de ellos, presumiblemente, para obtener las vacunas allá disponibles en varios estados.\n\nSin embargo, la vacunación de más peruanos –que debería ser siempre celebrada– parece no ser del total agrado de titular del Minsa, Óscar Ugarte. “Hay un nivel de desesperación por buscar vacunarse cuanto antes, pero eso mismo está reflejando las desigualdades en nuestra sociedad. Hay quienes pueden hacerlo y hay quienes no pueden hacerlo por más que quieran”, declaró la semana pasada. “Por eso el rol del Estado, por eso la necesidad de poner normas, todo lo que se ha discutido, por ejemplo, para que se priorice a las personas más vulnerables, y no es que yo me salto la fila y como yo tengo posibilidades económicas yo me vacuno, no es así”, indicó entonces.\n\nEsta visión del ministro es preocupante. En primer lugar, como resulta obvio, mientras más ciudadanos inmunizados haya en el país, la demanda por servicios médicos ya colapsados será menor, habrá mayor disponibilidad de vacunas para el resto, se alcanzará antes la inmunidad colectiva y se registrarán menos muertes. Solo desde una mirada muy mezquina se podrían entender estos beneficios netos como algo negativo.\n\nEn segundo lugar, no deja de ser llamativo que quien realiza la crítica sea, a la vez, el principal responsable de que el proceso de vacunación local marche a paso lento. Hasta mediados de la semana pasada, tan solo 11 regiones habían empezado con la inmunización de mayores de 80 años. Más que “saltar la fila”, como refiere el ministro, las personas que pueden han decidido hacer el esfuerzo para moverse a una fila que sí avanza. Lo que se quiere hacer pasar como una consecuencia de la desigualdad social en realidad refleja mejor la falta de efectividad del aparato público.\n\nEn cualquier caso, la manera correcta de reducir estas desigualdades es llevar las vacunas rápidamente para la gran mayoría, y no más bien mirar con cierto recelo a quienes usan sus propios medios para obtener aquello que el Estado no provee. Vale recordar que quienes sí se adelantaron a su turno de forma desleal fueron los funcionarios y autoridades que, aprovechando su cargo, accedieron a escondidas a la inmunización. Y esa crítica empieza por casa.',
#  'El principal propósito del sistema del balotaje es que el candidato al que le toque asumir el poder después de las elecciones lo haga con el respaldo de un sector significativo de la población: un asunto que cobra particular importancia en un proceso como el actual, en cuya primera vuelta ninguno de los postulantes alcanzó siquiera un 20% del voto válido. No es esa, sin embargo, la única virtud de este sistema. Después de la profusión de candidatos y propuestas a las que la ciudadanía se vio expuesta durante la etapa anterior de la campaña, ocho semanas en las que podemos concentrarnos en solo dos aspirantes presidenciales y sus planes de gobierno constituyen la ocasión ideal para conocerlos mejor… o por lo menos así debería ser.\n\nNo es eso, no obstante, lo que está sucediendo en esta oportunidad. Transcurridas dos de esas ocho semanas, son pocas las precisiones que hemos obtenido de parte de los postulantes de Perú Libre y Fuerza Popular sobre sus planes y equipos de gobierno. Generalidades y consignas propagandísticas es esencialmente lo que dejan sus mítines y entrevistas. Pero si lo que se puede extraer de las apariciones públicas de la señora Fujimori es poco, con el señor Castillo estamos simplemente ante el juego de las adivinanzas.\n\nEn los últimos días, ante diversos cuestionamientos de la prensa sobre lo que su candidatura le plantea al país, sus esfuerzos han estado orientados a decir lo que esos planteamientos no son, antes que a realmente definirlos. Sobre el plan que presentó ante el JNE para participar en estos comicios, por ejemplo, ha dicho que aquello solo era un “ideario”. “Nosotros hemos trabajado un programa de gobierno y, más allá de lo que diga o deje de decir [Vladimir] Cerrón, el que va a gobernar soy yo, Pedro Castillo”, ha sentenciado él. Y, aparte de que no se entiende por qué no fue ese el plan de gobierno que presentaron a las autoridades electorales, lo cierto es que aun hoy el supuesto documento continúa sin ver la luz.\n\nAlgo semejante sucede con su presunto equipo técnico. El domingo por la noche, en una entrevista televisiva en la que se le inquirió por la identidad de sus integrantes, Castillo repuso: “Los nombres no los voy a bajar, por situaciones del mismo equipo”. Y luego, dirigiéndose al periodista que lo interrogaba, añadió: “Te voy a dar [los nombres] luego de la entrevista”. Pero hasta donde se sabe, eso no se produjo.\n\nSi pensamos, por otro lado, en las iniciativas para combatir la pandemia del COVID-19 a las que el aspirante de Perú Libre ha aludido casi como al pasar –declarar en emergencia el sector salud, incrementar su presupuesto al 10% del PBI, priorizar la vacunación universal y potenciar un sistema de atención primaria con el programa Médico de la Familia–, el panorama se presenta igualmente brumoso, pues aquello no pasa de ser la recitación de un rosario de buenas intenciones.\n\nEn el fondo, lo que el señor Castillo parecería sugerirle a la ciudadanía es que le endose su apoyo en las ánforas por ser quien es –”un maestro, un rondero, un hombre del campo”– y dé por supuesta la idoneidad de sus planes… o siquiera su existencia. Pero la verdad es que esa pretensión es inaceptable. Por ser quien es –un profesor de educación primaria–, el candidato que nos ocupa debería estar, más bien, lleno de respuestas. Su mensaje debería ser claro, directo y fácil de transmitir. En lugar de ello, sin embargo, lo que recibimos son declaraciones borroneadas o reemplazadas por otras que supuestamente desautorizan las anteriores, o la reiteración de frases como “hay que escuchar al pueblo”, que sirven para salir del paso cuando se demandan las líneas maestras de un derrotero que brilla por su ausencia.\n\nLa buena noticia es que una situación de ambigüedad como esta difícilmente puede sostenerse por cinco semanas.',
#  'Sería un esfuerzo fútil y hasta avezado el intentar explicar el voto por determinada candidatura basados en una sola dimensión de análisis. En el acto electoral, los ciudadanos condensamos imperfectamente nuestras aspiraciones materiales, nuestra visión del mundo y simpatías, nuestras frustraciones y nuestra demanda por representatividad en el gobierno. No se puede escapar de esta complejidad humana utilizando perspectivas unidimensionales más de lo que se puede resumir una profunda novela en unas cuantas ideas fuerza y descripción de trama.\n\nEso no significa, sin embargo, que no se pueda buscar explicaciones parciales que ayuden a armar el rompecabezas. Uno de los temas que quedaron claros en la primera vuelta electoral del domingo pasado, por ejemplo, fue la fuerte inclinación del electorado nacional por opciones de corte conservador en lo social; en efecto, los cinco candidatos que ocuparon las primeras posiciones sostenían –en diferentes medidas– esta visión.\n\nEn esta búsqueda por comprender mejor los votos, explicar el súbito ascenso de Pedro Castillo, candidato de Perú Libre –quien pocas semanas atrás no ostentaba lugar prominente en las encuestas–, es una tarea pendiente. En vista de la correlación entre los índices de vulnerabilidad y la votación por Perú Libre, es obvio que la precariedad económica –si bien no es la historia completa– juega un rol en el voto de esta primera minoría política del Perú.\n\nNo hay duda de que en la gran mayoría de zonas donde ganó el dirigente sindical hace falta mayor presencia del Estado. Carencias de diversos tipos acercan a muchos lugares del país más al siglo XIX que al siglo XXI. Sin embargo, esto no significa necesariamente que falten recursos. De acuerdo con un informe publicado el viernes por este Diario, “en las regiones con mayor producción minera como Áncash, Apurímac, Arequipa, Cajamarca, Cusco, Junín, Moquegua y Tacna, en donde Castillo alcanzó la máxima votación entre los candidatos en la primera vuelta, los gobiernos subnacionales dejan de invertir en obras, en promedio, S/1.830 millones cada año, el 46% de su presupuesto”, según cifras del Ministerio de Economía y Finanzas (MEF). De acuerdo con la contraloría, existen 294 obras de infraestructura paralizadas que suman casi S/5.000 millones.\n\nLa población más vulnerable posiblemente tiene menos interés en ideologías políticas radicales y más en que sus problemas de acceso a servicios públicos se solucionen. Las brechas en educación, transporte, salud, conectividad digital, entre otras, guardan una relación directa con la incapacidad del aparato estatal de proveer estos servicios de forma adecuada. A pesar de contar con los recursos –muchos de ellos generados por la actividad minera–, los gobiernos regionales y locales no han logrado transformarlos en obras para la mejora de la calidad de vida de la población. Sea por displicencia, inefectividad o corrupción, el sistema debe repensarse desde la raíz.\n\nEl voto por cualquier candidato, decíamos, no se puede ni se debe resumir en una sola dimensión. A la vez, no obstante, es inevitable cuestionarse si las enormes limitaciones de la descentralización y del aparato público –claramente visibles en la pandemia pero que se arrastran por décadas– no habrán jugado un rol preponderante en esta primera vuelta. El mensaje, fuerte y claro desde el interior del Perú, es que ya no se puede seguir ignorando estas brechas. Aunque se quiera desconocer, la verdad es que todos pagamos las consecuencias de esta indolencia histórica.',
#  'Luego de que encabezó una larga y violenta huelga docente en el 2017, con el objetivo de que se suavizaran los criterios de evaluación a los maestros, la cercanía del candidato a la presidencia Pedro Castillo con individuos involucrados con el Movadef –brazo político de Sendero Luminoso– no ha sido ningún secreto. De hecho, como ha explicado con detalle el exministro del Interior Carlos Basombrío en nuestra sección de Opinión, el ahora candidato ha estado en la mira de la Dirección contra el Terrorismo de la Policía Nacional (Dircote), pues esta considera que hay evidencias documentadas de su proximidad a la organización en cuestión.\n\nConsultado sobre la materia hace unos días, el aspirante a la jefatura del Estado ha rechazado cualquier vínculo con el grupo homicida o con su fachada política. “Rechazo una vez más y que quede claro. Nosotros deslindamos abiertamente con situaciones y posturas extremistas”, ha dicho, para añadir que ellos han “luchado contra el terrorismo” y que lo seguirán haciendo. Ayer insistió en ello sentenciando: “A mí no me interesan las expresiones mediáticas, sino el país”.\n\nNo obstante, como reza un viejo adagio, “si el río suena es porque piedras trae”. Y las piedras en este caso abundan y ameritan una respuesta más asertiva y clara de quien pretende ser presidente de la República. Especialmente cuando la sospecha alcanza a personas harto cercanas a él y a la bancada que ha colocado en el Congreso.\n\nUn informe publicado ayer por este Diario ofrece muchísimos detalles inquietantes sobre ello. Como se sabe, el señor Castillo es el fundador de la Federación Nacional de Trabajadores en la Educación del Perú (Fenate-Perú), un grupo sindical del que fue secretario general hasta octubre pasado y en el que más de un miembro está asociado al Movadef. Ello según información de la Dircote, reportes de inteligencia, los archivos del propio Fenate y el padrón de ese grupo prosenderista.\n\nEl Fenate, como ha podido confirmar este Diario, tiene a dos integrantes de la agrupación fachada de Sendero Luminoso en sus filas: César Tito Rojas y Lucio Ccallo Ccallata. El primero, además de ser un miembro de base de la organización inaugurada por Castillo, fue uno de los fundadores del grupo prosenderista. Incluso, según la Dircote, registra visitas del 2000 al 2004 a miembros de la banda terrorista recluidos en el penal de Yanamayo. El segundo, por su lado, es secretario general de la base en el Collao (Puno) del Movadef (también según la Dircote).\n\nAsimismo, está el caso del congresista electo por Perú Libre Edgar Tello Montes, quien creó el referido gremio junto con Castillo. Su nombre aparece en un informe elaborado por la mencionada oficina de la policía en agosto del 2017, titulado “Infiltración del Movadef en algunas dirigencias del magisterio”. De acuerdo con las fuerzas del orden, Tello fue uno de los dirigentes del magisterio que firmó un pronunciamiento en apoyo del Movadef en enero del 2012. Como él, otros dos virtuales parlamentarios (Germán Tacuri Valdivia y Paul Gutiérrez Ticona) son señalados en el reporte.\n\nCon prescindencia de los descargos que hayan hecho y puedan hacer algunos de los mencionados en este editorial y quienes han sido nombrados en las notas producidas por este Diario sobre la materia, es claro que existe un patrón desconcertante en el entorno de Pedro Castillo. Cuesta creer que sea gratuito o casual que haya tantas personas asociadas a la misma organización siniestra alrededor de una sola persona y un solo partido. ¿Se trata de un exceso de desidia a la hora de evaluar a quienes ingresan al partido del lápiz o existe un atisbo de simpatía con las ideas del Movadef?\n\nEl candidato a la presidencia le debe a la ciudadanía mejores explicaciones no solo porque puede llegar a gobernarnos, sino por todas las víctimas de Sendero Luminoso que no merecen verlo reivindicado.',
#  'Ante las dudas de si el candidato Pedro Castillo (Perú Libre) acudiría o no a los debates que el Jurado Nacional de Elecciones (JNE) ha organizado para los dos últimos domingos de mayo, previos al balotaje que se disputará el 6 de junio, la candidata Keiko Fujimori (Fuerza Popular) lo conminó el miércoles a que “no se corra” y exponga sus propuestas al país. Ante ello, poco después, el sindicalista respondió retando a la exparlamentaria a que su primer encuentro se desarrolle en Chota, Cajamarca, su tierra natal. Luego, la postulante del partido naranja respondió proponiéndole que se den cita en el lugar elegido este domingo a las 8 p.m. Al día siguiente, Castillo exigió, más bien, que se lleve a cabo el sábado a la 1 p.m.: “Señora Keiko Fujimori, no estamos en una dictadura a la cual usted está acostumbrada para quebrarme una agenda que me ha puesto el pueblo. Pero si está tan apurada para debatir, le espero este sábado a la una de la tarde en la Plaza de Armas de Chota para debatir los puntos que quiera”.\n\nLamentablemente, después de tantas idas y venidas y de intentos de los postulantes al sillón de Pizarro por mostrarse los dientes, las posibilidades de que este evento se concrete parecen remotas. Por un lado, el señor Castillo ha sido sorprendido por un repentino resquebrajamiento de su salud que, según informó, lo forzó a suspender la agenda proselitista que tenía prevista ayer para atenderse en una clínica privada. Por el otro, el JNE ha asegurado que no puede organizar un intercambio de este tipo con tan poca anticipación por cuestiones logísticas. Cada polémica programada, además, tiene asignado un presupuesto y este encuentro improvisado no podría contar con uno. Así, el duelo anunciado solo podrá darse, primero, si el candidato del lápiz se recupera y, segundo, si se consigue un organismo neutral para que lo arbitre.\n\nEn todo caso, este juego en el que participaron Fujimori y Castillo seguro tendrá consecuencias políticas para ambos, que quizá se reflejen en las encuestas que vayan a publicarse en las semanas venideras. La circunstancia, empero, parece dejar mejor parada a la primera, toda vez que accedió a todos los peros planteados por su rival. De hecho, este último ha demostrado que puede ser sumamente escurridizo, especialmente cuando la prensa se ha propuesto interpelarlo por sus declaraciones, y reticente a aclarar los puntos más controversiales de su proyecto político.\n\nAnte esto, un debate entre los dos finalistas de este proceso electoral cobra mayor importancia. En ambos casos, que se sometan a un intercambio en vivo y en directo, donde sus declaraciones puedan ser refutadas por el rival y no simplemente celebradas por una muchedumbre de simpatizantes, es harto nutritivo para los electores. Además, la situación deja poco espacio para las evasivas o para que los postulantes se contradigan a su antojo. Esta podría ser una oportunidad dorada para que los ciudadanos obtengan respuestas, especialmente de Pedro Castillo, que recientemente ha dedicado mucha energía a generar preguntas.\n\nNo cabe duda de que este tipo de enfrentamientos democráticos son vitales para todos los procesos electorales. Y hoy más que nunca. Ambos contendores se encuentran en aceras ideológicas muy distintas y los dos tienen bagajes que preocupan a la ciudadanía. Sobre Fujimori, permanece fresca la memoria de la prepotencia que ejerció su bancada en el Congreso que fue disuelto. Sobre Castillo, alarma la facilidad con la que propone derrumbar instituciones básicas para la continuación de nuestro sistema democrático (el Tribunal Constitucional, el Parlamento, la Defensoría del Pueblo, etc.). Por todo ello, será fundamental ver cómo se proponen disipar las dudas que suscitan y cuán hábiles son bajo presión.\n\nQue el debate de mañana no se dé sería lamentable, pero no del todo desconcertante. Más bien, ambos candidatos deberían asegurar su presencia en los encuentros organizados por el JNE. Sin pretextos ni bravatas dignas de pel ...
#  'En los últimos días, diversos representantes de Perú Libre, partido del candidato a la presidencia Pedro Castillo, han descrito de forma explícita cómo los ejes principales de su proyecto político se sustentan en la destrucción de múltiples pilares de nuestra democracia. Así, se ha anunciado la disolución del Congreso para instalar –de buenas a primeras– una asamblea constituyente, la desarticulación del Tribunal Constitucional, la censura estatal de los medios de comunicación y la depredación de la propiedad privada. Una retahíla de medidas autoritarias en las antípodas de la libertad y del Estado de derecho.\n\nEl principal exponente de todas estas intenciones ha sido el líder del partido de marras, Vladimir Cerrón. Además de los diversos parlamentarios electos que vienen haciendo eco de su empresa política. De hecho, en ocasiones es difícil definir quién es verdaderamente el candidato que se enfrentará a Keiko Fujimori en el balotaje: ¿es el líder sindicalista que encabeza la fórmula presidencial o es el exgobernador de Junín, condenado por negociación incompatible?\n\nAyer, el señor Pedro Castillo trató de responder esta pregunta al ser entrevistado por una radio local: “Nosotros hemos trabajado un programa de gobierno. Más allá de lo que diga o deje de decir [Vladimir] Cerrón, el que va a gobernar soy yo”. Asimismo, trató de moderar el discurso que hasta ahora venían defendiendo él y sus adláteres (declaró que se respetaría el orden democrático, que no se expropiarían propiedades y que se defendería la libertad de expresión). Todo, a nuestro juicio, un poco difícil de creer.\n\nPara empezar, es tarde para que Castillo se busque desentender de su socio Vladimir Cerrón y de sus consignas políticas. No se trata de una figura discreta en su agrupación, pues, además de ser el claro líder de esta, la suya es la cara que más aparece en todo lo concerniente a Perú Libre: su retrato es la portada del documento que la campaña presentó al Jurado Nacional de Elecciones como plan de gobierno y la página web del partido está monopolizada por videos suyos. Por si fuese poco, el mismo Castillo ya ha defendido lo consignado por dicho documento, descartando la suscripción de una “hoja de ruta” o una moderación en su discurso: “El lenguaje está estructurado en función a las grandes necesidades del país […], no podemos decirles ‘hoy te vendo una cosa y mañana otra’ sabiendo que la realidad es la misma”.\n\nIncluso, en su momento, el señor Cerrón insistió en su rol de vocero para decir lo mismo: “No habrá hoja de ruta con Perú Libre y Pedro Castillo. Somos un partido consecuente y consciente de sus planteamientos”.\n\nPero si las inconsistencias en los pronunciamientos del candidato en cuestión no bastan para presagiar un encuentro suyo con la racionalidad democrática y un distanciamiento del exgobernador de Junín, el radicalismo de quienes lo representarán en el Parlamento zanja la discusión. Los elegidos, con el auspicio de la candidatura del líder sindicalista, son los principales promotores de la agenda extremista de Cerrón y cuesta imaginar que sea posible que modulen sus convicciones y, al mismo tiempo, que el postulante a jefe del Estado pueda ejercer el cargo antagonizando a las personas que llevó al Legislativo, que con tanto ahínco se han dedicado a reseñar cómo se traerían abajo los cimientos de nuestra democracia.\n\nEn suma, el elector tiene que tomarse con pinzas los conatos de prudencia de un candidato y de un partido que han basado su campaña en todo lo contrario. Al mismo tiempo, hay que mirar con escepticismo sus supuestos distanciamientos de personajes como Vladimir Cerrón, a quien todos los portales, y algunos documentos vinculados a la candidatura de Castillo, parecen rendirle culto. Al fin y al cabo, más de un tirano se ha hecho del poder edulcorando sus consignas.',
#  'Cada vez que se avecina un proceso electoral, la importancia de votar empuñando la mayor cantidad de información posible sobre los candidatos, y el proceso en sí, es exaltada tanto por los medios de comunicación como por las autoridades encargadas de organizar los comicios. Se trata, pues, de un requisito obvio y básico para emitir un voto responsable, consciente de las implicancias que tal o cual decisión pueda tener en el país y en la vida de los ciudadanos. Sin embargo, el artículo 191 de la Ley Orgánica de Elecciones, que prohíbe la difusión de encuestas en los días previos a que los peruanos acudan a las urnas, atenta directamente contra este principio.\n\nPara empezar, es evidente que hay un divorcio entre lo que la norma pretende y la realidad. Como suele ocurrir, las prohibiciones expresas a la provisión de un producto o servicio no eliminan la demanda por los mismos, solo la dirigen a fuentes clandestinas. En este caso, si los ciudadanos necesitan información encontrarán la manera de obtenerla a pesar de las proscripciones, solo que con el riesgo de que aquello que se obtiene sea fraudulento o engañoso, toda vez que los medios confiables de difusión están impedidos de compartir la data verificada y con el rigor de las encuestadoras profesionales. Algunos, como ocurrió días antes del 11 de abril, logran acceder a los sondeos reales gracias a las conexiones que puedan tener, mientras que muchos quedan expuestos a reportes hechizos que solo terminan por desinformarlos.\n\nEn ese sentido, si lo que pretende la ley que nos ocupa es “proteger” a la población de ser influenciada en vísperas de los comicios, es claro que logra todo lo contrario. Las encuestas compiladas de forma responsable y ajustada a criterios científicos no hacen más que ofrecer imágenes de la realidad que pueden nutrir las decisiones de los votantes. Pretender salvaguardarlos de ello es condescendiente y, ante la presencia de tanta información falsa, peligroso, ya que quienes buscan “influenciar” el voto no lo hacen en base a la verdad, sino a mentiras que la norma hace casi imposible conjurar.\n\nLos resultados de la primera vuelta del domingo, y los de otros procesos pasados, demuestran que en las últimas semanas ocurren cambios en las preferencias que la ciudadanía merece conocer. En 1990, Alberto Fujimori subió vertiginosamente en la última semana de la elección. En el 2018 ocurrió algo parecido con Jorge Muñoz en la carrera por la Municipalidad de Lima. Este año, Pedro Castillo, un candidato que hasta hace pocas semanas ocupaba la categoría “otros”, escaló en la última semana lo suficiente para llegar a la segunda vuelta.\n\nEn general, en campañas en las que los márgenes entre los aspirantes a cargos públicos son tan estrechos, tener información constante sobre cómo se perfilan las tendencias es de suma importancia. En este punto habrá quienes cuestionen que se decida el voto a partir de la posición de los políticos en las preferencias, pero si ello se hace o no es competencia exclusiva del ciudadano que tiene soberanía sobre su derecho a elegir. Los factores que cada uno tome en cuenta para ejercer su ciudadanía no deberían limitarse en base a los criterios que el Estado de forma antojadiza considere convenientes. Todas las herramientas tienen que estar en manos de los peruanos para que hagan lo que consideren más apropiado y ello incluye las encuestas. Prohibirlas, en cualquier momento, es perjudicarlos.\n\nLa información, en el contexto de un proceso electoral, cumple dos funciones fundamentales: primero, les permite a los votantes decidir con mayor consciencia quiénes los representarán mejor desde el poder. Segundo, y tan importante como la anterior, permite enfrentar las mentiras que se suelen propalar. El silencio electoral contraviene ambas.',
#  'Si bien el conteo de votos para el Congreso todavía no ha terminado, con los resultados que ya se conocen es factible hacer una proyección bastante precisa de cómo lucirá la próxima representación nacional en lo que concierne al número de integrantes por bancada. Con ese criterio en mente, es posible también anticipar la suerte que correrán algunos de los proyectos promovidos por los distintos partidos durante la reciente campaña electoral que necesariamente deberían pasar por el Legislativo; en particular, aquellos que requerirían una mayoría absoluta (66 votos) o una mayoría calificada (87 votos) para ser aprobados.\n\nHacer semejante puntualización desde ahora resulta fundamental, pues, en sus discursos frente a la ciudadanía, los candidatos presidenciales muchas veces han ignorado las limitaciones que tiene el ejercicio del poder de quien accede al Ejecutivo, creando la ficción de que a sola voluntad del gobernante se podrían poner en marcha determinadas iniciativas. De entre ellas, quizás la más promocionada ha sido la de un reemplazo de la actual Constitución por la vía de una Asamblea Constituyente.\n\nEl primer problema que ese empeño encuentra, sin embargo, es que no existe en nuestro ordenamiento legal una vía para convocarla. La vigente Carta Magna, en efecto, establece que es el propio Congreso la única instancia facultada para introducir modificaciones en el texto constitucional, por lo que las recientes promesas de algunos postulantes de convocar un referéndum no bien llegasen a Palacio no tenían –ni tienen– forma de materializarse, como no sea transgrediendo el orden institucional…\n\nSí se puede, en cambio, hacer modificaciones parciales o totales de la Constitución a través de una votación con mayoría absoluta en el Congreso que luego sea ratificada en un referéndum, o a través de una aprobación de tales cambios por una mayoría parlamentaria calificada repetida en dos legislaturas consecutivas. Pero es aquí donde la aritmética que sugieren las cifras electorales deviene determinante, pues, de acuerdo con un informe elaborado por este Diario, las bancadas de los grupos que propugnan el cambio total del texto constitucional tendrían, sumadas, cerca de 50 miembros, mientras que las de aquellas organizaciones que solo abogan por reformas parciales contarían con más de 80. Es cierto que, sobre la base de la experiencia, no se puede asumir que todas las bancadas votarán disciplinadamente en un solo sentido, pero llegar a los números requeridos en los escenarios arriba señalados sería en cualquier caso bastante difícil.\n\nTal circunstancia, no obstante, no es necesariamente una mala noticia. Los permanentes cambios en la ley de leyes para satisfacer los estados de ánimo de tal o cual coyuntura política generan incertidumbre jurídica y no favorecen el desarrollo pacífico de una sociedad.\n\nEn el afán de quienes tratan de impulsar un reemplazo de la actual Carta Magna, por otra parte, lo que parece existir es una irritación con su origen y la fantasía de que la sola consignación en el nuevo texto del derecho de la población a la salud y la educación de calidad, o a la vivienda digna, haría que esos beneficios se materializaran por arte de magia. Harían bien ellos en recordar, no obstante, que la Constitución que nos rige fue redactada por un Congreso Constituyente elegido libremente y que no hay forma de que el Estado provea los beneficios que quieren dar por garantizados como no sea permitiendo que los privados generen riqueza y obteniendo recursos fiscales a partir de ello. Es decir, la figura exactamente inversa a lo que se conseguiría forzando los mecanismos institucionales para convocar espuriamente una Asamblea Constituyente como la que han prometido.\n\nLas constituciones, no lo olvidemos, son esencialmente un instrumento para limitar el poder de quienes nos gobiernan y lo que los ímpetus por cambiarlas muchas veces esconden es un interés por quebrar tales límites y avasallar los resguardos de la democracia. ...
# ...
#  'Durante el año pasado, la atención del país estuvo centrada, lógicamente, en el combate sanitario al nuevo coronavirus y en sus consecuencias económicas. Pero este no fue el único obstáculo serio que vivió el Perú. Desde marzo pasado, un Congreso fragmentado, impulsivo y demagógico promovió normas miopes, complicó la gestión de la pandemia y causó una crisis política de proporciones históricas –y todo eso antes de cumplir un año de gestión–.\n\nEl país, sin embargo, no habría extraído demasiadas lecciones de esta triste experiencia parlamentaria. A primera vista, el Congreso electo en las elecciones generales de este mes repetiría algunos de los vicios del actual Legislativo, y le agregaría algunos nuevos. Entre las características compartidas con el actual Congreso está, por ejemplo, la atomización de la estructura parlamentaria. Esta vez serán diez las bancadas las que deberán buscar consensos, con la más grande, de 37 congresistas, perteneciente a Perú Libre.\n\nAnte un Legislativo fragmentado, los avances en la agenda de políticas públicas necesarias para el país se ponen cuesta arriba. Más bien, la experiencia reciente demuestra que, –a pesar de las diferencias–, cuando la coyuntura lo permite, los puntos de encuentro regulares entre distintas bancadas suelen ser el populismo y la conveniencia política. Por lo demás, y en vista de la poca cohesión de la mayoría de bancadas, lo esperable es que durante los siguientes períodos estas se dividan aún más.\n\nOtro punto preocupante en el que el nuevo Congreso se asemeja al actual es la baja experiencia relevante de los nuevos legisladores. De acuerdo con un informe elaborado por este Diario, solo nueve congresistas virtualmente electos –equivalente al 7% del total– han tenido ya experiencia como parlamentarios. Si se suman los asesores legislativos, el número de nuevos congresistas con algún paso por el ecosistema del hemiciclo y comisiones sube apenas al 15%.\n\nEste pobre resultado no es únicamente responsabilidad de los partidos políticos o de los electores. El impedimento de la reelección parlamentaria inmediata ha dañado seriamente la construcción de perfiles legislativos profesionales que aporten experiencia al Congreso. Si bien la renovación generacional es positiva, un Legislativo en el que la gran mayoría entrará a aprender el oficio puede tener muy malos resultados. Peor aún, entre los que sí tienen experiencia legislativa se encuentran perfiles altamente cuestionables, como José Luna (Podemos), quien afronta detención domiciliaria, o la exasesora Leslie Olivos (Fuerza Popular), excluida de las elecciones del 2020 por no haber consignado una sentencia –por falsificación de documentos en “agravio del Congreso”, dicho sea de paso–.\n\nLo que sí es nuevo en esta ocasión es la presencia significativa de miembros del Legislativo que tendrían vínculos con el Movadef, órgano de fachada de Sendero Luminoso. De acuerdo con un reporte de la Dirección contra el Terrorismo (Dircote), tres virtuales congresistas de Perú Libre pertenecerían a un sector radical del magisterio que para la policía está vinculado al Movadef. Por otro lado, la Dirección Nacional de Inteligencia (DINI) señala la existencia de vínculos entre dos virtuales parlamentarios del mismo partido y el Conare-Sutep de la facción del Movadef. Tres de estos cinco virtuales parlamentarios han negado que tengan relaciones con movimientos afines al senderismo, pero aun así su participación directa en un poder del Estado que determina el marco legal del país y que además maneja información de inteligencia reservada es motivo de preocupación.\n\nA diferencia del actual Congreso, que tiene un mandato reducido, el próximo Legislativo estaría en funciones por cinco años. Este es, además, un período crítico para el país, en el que no solo hay que reconstruir las bases económicas pospandemia, sino, quizá más importante aún, las bases institucionales que prevengan nuevas crisis políticas. Dada su conformación, por ahora exist ...
#  'No ha existido proceso de segunda vuelta en nuestra historia reciente en el que no se haya esgrimido –desde una de las partes en contienda o desde las dos– el argumento de que lo que está en juego es la vigencia de la democracia. Tales advertencias, sin embargo, han estado por lo general asociadas a la trayectoria política o a las vinculaciones internacionales del candidato al que se identificaba como peligroso para la subsistencia del Estado de derecho, antes que a declaraciones suyas o de las personas de su entorno. Y menos aún, a anuncios que formasen parte de su plan de gobierno.\n\nEn la presente coyuntura, no obstante, eso ha cambiado. Tanto en el discurso programático de Perú Libre como en las entrevistas que conceden en estos días a los medios los congresistas virtualmente electos de esa organización es posible distinguir nítidas amenazas a la institucionalidad democrática en el país que debemos señalar.\n\nEn el documento presentado ante el Jurado Nacional de Elecciones para reseñar las acciones que adoptaría de llegar al poder, por ejemplo, Perú Libre afirma: “Los ministerios de Educación y Cultura deben evaluar los contenidos de la televisión y las radios antes de la difusión, evitando de esta forma que se atente contra la moral y las buenas costumbres de la sociedad peruana”. Más adelante, se puntualizan también las supuestas razones por las que “la ley de regulación es necesaria” para “evitar con ello la ‘libertad’ del enriquecimiento, chantaje, difamación, calumnia y sobre todo la mentira”. Es decir, casi la versión de manual para imponer un mecanismo de censura a la crítica y a la información incómoda para el gobierno de turno.\n\nEn ese mismo sentido, se han pronunciado, además, los futuros parlamentarios Samuel Coayla (“El partido es un partido democrático; cuando dice ‘regule’ se refiere, por ejemplo, a los medios de comunicación que propagan programas que no llevan a nada a culturizar al pueblo”) y Zaira Arias (“Vamos a ganar y tu programa y tu persona se van a tener que retirar”, le dijo fuera de cámaras al conductor de un espacio político al que previamente había llamado “miserable”).\n\nA la misma legisladora en ciernes, por otro lado, debemos la versión más acabada de un proyecto abiertamente inconstitucional del que permanentemente se habla en los predios de Perú Libre. “El maestro [Castillo] plantea que en un plazo no mayor a seis meses va a llamar a la Asamblea Constituyente; esto automáticamente va a disolver el Congreso”, proclamó ella días atrás. Y luego añadió: “Solo va a quedar la Mesa Permanente (sic) actuando en el Legislativo de la mano con el Ejecutivo y se dará paso a los asambleístas que van a redactar la nueva Constitución”.\n\nPor su parte, el futuro parlamentario Guillermo Bermejo también ha abundado en la tesis de que el eventual cambio constitucional no debe ser decidido en el Congreso –como manda la actual ley de leyes– sino “en las ánforas”. Un comentario que acompañó con la advertencia de que, de llegar al poder, piensan expulsar a la DEA (la agencia norteamericana para la administración del control de drogas), principal colaborador en la lucha contra el narcotráfico en el país.\n\nEn suma, pues, lo que tenemos es a voceros calificados de una de las dos opciones que se disputan el acceso al gobierno en esta segunda vuelta que nos están describiendo, con pelos y señales, la tormenta que piensan desatar si obtienen el triunfo. Una tormenta que, como decíamos al principio, afectaría las instituciones sobre las que descansa nuestra democracia –libertad de prensa, separación de poderes, limitación constitucional de la capacidad de acción de quien administra el Ejecutivo, etc.– de manera definitiva.\n\nY no tomar precauciones ante los anuncios de un temporal, ya se sabe, es la manera más absurda de dejarse abatir por la desgracia.',
#  'Decir, como se dice estos días, que el resultado cosechado este domingo en las elecciones presidenciales por el candidato de Perú Libre, Pedro Castillo, no se vio venir es falsear la realidad. Los sondeos y simulacros de votación de las dos últimas semanas (incluyendo los que no podían divulgarse libremente, pero a los que cualquier persona interesada podía acceder) registraron el crecimiento de la intención de voto por él y permitían proyectar que seguiría creciendo hasta el momento del sufragio.\n\nPero ver venir no es lo mismo que entender. En lo rápido del incremento del respaldo a Castillo y en la ubicación de los lugares donde este se produjo de manera más señalada –la sierra sur y central del país– existe evidentemente un mensaje que requiere ser interpretado. Es, además, un mensaje repetido, pues de alguna forma reproduce lo que significó la votación por algunas listas parlamentarias de organizaciones marginales al ‘establishment’ político en las elecciones complementarias del año pasado, y se lo puede rastrear en realidad hasta la irrupción del fujimorismo en los comicios de 1990.\n\nConviene anotar de paso que, en comparación con aquel, este es un fenómeno modesto. De acuerdo con el conteo rápido de Ipsos, el postulante de Perú Libre habría conseguido apenas un 18,1% de los votos válidos: menos de lo que obtuvo, por ejemplo, Verónika Mendoza en el 2016, que en esa ocasión llegó tercera y no pasó a la segunda vuelta.\n\nDe cualquier forma, por moderado que sea, el porcentaje conseguido por Castillo es mayor que el obtenido por cualquier otro candidato en la primera vuelta; y en algunas regiones, como Apurímac, sí ha sido impresionante (más del 50%, de acuerdo con las proyecciones). Sería necio, en consecuencia, seguir ignorando el mensaje al que aludimos. Y descifrarlo, a decir verdad, no es tan difícil.\n\nDescartemos de antemano la lectura puramente ideologizada del apoyo a la candidatura que nos ocupa: si esa fuera la explicación, los votos habrían ido hacia otras postulaciones de izquierda que representaban esa opción de manera más orgánica y que, en buena cuenta, han estado esta vez entre las más castigadas en las ánforas. Nos parece obvio, sin embargo, que sí estamos ante un reclamo y una insatisfacción por el estado de cosas. Tanto en lo que concierne a la provisión de servicios de parte del Estado como en lo que se refiere a la representación política. La mayor virtud de Castillo, se diría, es no ser ninguno de los otros postulantes. Ninguno de aquellos que la población identifica con el sistema que ha fallado reiteradamente en su intento de representarla, por lo menos…\n\nUn sector del país le ha dicho al otro, por enésima vez, que quizás lo esté viendo, pero que no lo está mirando. Porque, tras el sobresalto que producen votaciones como la del domingo en la población urbana y mejor colocada frente a los beneficios derivados del crecimiento económico de las últimas décadas, la vida de alguna forma se normaliza y todo sigue más o menos igual por otros cinco años.\n\nEl resultado de esa indolencia, no obstante, es muy peligroso, porque, junto con aquellas cosas que hace falta cambiar, se pone en riesgo todo lo valioso que ya hemos conquistado: un manejo macroeconómico sensato, un mínimo grado de institucionalidad y un acuerdo mayoritario por respetar las formas de la democracia. Procesar ese mensaje de una vez por todas antes de la segunda vuelta deviene hoy, pues, indispensable.\n\nNo solo se trata de asegurar un futuro ejercicio de gobierno en el que la generación de riqueza se traduzca por fin en mejoras sustantivas en materias tan elementales como salud, educación y seguridad para toda esa enorme porción de la población que desde Lima y otros lugares de la costa no se está mirando, sino de ofrecer una representación política atenta, comprometida y cercana. Únicamente de esa forma se conseguirá que esos compatriotas miren y aprecien también los hitos del avance logrado hasta ahora, y que el progreso pacífi ...
#  'La prensa ha jugado un papel importantísimo en los últimos años no solo porque ha mantenido a la ciudadanía informada en tiempos en los que las crisis políticas han sido una constante, sino también porque ha sido clave para el destape de múltiples casos de corrupción y para hacer que los políticos y funcionarios involucrados rindan cuentas por los actos que se les imputa. Así, la libertad de expresión y el ejercicio sin restricciones del periodismo independiente son ingredientes claves en el sistema democrático y cualquier intento por socavarlos debería ser visto con preocupación y alarma.\n\nY esto es precisamente lo que los candidatos elegidos para disputar el balotaje de junio, Keiko Fujimori y Pedro Castillo, deberían generarnos, aunque por diferentes razones y en distintas escalas.\n\nEn lo concerniente a la señora Fujimori, basta con remitirse a la conducta de su bancada parlamentaria entre los años 2016 y 2019 para saber que no siempre ha sido afín al trabajo de los medios de comunicación. Como se recuerda, sus congresistas estuvieron entre los principales defensores de la llamada ‘ley Mulder’, que buscaba prohibir la publicidad estatal en diarios, radio y televisión. Aunque esta norma fue declarada inconstitucional por el Tribunal Constitucional, quedó el sinsabor de aquello que la motivó: la animosidad a la prensa por parte de algunos legisladores. Al mismo tiempo, fue desde su agrupación que las parlamentarias Úrsula Letona y Alejandra Aramayo promovieron una norma para regular a los medios.\n\nPero si los antecedentes de Keiko Fujimori dejan mucho que desear en este aspecto, el plan de gobierno presentado por Pedro Castillo ante el Jurado Nacional de Elecciones deja poco espacio para las dudas. Sus intenciones de establecer rígidos controles a los contenidos de los medios de comunicación están nítidamente descritas en el texto, y se sustentan en elucubraciones carentes de evidencia y en conjeturas abiertamente ideologizadas.\n\nEn el campo de la publicidad estatal en medios privados, por ejemplo, el documento en cuestión plantea posiciones similares a las de otros candidatos, pero tanto o más preocupantes. Según dice, este tipo de auspicio es un “soborno encubierto para mantener el sistema sobre el cual se asienta el gobierno”, un discurso socorrido fácilmente contradicho por el hecho de que, para la mayoría de los medios, este tipo de ingresos solo constituyen una parte pequeña de todos los que reciben. Asimismo, el retiro o continuación de estos anuncios pagados no puede determinarse por el capricho de un gobernante, sino a partir de las necesidades comunicacionales del Estado.\n\n“El socialismo no aboga por la libertad de prensa, sino por la prensa comprometida con la educación y la cohesión de su pueblo”, señala en otro punto. Una posición cuyos alcances se hacen explícitos cuando se refiere a establecer una censura previa, encabezada por los ministerios de Educación y de Cultura, a los contenidos de la radio y la televisión, para atajar lo que consideran “basura”. En otras palabras, poner al gato de despensero. Al fin y al cabo, ¿qué son los contenidos “basura”? ¿Qué entrañan precisamente la “moral y las buenas costumbres de la sociedad peruana” que el plan de gobierno se propone salvaguardar? ¿Qué garantiza que esto no sea una herramienta para amordazar los contenidos incómodos para el Ejecutivo? Absolutamente nada y supone una peligrosa puerta que ningún demócrata debería abrir.\n\nA esto se añaden las falsedades que el texto lanza contra este medio y elementos como la obligatoriedad del título de periodista para ejercer la profesión y la animosidad expresa contra instituciones como la Sociedad Interamericana de Prensa, que en más de una ocasión ha velado por la libertad de prensa en países como Venezuela. Además, cita a Vladimir Lenin, Fidel Castro y Rafael Correa como referentes ejemplares en el tópico, cuando son todo lo contrario…\n\nDicho todo esto, será importante que los ciudadanos sean cuidadosos a  ...

# %%
import numpy as np
import pandas as pd

# Crear un DataFrame a partir de la lista de textos
df_textos = pd.DataFrame(textos, columns=['texto'])

# Utilizar la función de split y luego concatenar usando numpy
seriepalabras = pd.Series(np.concatenate(df_textos['texto'].str.split()))
seriepalabras
# Out:
# 0               La
# 1          segunda
# 2           vuelta
# 3               no
# 4               es
#            ...
# 13233          Sin
# 13234    controles
# 13235            y
# 13236          sin
# 13237    mordazas.
# Length: 13238, dtype: object

# %%
# punctuation
import string
PUNCs=string.punctuation # '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'
seriepalabras=seriepalabras.str.replace('['+PUNCs+']', '',regex=True)

# all to lower case
seriepalabras=seriepalabras.str.lower()
seriepalabras
# Out:
# 0               la
# 1          segunda
# 2           vuelta
# 3               no
# 4               es
#            ...
# 13233          sin
# 13234    controles
# 13235            y
# 13236          sin
# 13237     mordazas
# Length: 13238, dtype: object

# %%
seriepalabras.value_counts()
# Out:
# de             824
# la             546
# que            514
# en             394
# el             385
#               ...
# collao           1
# puno             1
# congresista      1
# edgar            1
# 2000             1
# Name: count, Length: 3469, dtype: int64

# %%
import nltk
nltk.download('stopwords')

from nltk.corpus import stopwords
spanish_stopwords = stopwords.words('spanish')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/codespace/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import pandas as pd

# Supongamos que seriepalabras es una serie con todas las palabras de los textos
# y necesitamos filtrar las stopwords
seriepalabras = seriepalabras[~seriepalabras.isin(spanish_stopwords)].reset_index(drop=True)
seriepalabras
# Out:
# 0            segunda
# 1             vuelta
# 2            proceso
# 3       definiciones
# 4          políticas
#             ...
# 6677           turno
# 6678           clave
# 6679            ello
# 6680       controles
# 6681        mordazas
# Length: 6682, dtype: object

# %%
seriepalabras.value_counts()
# Out:
# castillo       54
# perú           43
# ser            33
# si             32
# solo           30
#                ..
# alcances        1
# explícitos      1
# socorrido       1
# fácilmente      1
# contradicho     1
# Name: count, Length: 3317, dtype: int64

# %%
EC_12abril_2mayo=seriepalabras.value_counts()[seriepalabras.value_counts()>10]
EC_12abril_2mayo
# Out:
# castillo     54
# perú         43
# ser          33
# si           32
# solo         30
#              ..
# mientras     11
# menos        11
# años         11
# hacer        11
# electoral    11
# Name: count, Length: 75, dtype: int64

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

EC_wc = WordCloud(background_color='white')
EC_wc.generate_from_frequencies(frequencies=EC_12abril_2mayo.to_dict())
plt.figure()
plt.imshow(EC_wc, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
df_textos
# Out:
#                                                 texto
# 0   La segunda vuelta no es un proceso de definici...
# 1   En la peor de las condiciones posibles, con un...
# 2   Con las tensiones de segunda vuelta al alza mi...
# 3   En abril, un peruano ha muerto cada cinco minu...
# 4   Si en algún momento había que decir que la pan...
# 5   El principal propósito del sistema del balotaj...
# 6   Sería un esfuerzo fútil y hasta avezado el int...
# 7   Luego de que encabezó una larga y violenta hue...
# 8   Ante las dudas de si el candidato Pedro Castil...
# 9   En los últimos días, diversos representantes d...
# 10  Cada vez que se avecina un proceso electoral, ...
# 11  Si bien el conteo de votos para el Congreso to...
# 12  Después de idas y venidas, ayer por fin se con...
# 13  Hasta ahora, la oferta electoral de Pedro Cast...
# 14  Sea quien sea elegido presidente del Perú, Ped...
# 15  El más reciente reporte de la ONPE sobre las a...
# 16  Desde este espacio nos hemos mostrado particul...
# 17  Durante el año pasado, la atención del país es...
# 18  No ha existido proceso de segunda vuelta en nu...
# 19  Decir, como se dice estos días, que el resulta...
# 20  La prensa ha jugado un papel importantísimo en...

# %%
type(seriepalabras)
# Out:
# pandas.core.series.Series

# %%
type(df_textos)
# Out:
# pandas.core.frame.DataFrame

# %%
# Convertir todo el texto en la columna 'texto' a minúsculas
df_textos['texto'] = df_textos['texto'].str.lower()

# Reemplazar los caracteres de puntuación en la columna 'texto'
df_textos['texto'] = df_textos['texto'].str.replace('[' + PUNCs + ']', '', regex=True)

# %%
from nltk import bigrams

theBigrams_EC=[bigrams(eachTW.split()) for eachTW in df_textos['texto']]


# list of all bigrams
from itertools import chain

pairWords_EC = list(chain(*theBigrams_EC))

pairWords_EC
# Out:
# [('la', 'segunda'),
#  ('segunda', 'vuelta'),
#  ('vuelta', 'no'),
#  ('no', 'es'),
#  ('es', 'un'),
#  ('un', 'proceso'),
#  ('proceso', 'de'),
#  ('de', 'definiciones'),
#  ('definiciones', 'políticas'),
#  ('políticas', 'que'),
#  ('que', 'compromete'),
#  ('compromete', 'solo'),
#  ('solo', 'a'),
#  ('a', 'los'),
#  ('los', 'dos'),
#  ('dos', 'candidatos'),
#  ('candidatos', 'que'),
#  ('que', 'continúan'),
#  ('continúan', 'compitiendo'),
#  ('compitiendo', 'por'),
#  ('por', 'acceder'),
#  ('acceder', 'a'),
#  ('a', 'la'),
#  ('la', 'presidencia'),
#  ('presidencia', 'o'),
#  ('o', 'a'),
#  ('a', 'sus'),
#  ('sus', 'partidos'),
#  ('partidos', 'también'),
#  ('también', 'los'),
#  ('los', 'postulantes'),
#  ('postulantes', 'que'),
#  ('que', 'quedaron'),
#  ('quedaron', 'fuera'),
#  ('fuera', 'de'),
#  ('de', 'carrera'),
#  ('carrera', 'tras'),
#  ('tras', 'la'),
#  ('la', 'votación'),
#  ('votación', 'del'),
#  ('del', '11'),
#  ('11', 'de'),
#  ('de', 'abril'),
#  ('abril', 'tienen'),
#  ('tienen', 'responsabilidades'),
#  ('responsabilidades', 'que'),
#  ('que', 'no'),
#  ('no', 'deberían'),
#  ('deberían', 'eludir'),
#  ('eludir', 'en'),
#  ('en', 'la'),
#  ('la', 'medida'),
#  ('medida', 'en'),
#  ('en', 'que'),
#  ('que', 'representaron'),
#  ('representaron', 'a'),
#  ('a', 'determinados'),
#  ('determinados', 'sectores'),
#  ('sectores', 'ciudadanos'),
#  ('ciudadanos', 'en'),
#  ('en', 'la'),
#  ('la', 'primera'),
#  ('primera', 'etapa'),
#  ('etapa', 'de'),
#  ('de', 'la'),
#  ('la', 'contienda'),
#  ('contienda', 'les'),
#  ('les', 'corresponde'),
#  ('corresponde', 'efectivamente'),
#  ('efectivamente', 'velar'),
#  ('velar', 'por'),
#  ('por', 'lo'),
#  ('lo', 'que'),
#  ('que', 'suceda'),
#  ('suceda', 'con'),
#  ('con', 'los'),
#  ('los', 'intereses'),
#  ('intereses', 'y'),
#  ('y', 'valores'),
#  ('valores', 'de'),
#  ('de', 'tales'),
#  ('tales', 'sectores'),
#  ('sectores', 'en'),
#  ('en', 'la'),
#  ('la', 'segunda'),
#  ('segunda', 'algunos'),
#  ('algunos', 'de'),
#  ('de', 'ellos'),
#  ('ellos', 'sin'),
#  ('sin', 'embargo'),
#  ('embargo', 'dolidos'),
#  ('dolidos', 'por'),
#  ('por', 'las'),
#  ('las', 'noticias'),
#  ('noticias', 'que'),
#  ('que', 'les'),
#  ('les', 'trajo'),
#  ('trajo', 'el'),
#  ('el', 'conteo'),
#  ('conteo', 'de'),
#  ('de', 'votos'),
#  ('votos', 'o'),
#  ('o', 'temerosos'),
#  ('temerosos', 'de'),
#  ('de', 'perjudicarse'),
#  ('perjudicarse', 'si'),
#  ('si', 'se'),
#  ('se', 'involucran'),
#  ('involucran', 'demasiado'),
#  ('demasiado', 'en'),
#  ('en', 'el'),
#  ('el', 'respaldo'),
#  ('respaldo', 'o'),
#  ('o', 'rechazo'),
#  ('rechazo', 'a'),
#  ('a', 'las'),
#  ('las', 'posiciones'),
#  ('posiciones', 'de'),
#  ('de', 'los'),
#  ('los', 'dos'),
#  ('dos', 'aspirantes'),
#  ('aspirantes', 'todavía'),
#  ('todavía', 'en'),
#  ('en', 'liza'),
#  ('liza', 'prefieren'),
#  ('prefieren', 'ignorar'),
#  ('ignorar', 'las'),
#  ('las', 'demandas'),
#  ('demandas', 'que'),
#  ('que', 'la'),
#  ('la', 'situación'),
#  ('situación', 'les'),
#  ('les', 'plantea'),
#  ('plantea', 'no'),
#  ('no', 'se'),
#  ('se', 'trata'),
#  ('trata', 'por'),
#  ('por', 'cierto'),
#  ('cierto', 'de'),
#  ('de', 'que'),
#  ('que', 'forzosamente'),
#  ('forzosamente', 'endosen'),
#  ('endosen', 'una'),
#  ('una', 'candidatura'),
#  ('candidatura', 'o'),
#  ('o', 'la'),
#  ('la', 'otra'),
#  ('otra', 'sino'),
#  ('sino', 'de'),
#  ('de', 'que'),
#  ('que', 'señalen'),
#  ('señalen', 'los'),
#  ('los', 'riesgos'),
#  ('riesgos', 'que'),
#  ('que', 'cada'),
#  ('cada', 'una'),
#  ('una', 'de'),
#  ('de', 'ellas'),
#  ('ellas', 'entraña'),
#  ('entraña', 'para'),
#  ('para', 'orientar'),
#  ('orientar', 'de'),
#  ('de', 'esa'),
#  ('esa', 'manera'),
#  ('manera', 'a'),
#  ('a', 'quienes'),
#  ('quienes', 'confiaron'),
#  ('confiaron', 'en'),
#  ('en', 'ellos'),
#  ('ellos', 'en'),
#  ('en', 'la'),
#  ('la', 'primera'),
#  ('primera', 'vuelta'),
#  ('vuelta', 'en'),
#  ('en', 'eso'),
#  ('eso', 'consiste'),
#  ('consiste', 'precisamente'),
#  ('precisamente', 'la'),
#  ('la', 'tarea'),
#  ('tarea', 'de'),
#  ('de', 'un'),
#  ('un', 'líder'),
#  ('líder', 'político'),
#  ('político', 'en'),
#  ('en', 'liderar'),
#  ('liderar', 'en'),
#  ('en', 'ese'),
#  ('ese', 'sentido'),
#  ('sentido', 'el'),
#  ('el', 'eventual'),
#  ('eventual', 'respaldo'),
#  ('respaldo', 'a'),
#  ('a', 'una'),
#  ('una', 'de'),
#  ('de', 'las'),
#  ('las', 'dos'),
#  ('dos', 'opciones'),
#  ('opciones', 'en'),
#  ('en', 'disputa'),
#  ('disputa', 'debería'),
#  ('debería', 'ser'),
#  ('ser', 'para'),
#  ('para', 'los'),
#  ('los', 'excandidatos'),
#  ('excandidatos', 'un'),
#  ('un', 'corolario'),
#  ('corolario', 'y'),
#  ('y', 'no'),
#  ('no', 'una'),
#  ('una', 'premisa'),
#  ('premisa', 'lamentablemente'),
#  ('lamentablemente', 'lo'),
#  ('lo', 'que'),
#  ('que', 'estamos'),
#  ('estamos', 'viendo'),
#  ('viendo', 'en'),
#  ('en', 'una'),
#  ('una', 'mayoría'),
#  ('mayoría', 'de'),
#  ('de', 'casos'),
#  ('casos', 'no'),
#  ('no', 'se'),
#  ('se', 'ajusta'),
#  ('ajusta', 'a'),
#  ('a', 'esa'),
#  ('esa', 'descripción'),
#  ('descripción', 'o'),
#  ('o', 'bien'),
#  ('bien', 'el'),
#  ('el', 'endose'),
#  ('endose', 'se'),
#  ('se', 'ha'),
#  ('ha', 'producido'),
#  ('producido', 'de'),
#  ('de', 'manera'),
#  ('manera', 'sumaria'),
#  ('sumaria', 'y'),
#  ('y', 'sin'),
#  ('sin', 'acompañarlo'),
#  ('acompañarlo', 'luego'),
#  ('luego', 'de'),
#  ('de', 'una'),
#  ('una', 'crítica'),
#  ('crítica', 'a'),
#  ('a', 'los'),
#  ('los', 'asuntos'),
#  ('asuntos', 'en'),
#  ('en', 'los'),
#  ('los', 'que'),
#  ('que', 'los'),
#  ('los', 'votantes'),
#  ('votantes', 'del'),
#  ('del', 'expostulante'),
#  ('expostulante', 'que'),
#  ('que', 'lo'),
#  ('lo', 'ha'),
#  ('ha', 'otorgado'),
#  ('otorgado', 'podrían'),
#  ('podrían', 'sentirse'),
#  ('sentirse', 'defraudados'),
#  ('defraudados', 'o'),
#  ('o', 'bien'),
#  ('bien', 'la'),
#  ('la', 'imposibilidad'),
#  ('imposibilidad', 'de'),
#  ('de', 'renunciar'),
#  ('renunciar', 'al'),
#  ('al', 'protagonismo'),
#  ('protagonismo', 'alcanzado'),
#  ('alcanzado', 'en'),
#  ('en', 'la'),
#  ('la', 'primera'),
#  ('primera', 'parte'),
#  ('parte', 'de'),
#  ('de', 'la'),
#  ('la', 'campaña'),
#  ('campaña', 'se'),
#  ('se', 'convierte'),
#  ('convierte', 'en'),
#  ('en', 'un'),
#  ('un', 'obstáculo'),
#  ('obstáculo', 'para'),
#  ('para', 'que'),
#  ('que', 'el'),
#  ('el', 'expostulante'),
#  ('expostulante', 'ejerza'),
#  ('ejerza', 'eficazmente'),
#  ('eficazmente', 'la'),
#  ('la', 'crítica'),
#  ('crítica', 'o'),
#  ('o', 'el'),
#  ('el', 'apoyo'),
#  ('apoyo', 'según'),
#  ('según', 'dicte'),
#  ('dicte', 'la'),
#  ('la', 'coherencia'),
#  ('coherencia', 'con'),
#  ('con', 'las'),
#  ('las', 'líneas'),
#  ('líneas', 'generales'),
#  ('generales', 'de'),
#  ('de', 'lo'),
#  ('lo', 'que'),
#  ('que', 'le'),
#  ('le', 'ofreció'),
#  ('ofreció', 'al'),
#  ('al', 'país'),
#  ('país', 'mientras'),
#  ('mientras', 'era'),
#  ('era', 'uno'),
#  ('uno', 'de'),
#  ('de', 'los'),
#  ('los', 'participantes'),
#  ('participantes', 'del'),
#  ('del', 'proceso'),
#  ('proceso', 'verónika'),
#  ('verónika', 'mendoza'),
#  ('mendoza', 'es'),
#  ('es', 'de'),
#  ('de', 'hecho'),
#  ('hecho', 'un'),
#  ('un', 'buen'),
#  ('buen', 'ejemplo'),
#  ('ejemplo', 'de'),
#  ('de', 'lo'),
#  ('lo', 'primero'),
#  ('primero', 'mientras'),
#  ('mientras', 'que'),
#  ('que', 'hernando'),
#  ('hernando', 'de'),
#  ('de', 'soto'),
#  ('soto', 'lo'),
#  ('lo', 'es'),
#  ('es', 'de'),
#  ('de', 'lo'),
#  ('lo', 'segundo'),
#  ('segundo', 'la'),
#  ('la', 'excandidata'),
#  ('excandidata', 'presidencial'),
#  ('presidencial', 'de'),
#  ('de', 'juntos'),
#  ('juntos', 'por'),
#  ('por', 'el'),
#  ('el', 'perú'),
#  ('perú', 'como'),
#  ('como', 'se'),
#  ('se', 'sabe'),
#  ('sabe', 'anunció'),
#  ('anunció', 'muy'),
#  ('muy', 'rápidamente'),
#  ('rápidamente', 'que'),
#  ('que', 'ella'),
#  ('ella', 'y'),
#  ('y', 'la'),
#  ('la', 'organización'),
#  ('organización', 'política'),
#  ('política', 'que'),
#  ('que', 'la'),
#  ('la', 'postuló'),
#  ('postuló', 'apoyarán'),
#  ('apoyarán', 'en'),
#  ('en', 'esta'),
#  ('esta', 'segunda'),
#  ('segunda', 'vuelta'),
#  ('vuelta', 'a'),
#  ('a', 'pedro'),
#  ('pedro', 'castillo'),
#  ('castillo', 'una'),
#  ('una', 'consecuencia'),
#  ('consecuencia', 'previsible'),
#  ('previsible', 'de'),
#  ('de', 'la'),
#  ('la', 'sintonía'),
#  ('sintonía', 'que'),
#  ('que', 'guarda'),
#  ('guarda', 'con'),
#  ('con', 'los'),
#  ('los', 'planes'),
#  ('planes', 'estatistas'),
#  ('estatistas', 'de'),
#  ('de', 'perú'),
#  ('perú', 'libre'),
#  ('libre', 'y'),
#  ('y', 'su'),
#  ('su', 'simpatía'),
#  ('simpatía', 'por'),
#  ('por', 'los'),
#  ('los', 'regímenes'),
#  ('regímenes', 'totalitarios'),
#  ('totalitarios', 'del'),
#  ('del', 'continente'),
#  ('continente', 'frente'),
#  ('frente', 'a'),
#  ('a', 'los'),
#  ('los', 'anuncios'),
#  ('anuncios', 'de'),
#  ('de', '“desactivación”'),
#  ('“desactivación”', 'de'),
#  ('de', 'la'),
#  ('la', 'defensoría'),
#  ('defensoría', 'del'),
#  ('del', 'pueblo'),
#  ('pueblo', 'o'),
#  ('o', 'la'),
#  ('la', 'atu'),
#  ('atu', 'o'),
#  ('o', 'de'),
#  ('de', 'intervención'),
#  ('intervención', 'en'),
#  ('en', 'la'),
#  ('la', 'labor'),
#  ('labor', 'que'),
#  ('que', 'viene'),
#  ('viene', 'llevando'),
#  ('llevando', 'adelante'),
#  ('adelante', 'la'),
#  ('la', 'sunedu'),
#  ('sunedu', 'no'),
#  ('no', 'obstante'),
#  ('obstante', 'verónika'),
#  ('verónika', 'mendoza'),
#  ('mendoza', 'no'),
#  ('no', 'ha'),
#  ('ha', 'dicho'),
#  ('dicho', 'nada'),
#  ('nada', '¿debemos'),
#  ('¿debemos', 'entender'),
#  ('entender', 'que'),
#  ('que', 'está'),
#  ('está', 'conforme'),
#  ('conforme', 'con'),
#  ('con', 'los'),
#  ('los', 'planes'),
#  ('planes', 'de'),
#  ('de', 'castillo'),
#  ('castillo', 'al'),
#  ('al', 'respecto'),
#  ('respecto', 'o'),
#  ('o', 'que'),
#  ('que', 'sencillamente'),
#  ('sencillamente', 'prefiere'),
#  ('prefiere', 'callar'),
#  ('callar', 'para'),
#  ('para', 'no'),
#  ('no', 'afectar'),
#  ('afectar', 'las'),
#  ('las', 'chances'),
#  ('chances', 'de'),
#  ('de', 'la'),
#  ('la', 'izquierda'),
#  ('izquierda', 'el'),
#  ('el', '6'),
#  ('6', 'de'),
#  ('de', 'junio'),
#  ('junio', 'hernando'),
#  ('hernando', 'de'),
#  ('de', 'soto'),
#  ('soto', 'por'),
#  ('por', 'otro'),
#  ('otro', 'lado'),
#  ('lado', 'luce'),
#  ('luce', 'más'),
#  ('más', 'interesado'),
#  ('interesado', 'en'),
#  ('en', 'tener'),
#  ('tener', 'un'),
#  ('un', 'rol'),
#  ('rol', 'estelar'),
#  ('estelar', 'en'),
#  ('en', 'la'),
#  ('la', 'segunda'),
#  ('segunda', 'vuelta'),
#  ('vuelta', 'que'),
#  ('que', 'en'),
#  ('en', 'ayudar'),
#  ('ayudar', 'a'),
#  ('a', 'sus'),
#  ('sus', 'antiguos'),
#  ('antiguos', 'adherentes'),
#  ('adherentes', 'a'),
#  ('a', 'decidir'),
#  ('decidir', 'qué'),
#  ('qué', 'hacer'),
#  ('hacer', 'ahora'),
#  ('ahora', 'con'),
#  ('con', 'su'),
#  ('su', 'voto'),
#  ('voto', '“estoy'),
#  ('“estoy', 'proponiendo'),
#  ('proponiendo', 'a'),
#  ('a', 'la'),
#  ('la', 'candidata'),
#  ('candidata', 'fujimori'),
#  ('fujimori', 'una'),
#  ('una', 'fórmula'),
#  ('fórmula', 'para'),
#  ('para', 'que'),
#  ('que', 'su'),
#  ('su', 'propuesta'),
#  ('propuesta', 'sea'),
#  ('sea', 'inclusiva'),
#  ('inclusiva', 'y'),
#  ('y', 'no'),
#  ('no', 'mercantilista'),
#  ('mercantilista', 'y'),
#  ('y', 'al'),
#  ('al', 'candidato'),
#  ('candidato', 'castillo'),
#  ('castillo', 'otra'),
#  ('otra', 'fórmula'),
#  ('fórmula', 'para'),
#  ('para', 'que'),
#  ('que', 'no'),
#  ('no', 'se'),
#  ('se', 'politice'),
#  ('politice', 'la'),
#  ('la', 'economía'),
#  ('economía', 'dentro'),
#  ('dentro', 'de'),
#  ('de', 'un'),
#  ('un', 'régimen'),
#  ('régimen', 'comunista”'),
#  ('comunista”', 'ha'),
#  ('ha', 'escrito'),
#  ('escrito', 'en'),
#  ('en', 'un'),
#  ('un', 'comunicado'),
#  ('comunicado', 'divulgado'),
#  ('divulgado', 'ayer'),
#  ('ayer', '¿debemos'),
#  ('¿debemos', 'entender'),
#  ('entender', 'acaso'),
#  ('acaso', 'que'),
#  ('que', 'solo'),
#  ('solo', 'el'),
#  ('el', 'que'),
#  ('que', 'le'),
#  ('le', 'dé'),
#  ('dé', 'la'),
#  ('la', 'razón'),
#  ('razón', 'obtendrá'),
#  ('obtendrá', 'la'),
#  ('la', 'gracia'),
#  ('gracia', 'de'),
#  ('de', 'su'),
#  ('su', 'voto'),
#  ('voto', 'en'),
#  ('en', 'los'),
#  ('los', 'predios'),
#  ('predios', 'de'),
#  ('de', 'avanza'),
#  ('avanza', 'país'),
#  ('país', 'mientras'),
#  ('mientras', 'tanto'),
#  ('tanto', 'parece'),
#  ('parece', 'existir'),
#  ('existir', 'la'),
#  ('la', 'impresión'),
#  ('impresión', 'de'),
#  ('de', 'que'),
#  ('que', 'las'),
#  ('las', 'urgencias'),
#  ('urgencias', 'son'),
#  ('son', 'otras'),
#  ('otras', 'pues'),
#  ('pues', 'la'),
#  ('la', 'mayoría'),
#  ('mayoría', 'de'),
#  ('de', 'los'),
#  ('los', 'congresistas'),
#  ('congresistas', 'elegidos'),
#  ('elegidos', 'en'),
#  ('en', 'sus'),
#  ('sus', 'listas'),
#  ('listas', 'ya'),
#  ('ya', 'anunció'),
#  ('anunció', 'que'),
#  ('que', 'votará'),
#  ('votará', '“contra'),
#  ('“contra', 'el'),
#  ('el', 'comunismo”'),
#  ('comunismo”', 'y'),
#  ('y', 'el'),
#  ('el', 'canciller'),
#  ('canciller', 'francisco'),
#  ('francisco', 'tudela'),
#  ('tudela', 'hasta'),
#  ('hasta', 'hace'),
#  ('hace', 'poco'),
#  ('poco', 'miembro'),
#  ('miembro', 'de'),
#  ('de', 'su'),
#  ('su', '“gabinete'),
#  ('“gabinete', 'en'),
#  ('en', 'la'),
#  ('la', 'sombra”'),
#  ('sombra”', 'se'),
#  ('se', 'ha'),
#  ('ha', 'alejado'),
#  ('alejado', 'del'),
#  ('del', 'proyecto'),
#  ('proyecto', 'político'),
#  ('político', 'conjunto'),
#  ('conjunto', 'argumentando'),
#  ('argumentando', 'que'),
#  ('que', '“en'),
#  ('“en', 'esta'),
#  ('esta', 'hora'),
#  ('hora', 'decisiva'),
#  ('decisiva', 'no'),
#  ('no', 'se'),
#  ('se', 'puede'),
#  ('puede', 'ser'),
#  ('ser', 'indeciso'),
#  ('indeciso', 'o'),
#  ('o', 'esperar'),
#  ('esperar', 'a'),
#  ('a', 'ver'),
#  ('ver', 'quién'),
#  ('quién', 'gana”'),
#  ('gana”', 'una'),
#  ('una', 'severa'),
#  ('severa', 'llamada'),
#  ('llamada', 'de'),
#  ('de', 'atención'),
#  ('atención', 'en'),
#  ('en', 'fin'),
#  ('fin', 'para'),
#  ('para', 'quien'),
#  ('quien', 'al'),
#  ('al', 'igual'),
#  ('igual', 'que'),
#  ('que', 'la'),
#  ('la', 'señora'),
#  ('señora', 'mendoza'),
#  ('mendoza', 'parecería'),
#  ('parecería', 'estar'),
#  ('estar', 'dispuesto'),
#  ('dispuesto', 'a'),
#  ('a', 'actuar'),
#  ('actuar', 'como'),
#  ('como', 'un'),
#  ('un', 'convidado'),
#  ('convidado', 'de'),
#  ('de', 'piedra'),
#  ('piedra', 'en'),
#  ('en', 'esta'),
#  ('esta', 'segunda'),
#  ('segunda', 'vuelta…'),
#  ('vuelta…', 'a'),
#  ('a', 'menos'),
#  ('menos', 'que'),
#  ('que', 'le'),
#  ('le', 'concedan'),
#  ('concedan', 'el'),
#  ('el', 'centro'),
#  ('centro', 'del'),
#  ('del', 'escenario'),
#  ('escenario', 'todo'),
#  ('todo', 'indica'),
#  ('indica', 'que'),
#  ('que', 'el'),
#  ('el', 'desencanto'),
#  ('desencanto', 'de'),
#  ('de', 'los'),
#  ('los', 'ciudadanos'),
#  ('ciudadanos', 'con'),
#  ('con', 'sus'),
#  ('sus', 'líderes'),
#  ('líderes', 'políticos'),
#  ('políticos', 'tiene'),
#  ('tiene', 'una'),
#  ('una', 'explicación'),
#  ('explicación', 'fácil'),
#  ('fácil', 'pero'),
#  ('pero', 'una'),
#  ('una', 'difícil'),
#  ('difícil', 'solución'),
#  ('en', 'la'),
#  ('la', 'peor'),
#  ('peor', 'de'),
#  ('de', 'las'),
#  ('las', 'condiciones'),
#  ('condiciones', 'posibles'),
#  ('posibles', 'con'),
#  ('con', 'una'),
#  ('una', 'pandemia'),
#  ('pandemia', 'que'),
#  ('que', 'dificulta'),
#  ('dificulta', 'el'),
#  ('el', 'contacto'),
#  ('contacto', 'entre'),
#  ('entre', 'las'),
#  ('las', 'personas'),
#  ('personas', 'los'),
#  ('los', 'peruanos'),
#  ('peruanos', 'acudimos'),
#  ('acudimos', 'ayer'),
#  ('ayer', 'a'),
#  ('a', 'las'),
#  ('las', 'urnas'),
#  ('urnas', 'para'),
#  ('para', 'ejercer'),
#  ('ejercer', 'el'),
#  ('el', 'más'),
#  ('más', 'fundamental'),
#  ('fundamental', 'de'),
#  ('de', 'nuestros'),
#  ('nuestros', 'derechos'),
#  ('derechos', 'democráticos'),
#  ('democráticos', 'elegir'),
#  ('elegir', 'a'),
#  ('a', 'quienes'),
#  ('quienes', 'liderarán'),
#  ('liderarán', 'nuestro'),
#  ('nuestro', 'futuro'),
#  ('futuro', 'por'),
#  ('por', 'cinco'),
#  ('cinco', 'años'),
#  ('años', 'la'),
#  ('la', 'jornada'),
#  ('jornada', 'empezó'),
#  ('empezó', 'de'),
#  ('de', 'manera'),
#  ('manera', 'accidentada'),
#  ('accidentada', 'particularmente'),
#  ('particularmente', 'en'),
#  ('en', 'lima'),
#  ('lima', 'donde'),
#  ('donde', 'múltiples'),
#  ('múltiples', 'mesas'),
#  ('mesas', 'demoraron'),
#  ('demoraron', 'en'),
#  ('en', 'abrirse'),
#  ('abrirse', 'por'),
#  ('por', 'la'),
#  ('la', 'ausencia'),
#  ('ausencia', 'de'),
#  ('de', 'sus'),
#  ('sus', 'miembros'),
#  ('miembros', 'y'),
#  ('y', 'con'),
#  ('con', 'largas'),
#  ('largas', 'colas'),
#  ('colas', 'formándose'),
#  ('formándose', 'en'),
#  ('en', 'el'),
#  ('el', 'exterior'),
#  ('exterior', 'de'),
#  ('de', 'los'),
#  ('los', 'locales'),
#  ('locales', 'de'),
#  ('de', 'sufragio'),
#  ('sufragio', 'aun'),
#  ('aun', 'así'),
#  ('así', 'para'),
#  ('para', 'alrededor'),
#  ('alrededor', 'de'),
#  ('de', 'las'),
#  ('las', 'dos'),
#  ('dos', 'de'),
#  ('de', 'la'),
#  ('la', 'tarde'),
#  ('tarde', 'el'),
#  ('el', '996'),
#  ('996', 'de'),
#  ('de', 'las'),
#  ('las', 'mesas'),
#  ('mesas', 'ya'),
#  ('ya', 'se'),
#  ('se', 'habían'),
#  ('habían', 'instalado'),
#  ('instalado', 'gracias'),
#  ('gracias', 'a'),
#  ('a', 'ciudadanos'),
#  ('ciudadanos', 'que'),
#  ('que', 'se'),
#  ('se', 'ofrecieron'),
#  ('ofrecieron', 'para'),
#  ('para', 'suplir'),
#  ('suplir', 'a'),
#  ('a', 'los'),
#  ('los', 'que'),
#  ('que', 'habían'),
#  ('habían', 'sido'),
#  ('sido', 'asignados'),
#  ('asignados', 'y'),
#  ('y', 'no'),
#  ('no', 'se'),
#  ('se', 'presentaron'),
#  ('presentaron', 'así'),
#  ('así', 'las'),
#  ('las', 'cosas'),
#  ('cosas', 'el'),
#  ('el', 'proceso'),
#  ('proceso', 'fluyó'),
#  ('fluyó', 'de'),
#  ('de', 'forma'),
#  ('forma', 'ordenada'),
#  ('ordenada', 'y'),
#  ('y', 'sin'),
#  ('sin', 'verdaderas'),
#  ('verdaderas', 'sorpresas'),
#  ('sorpresas', 'y'),
#  ('y', 'salvo'),
#  ('salvo', 'por'),
#  ('por', 'algunas'),
#  ('algunas', 'pocas'),
#  ('pocas', 'quejas'),
#  ('quejas', 'cuya'),
#  ('cuya', 'pertinencia'),
#  ('pertinencia', 'tendrá'),
#  ('tendrá', 'que'),
#  ('que', 'ser'),
#  ('ser', 'verificada'),
#  ('verificada', 'ajustado'),
#  ('ajustado', 'a'),
#  ('a', 'la'),
#  ('la', 'asepsia'),
#  ('asepsia', 'que'),
#  ('que', 'todos'),
#  ('todos', 'esperábamos'),
#  ('esperábamos', 'ello'),
#  ('ello', 'no'),
#  ('no', 'evitó'),
#  ('evitó', 'que'),
#  ('que', 'como'),
#  ('como', 'suele'),
#  ('suele', 'ocurrir'),
#  ('ocurrir', 'algunos'),
#  ('algunos', 'candidatos'),
#  ('candidatos', 'como'),
#  ('como', 'el'),
#  ('el', 'señor'),
#  ('señor', 'rafael'),
#  ('rafael', 'lópez'),
#  ('lópez', 'aliaga'),
#  ('aliaga', 'sugiriesen'),
#  ('sugiriesen', 'la'),
#  ('la', 'existencia'),
#  ('existencia', 'de'),
#  ('de', 'irregularidades'),
#  ('irregularidades', 'en'),
#  ('en', 'su'),
#  ('su', 'contra'),
#  ('contra', 'sin'),
#  ('sin', 'ningún'),
#  ('ningún', 'tipo'),
#  ('tipo', 'de'),
#  ('de', 'evidencia'),
#  ('evidencia', 'para'),
#  ('para', 'sustentarlo'),
#  ('sustentarlo', 'los'),
#  ('los', 'verdaderos'),
#  ('verdaderos', 'sobresaltos'),
#  ('sobresaltos', 'recién'),
#  ('recién', 'llegaron'),
#  ('llegaron', 'por'),
#  ('por', 'la'),
#  ('la', 'noche'),
#  ('noche', 'cuando'),
#  ('cuando', 'los'),
#  ('los', 'noticieros'),
#  ('noticieros', 'dieron'),
#  ('dieron', 'a'),
#  ('a', 'conocer'),
#  ('conocer', 'primero'),
#  ('primero', 'el'),
#  ('el', 'flash'),
#  ('flash', 'electoral'),
#  ('electoral', 'a'),
#  ('a', 'boca'),
#  ('boca', 'de'),
#  ('de', 'urna'),
#  ('urna', 'y'),
#  ('y', 'luego'),
#  ('luego', 'el'),
#  ('el', 'conteo'),
#  ('conteo', 'rápido'),
#  ('rápido', 'de'),
#  ('de', 'ipsos'),
#  ('ipsos', 'como'),
#  ('como', 'ya'),
#  ('ya', 'mostraban'),
#  ('mostraban', 'las'),
#  ('las', 'encuestas'),
#  ('encuestas', 'que'),
#  ('que', 'trascendían'),
#  ('trascendían', 'en'),
#  ('en', 'la'),
#  ('la', 'víspera'),
#  ('víspera', 'el'),
#  ('el', 'candidato'),
#  ('candidato', 'de'),
#  ('de', 'perú'),
#  ('perú', 'libre'),
#  ('libre', 'pedro'),
#  ('pedro', 'castillo'),
#  ('castillo', 'consolidó'),
#  ('consolidó', 'su'),
#  ('su', 'ascenso'),
#  ('ascenso', 'y'),
#  ('y', 'habría'),
#  ('habría', 'alcanzado'),
#  ('alcanzado', 'más'),
#  ('más', 'votos'),
#  ('votos', 'que'),
#  ('que', 'cualquier'),
#  ('cualquier', 'otro'),
#  ('otro', 'postulante'),
#  ('postulante', 'colocándose'),
#  ('colocándose', 'en'),
#  ('en', 'el'),
#  ('el', 'primer'),
#  ('primer', 'puesto'),
#  ('puesto', 'con'),
#  ('con', '181'),
#  ('181', 'del'),
#  ('del', 'voto'),
#  ('voto', 'al'),
#  ('al', '90'),
#  ('90', 'del'),
#  ('del', 'conteo'),
#  ('conteo', 'según'),
#  ('según', 'la'),
#  ('la', 'referida'),
#  ('referida', 'medición'),
#  ('medición', 'de'),
#  ('de', 'ipsos'),
#  ('ipsos', 'lo'),
#  ('lo', 'siguen'),
#  ('siguen', 'keiko'),
#  ('keiko', 'fujimori'),
#  ('fujimori', 'fuerza'),
#  ('fuerza', 'popular'),
#  ('popular', 'con'),
#  ('con', '144'),
#  ('144', 'y'),
#  ('y', 'rafael'),
#  ('rafael', 'lópez'),
#  ('lópez', 'aliaga'),
#  ('aliaga', 'renovación'),
#  ('renovación', 'popular'),
#  ('popular', 'con'),
#  ('con', '124'),
#  ('124', 'hará'),
#  ('hará', 'falta'),
#  ('falta', 'esperar'),
#  ('esperar', 'los'),
#  ('los', 'resultados'),
#  ('resultados', 'de'),
#  ('de', 'la'),
#  ('la', 'onpe'),
#  ('onpe', 'al'),
#  ('al', '100'),
#  ('100', 'para'),
#  ('para', 'saber'),
#  ('saber', 'el'),
#  ('el', 'cuadro'),
#  ('cuadro', 'final'),
#  ('final', 'de'),
#  ('de', 'candidatos'),
#  ('candidatos', 'tras'),
#  ('tras', 'una'),
#  ('una', 'campaña'),
#  ('campaña', 'marcada'),
#  ('marcada', 'por'),
#  ('por', 'la'),
#  ('la', 'polarización'),
#  ('polarización', '–por'),
#  ('–por', 'la'),
#  ('la', 'presencia'),
#  ('presencia', 'de'),
#  ('de', 'posiciones'),
#  ('posiciones', 'extremas–'),
#  ('extremas–', 'y'),
#  ('y', 'la'),
#  ('la', 'atomización'),
#  ('atomización', '–por'),
#  ('–por', 'lo'),
#  ('lo', 'pequeño'),
#  ('pequeño', 'del'),
#  ('del', 'apoyo'),
#  ('apoyo', 'que'),
#  ('que', 'recibió'),
#  ('recibió', 'cada'),
#  ('cada', 'aspirante'),
#  ('aspirante', 'al'),
#  ('al', 'sillón'),
#  ('sillón', 'de'),
#  ('de', 'pizarro–'),
#  ('pizarro–', 'este'),
#  ('este', 'desenlace'),
#  ('desenlace', 'solo'),
#  ('solo', 'augura'),
#  ('augura', 'aún'),
#  ('aún', 'más'),
#  ('más', 'división'),
#  ('división', 'en'),
#  ('en', 'el'),
#  ...]

# %%
pairWords_EC_clean = [gram for gram in pairWords_EC if not any(stop in gram for stop in spanish_stopwords)]
print(pairWords_EC_clean)
# Out:
# [('segunda', 'vuelta'), ('definiciones', 'políticas'), ('compromete', 'solo'), ('dos', 'candidatos'), ('continúan', 'compitiendo'), ('carrera', 'tras'), ('deberían', 'eludir'), ('determinados', 'sectores'), ('sectores', 'ciudadanos'), ('primera', 'etapa'), ('corresponde', 'efectivamente'), ('efectivamente', 'velar'), ('tales', 'sectores'), ('embargo', 'dolidos'), ('perjudicarse', 'si'), ('involucran', 'demasiado'), ('dos', 'aspirantes'), ('aspirantes', 'todavía'), ('liza', 'prefieren'), ('prefieren', 'ignorar'), ('forzosamente', 'endosen'), ('primera', 'vuelta'), ('consiste', 'precisamente'), ('líder', 'político'), ('eventual', 'respaldo'), ('dos', 'opciones'), ('disputa', 'debería'), ('debería', 'ser'), ('premisa', 'lamentablemente'), ('manera', 'sumaria'), ('acompañarlo', 'luego'), ('otorgado', 'podrían'), ('podrían', 'sentirse'), ('sentirse', 'defraudados'), ('protagonismo', 'alcanzado'), ('primera', 'parte'), ('expostulante', 'ejerza'), ('ejerza', 'eficazmente'), ('apoyo', 'según'), ('según', 'dicte'), ('líneas', 'generales'), ('país', 'mientras'), ('proceso', 'verónika'), ('verónika', 'mendoza'), ('buen', 'ejemplo'), ('primero', 'mientras'), ('excandidata', 'presidencial'), ('sabe', 'anunció'), ('organización', 'política'), ('postuló', 'apoyarán'), ('segunda', 'vuelta'), ('pedro', 'castillo'), ('consecuencia', 'previsible'), ('planes', 'estatistas'), ('perú', 'libre'), ('regímenes', 'totalitarios'), ('continente', 'frente'), ('viene', 'llevando'), ('llevando', 'adelante'), ('obstante', 'verónika'), ('verónika', 'mendoza'), ('¿debemos', 'entender'), ('sencillamente', 'prefiere'), ('prefiere', 'callar'), ('junio', 'hernando'), ('lado', 'luce'), ('rol', 'estelar'), ('segunda', 'vuelta'), ('antiguos', 'adherentes'), ('hacer', 'ahora'), ('voto', '“estoy'), ('“estoy', 'proponiendo'), ('candidata', 'fujimori'), ('candidato', 'castillo'), ('economía', 'dentro'), ('régimen', 'comunista”'), ('comunicado', 'divulgado'), ('divulgado', 'ayer'), ('ayer', '¿debemos'), ('¿debemos', 'entender'), ('entender', 'acaso'), ('razón', 'obtendrá'), ('avanza', 'país'), ('país', 'mientras'), ('parece', 'existir'), ('congresistas', 'elegidos'), ('votará', '“contra'), ('canciller', 'francisco'), ('francisco', 'tudela'), ('proyecto', 'político'), ('político', 'conjunto'), ('conjunto', 'argumentando'), ('hora', 'decisiva'), ('puede', 'ser'), ('ser', 'indeciso'), ('ver', 'quién'), ('quién', 'gana”'), ('severa', 'llamada'), ('señora', 'mendoza'), ('mendoza', 'parecería'), ('segunda', 'vuelta…'), ('líderes', 'políticos'), ('explicación', 'fácil'), ('difícil', 'solución'), ('condiciones', 'posibles'), ('peruanos', 'acudimos'), ('acudimos', 'ayer'), ('derechos', 'democráticos'), ('democráticos', 'elegir'), ('cinco', 'años'), ('jornada', 'empezó'), ('manera', 'accidentada'), ('accidentada', 'particularmente'), ('múltiples', 'mesas'), ('mesas', 'demoraron'), ('largas', 'colas'), ('colas', 'formándose'), ('sufragio', 'aun'), ('aun', 'así'), ('instalado', 'gracias'), ('sido', 'asignados'), ('presentaron', 'así'), ('proceso', 'fluyó'), ('forma', 'ordenada'), ('verdaderas', 'sorpresas'), ('pocas', 'quejas'), ('quejas', 'cuya'), ('cuya', 'pertinencia'), ('ser', 'verificada'), ('verificada', 'ajustado'), ('esperábamos', 'ello'), ('suele', 'ocurrir'), ('señor', 'rafael'), ('rafael', 'lópez'), ('lópez', 'aliaga'), ('aliaga', 'sugiriesen'), ('ningún', 'tipo'), ('verdaderos', 'sobresaltos'), ('sobresaltos', 'recién'), ('recién', 'llegaron'), ('noticieros', 'dieron'), ('conocer', 'primero'), ('flash', 'electoral'), ('conteo', 'rápido'), ('perú', 'libre'), ('libre', 'pedro'), ('pedro', 'castillo'), ('castillo', 'consolidó'), ('postulante', 'colocándose'), ('primer', 'puesto'), ('conteo', 'según'), ('referida', 'medición'), ('siguen', 'keiko'), ('keiko', 'fujimori'), ('fujimori', 'fuerza'), ('fuerza', 'popular'), ('rafael', 'lópez'), ('lópez', 'aliaga'), ('aliaga', 'renovación'), ('renovación', 'popular'), ('124', 'hará'), ('hará', 'falta'), ('falta', 'esperar'), ('cuadro ...

# %%
from collections import Counter

bigramsCount_dict_EC = Counter(pairWords_EC_clean) #generate counter

# Turn bigramsCount_dict  into dataframe, naming columns
bigramsCount_EC = pd.DataFrame(bigramsCount_dict_EC.most_common(),
                        columns=['bigrama', 'peso'])
bigramsCount_EC
# Out:
#                        bigrama  peso
# 0                (perú, libre)    30
# 1            (pedro, castillo)    24
# 2            (segunda, vuelta)    15
# 3            (keiko, fujimori)    13
# 4            (fuerza, popular)    13
# ...                        ...   ...
# 2204            (además, cita)     1
# 2205            (lenin, fidel)     1
# 2206          (rafael, correa)     1
# 2207  (referentes, ejemplares)     1
# 2208       (contrario…, dicho)     1
#
# [2209 rows x 2 columns]

# %%
bigramsCount_EC['palabra 1'], bigramsCount_EC['palabra 2'] = zip(*bigramsCount_EC['bigrama'])
bigramsCount_EC
# Out:
#                        bigrama  peso   palabra 1   palabra 2
# 0                (perú, libre)    30        perú       libre
# 1            (pedro, castillo)    24       pedro    castillo
# 2            (segunda, vuelta)    15     segunda      vuelta
# 3            (keiko, fujimori)    13       keiko    fujimori
# 4            (fuerza, popular)    13      fuerza     popular
# ...                        ...   ...         ...         ...
# 2204            (además, cita)     1      además        cita
# 2205            (lenin, fidel)     1       lenin       fidel
# 2206          (rafael, correa)     1      rafael      correa
# 2207  (referentes, ejemplares)     1  referentes  ejemplares
# 2208       (contrario…, dicho)     1  contrario…       dicho
#
# [2209 rows x 4 columns]

# %%
filtered_bigrams_3 = bigramsCount_EC[bigramsCount_EC['peso'] >= 3]

# %%
import networkx as nx
G_bigram_EC_3=nx.from_pandas_edgelist(df=filtered_bigrams_3, source='palabra 1',target= 'palabra 2',edge_attr= ["peso"])

# %%
# plotting graph (default layout)
nx.draw_networkx(G_bigram_EC_3)

# %% [markdown]
# # Reto: 3-gramas

# %%
import pandas as pd
from nltk.util import ngrams

# 'texto' es la columna de texto
the3grams_EC = [list(ngrams(eachTW.split(), 3)) for eachTW in df_textos['texto']]

# %%
# list of all bigrams
from itertools import chain

triWords_EC = list(chain(*the3grams_EC))

triWords_EC
# Out:
# [('la', 'segunda', 'vuelta'),
#  ('segunda', 'vuelta', 'no'),
#  ('vuelta', 'no', 'es'),
#  ('no', 'es', 'un'),
#  ('es', 'un', 'proceso'),
#  ('un', 'proceso', 'de'),
#  ('proceso', 'de', 'definiciones'),
#  ('de', 'definiciones', 'políticas'),
#  ('definiciones', 'políticas', 'que'),
#  ('políticas', 'que', 'compromete'),
#  ('que', 'compromete', 'solo'),
#  ('compromete', 'solo', 'a'),
#  ('solo', 'a', 'los'),
#  ('a', 'los', 'dos'),
#  ('los', 'dos', 'candidatos'),
#  ('dos', 'candidatos', 'que'),
#  ('candidatos', 'que', 'continúan'),
#  ('que', 'continúan', 'compitiendo'),
#  ('continúan', 'compitiendo', 'por'),
#  ('compitiendo', 'por', 'acceder'),
#  ('por', 'acceder', 'a'),
#  ('acceder', 'a', 'la'),
#  ('a', 'la', 'presidencia'),
#  ('la', 'presidencia', 'o'),
#  ('presidencia', 'o', 'a'),
#  ('o', 'a', 'sus'),
#  ('a', 'sus', 'partidos'),
#  ('sus', 'partidos', 'también'),
#  ('partidos', 'también', 'los'),
#  ('también', 'los', 'postulantes'),
#  ('los', 'postulantes', 'que'),
#  ('postulantes', 'que', 'quedaron'),
#  ('que', 'quedaron', 'fuera'),
#  ('quedaron', 'fuera', 'de'),
#  ('fuera', 'de', 'carrera'),
#  ('de', 'carrera', 'tras'),
#  ('carrera', 'tras', 'la'),
#  ('tras', 'la', 'votación'),
#  ('la', 'votación', 'del'),
#  ('votación', 'del', '11'),
#  ('del', '11', 'de'),
#  ('11', 'de', 'abril'),
#  ('de', 'abril', 'tienen'),
#  ('abril', 'tienen', 'responsabilidades'),
#  ('tienen', 'responsabilidades', 'que'),
#  ('responsabilidades', 'que', 'no'),
#  ('que', 'no', 'deberían'),
#  ('no', 'deberían', 'eludir'),
#  ('deberían', 'eludir', 'en'),
#  ('eludir', 'en', 'la'),
#  ('en', 'la', 'medida'),
#  ('la', 'medida', 'en'),
#  ('medida', 'en', 'que'),
#  ('en', 'que', 'representaron'),
#  ('que', 'representaron', 'a'),
#  ('representaron', 'a', 'determinados'),
#  ('a', 'determinados', 'sectores'),
#  ('determinados', 'sectores', 'ciudadanos'),
#  ('sectores', 'ciudadanos', 'en'),
#  ('ciudadanos', 'en', 'la'),
#  ('en', 'la', 'primera'),
#  ('la', 'primera', 'etapa'),
#  ('primera', 'etapa', 'de'),
#  ('etapa', 'de', 'la'),
#  ('de', 'la', 'contienda'),
#  ('la', 'contienda', 'les'),
#  ('contienda', 'les', 'corresponde'),
#  ('les', 'corresponde', 'efectivamente'),
#  ('corresponde', 'efectivamente', 'velar'),
#  ('efectivamente', 'velar', 'por'),
#  ('velar', 'por', 'lo'),
#  ('por', 'lo', 'que'),
#  ('lo', 'que', 'suceda'),
#  ('que', 'suceda', 'con'),
#  ('suceda', 'con', 'los'),
#  ('con', 'los', 'intereses'),
#  ('los', 'intereses', 'y'),
#  ('intereses', 'y', 'valores'),
#  ('y', 'valores', 'de'),
#  ('valores', 'de', 'tales'),
#  ('de', 'tales', 'sectores'),
#  ('tales', 'sectores', 'en'),
#  ('sectores', 'en', 'la'),
#  ('en', 'la', 'segunda'),
#  ('la', 'segunda', 'algunos'),
#  ('segunda', 'algunos', 'de'),
#  ('algunos', 'de', 'ellos'),
#  ('de', 'ellos', 'sin'),
#  ('ellos', 'sin', 'embargo'),
#  ('sin', 'embargo', 'dolidos'),
#  ('embargo', 'dolidos', 'por'),
#  ('dolidos', 'por', 'las'),
#  ('por', 'las', 'noticias'),
#  ('las', 'noticias', 'que'),
#  ('noticias', 'que', 'les'),
#  ('que', 'les', 'trajo'),
#  ('les', 'trajo', 'el'),
#  ('trajo', 'el', 'conteo'),
#  ('el', 'conteo', 'de'),
#  ('conteo', 'de', 'votos'),
#  ('de', 'votos', 'o'),
#  ('votos', 'o', 'temerosos'),
#  ('o', 'temerosos', 'de'),
#  ('temerosos', 'de', 'perjudicarse'),
#  ('de', 'perjudicarse', 'si'),
#  ('perjudicarse', 'si', 'se'),
#  ('si', 'se', 'involucran'),
#  ('se', 'involucran', 'demasiado'),
#  ('involucran', 'demasiado', 'en'),
#  ('demasiado', 'en', 'el'),
#  ('en', 'el', 'respaldo'),
#  ('el', 'respaldo', 'o'),
#  ('respaldo', 'o', 'rechazo'),
#  ('o', 'rechazo', 'a'),
#  ('rechazo', 'a', 'las'),
#  ('a', 'las', 'posiciones'),
#  ('las', 'posiciones', 'de'),
#  ('posiciones', 'de', 'los'),
#  ('de', 'los', 'dos'),
#  ('los', 'dos', 'aspirantes'),
#  ('dos', 'aspirantes', 'todavía'),
#  ('aspirantes', 'todavía', 'en'),
#  ('todavía', 'en', 'liza'),
#  ('en', 'liza', 'prefieren'),
#  ('liza', 'prefieren', 'ignorar'),
#  ('prefieren', 'ignorar', 'las'),
#  ('ignorar', 'las', 'demandas'),
#  ('las', 'demandas', 'que'),
#  ('demandas', 'que', 'la'),
#  ('que', 'la', 'situación'),
#  ('la', 'situación', 'les'),
#  ('situación', 'les', 'plantea'),
#  ('les', 'plantea', 'no'),
#  ('plantea', 'no', 'se'),
#  ('no', 'se', 'trata'),
#  ('se', 'trata', 'por'),
#  ('trata', 'por', 'cierto'),
#  ('por', 'cierto', 'de'),
#  ('cierto', 'de', 'que'),
#  ('de', 'que', 'forzosamente'),
#  ('que', 'forzosamente', 'endosen'),
#  ('forzosamente', 'endosen', 'una'),
#  ('endosen', 'una', 'candidatura'),
#  ('una', 'candidatura', 'o'),
#  ('candidatura', 'o', 'la'),
#  ('o', 'la', 'otra'),
#  ('la', 'otra', 'sino'),
#  ('otra', 'sino', 'de'),
#  ('sino', 'de', 'que'),
#  ('de', 'que', 'señalen'),
#  ('que', 'señalen', 'los'),
#  ('señalen', 'los', 'riesgos'),
#  ('los', 'riesgos', 'que'),
#  ('riesgos', 'que', 'cada'),
#  ('que', 'cada', 'una'),
#  ('cada', 'una', 'de'),
#  ('una', 'de', 'ellas'),
#  ('de', 'ellas', 'entraña'),
#  ('ellas', 'entraña', 'para'),
#  ('entraña', 'para', 'orientar'),
#  ('para', 'orientar', 'de'),
#  ('orientar', 'de', 'esa'),
#  ('de', 'esa', 'manera'),
#  ('esa', 'manera', 'a'),
#  ('manera', 'a', 'quienes'),
#  ('a', 'quienes', 'confiaron'),
#  ('quienes', 'confiaron', 'en'),
#  ('confiaron', 'en', 'ellos'),
#  ('en', 'ellos', 'en'),
#  ('ellos', 'en', 'la'),
#  ('en', 'la', 'primera'),
#  ('la', 'primera', 'vuelta'),
#  ('primera', 'vuelta', 'en'),
#  ('vuelta', 'en', 'eso'),
#  ('en', 'eso', 'consiste'),
#  ('eso', 'consiste', 'precisamente'),
#  ('consiste', 'precisamente', 'la'),
#  ('precisamente', 'la', 'tarea'),
#  ('la', 'tarea', 'de'),
#  ('tarea', 'de', 'un'),
#  ('de', 'un', 'líder'),
#  ('un', 'líder', 'político'),
#  ('líder', 'político', 'en'),
#  ('político', 'en', 'liderar'),
#  ('en', 'liderar', 'en'),
#  ('liderar', 'en', 'ese'),
#  ('en', 'ese', 'sentido'),
#  ('ese', 'sentido', 'el'),
#  ('sentido', 'el', 'eventual'),
#  ('el', 'eventual', 'respaldo'),
#  ('eventual', 'respaldo', 'a'),
#  ('respaldo', 'a', 'una'),
#  ('a', 'una', 'de'),
#  ('una', 'de', 'las'),
#  ('de', 'las', 'dos'),
#  ('las', 'dos', 'opciones'),
#  ('dos', 'opciones', 'en'),
#  ('opciones', 'en', 'disputa'),
#  ('en', 'disputa', 'debería'),
#  ('disputa', 'debería', 'ser'),
#  ('debería', 'ser', 'para'),
#  ('ser', 'para', 'los'),
#  ('para', 'los', 'excandidatos'),
#  ('los', 'excandidatos', 'un'),
#  ('excandidatos', 'un', 'corolario'),
#  ('un', 'corolario', 'y'),
#  ('corolario', 'y', 'no'),
#  ('y', 'no', 'una'),
#  ('no', 'una', 'premisa'),
#  ('una', 'premisa', 'lamentablemente'),
#  ('premisa', 'lamentablemente', 'lo'),
#  ('lamentablemente', 'lo', 'que'),
#  ('lo', 'que', 'estamos'),
#  ('que', 'estamos', 'viendo'),
#  ('estamos', 'viendo', 'en'),
#  ('viendo', 'en', 'una'),
#  ('en', 'una', 'mayoría'),
#  ('una', 'mayoría', 'de'),
#  ('mayoría', 'de', 'casos'),
#  ('de', 'casos', 'no'),
#  ('casos', 'no', 'se'),
#  ('no', 'se', 'ajusta'),
#  ('se', 'ajusta', 'a'),
#  ('ajusta', 'a', 'esa'),
#  ('a', 'esa', 'descripción'),
#  ('esa', 'descripción', 'o'),
#  ('descripción', 'o', 'bien'),
#  ('o', 'bien', 'el'),
#  ('bien', 'el', 'endose'),
#  ('el', 'endose', 'se'),
#  ('endose', 'se', 'ha'),
#  ('se', 'ha', 'producido'),
#  ('ha', 'producido', 'de'),
#  ('producido', 'de', 'manera'),
#  ('de', 'manera', 'sumaria'),
#  ('manera', 'sumaria', 'y'),
#  ('sumaria', 'y', 'sin'),
#  ('y', 'sin', 'acompañarlo'),
#  ('sin', 'acompañarlo', 'luego'),
#  ('acompañarlo', 'luego', 'de'),
#  ('luego', 'de', 'una'),
#  ('de', 'una', 'crítica'),
#  ('una', 'crítica', 'a'),
#  ('crítica', 'a', 'los'),
#  ('a', 'los', 'asuntos'),
#  ('los', 'asuntos', 'en'),
#  ('asuntos', 'en', 'los'),
#  ('en', 'los', 'que'),
#  ('los', 'que', 'los'),
#  ('que', 'los', 'votantes'),
#  ('los', 'votantes', 'del'),
#  ('votantes', 'del', 'expostulante'),
#  ('del', 'expostulante', 'que'),
#  ('expostulante', 'que', 'lo'),
#  ('que', 'lo', 'ha'),
#  ('lo', 'ha', 'otorgado'),
#  ('ha', 'otorgado', 'podrían'),
#  ('otorgado', 'podrían', 'sentirse'),
#  ('podrían', 'sentirse', 'defraudados'),
#  ('sentirse', 'defraudados', 'o'),
#  ('defraudados', 'o', 'bien'),
#  ('o', 'bien', 'la'),
#  ('bien', 'la', 'imposibilidad'),
#  ('la', 'imposibilidad', 'de'),
#  ('imposibilidad', 'de', 'renunciar'),
#  ('de', 'renunciar', 'al'),
#  ('renunciar', 'al', 'protagonismo'),
#  ('al', 'protagonismo', 'alcanzado'),
#  ('protagonismo', 'alcanzado', 'en'),
#  ('alcanzado', 'en', 'la'),
#  ('en', 'la', 'primera'),
#  ('la', 'primera', 'parte'),
#  ('primera', 'parte', 'de'),
#  ('parte', 'de', 'la'),
#  ('de', 'la', 'campaña'),
#  ('la', 'campaña', 'se'),
#  ('campaña', 'se', 'convierte'),
#  ('se', 'convierte', 'en'),
#  ('convierte', 'en', 'un'),
#  ('en', 'un', 'obstáculo'),
#  ('un', 'obstáculo', 'para'),
#  ('obstáculo', 'para', 'que'),
#  ('para', 'que', 'el'),
#  ('que', 'el', 'expostulante'),
#  ('el', 'expostulante', 'ejerza'),
#  ('expostulante', 'ejerza', 'eficazmente'),
#  ('ejerza', 'eficazmente', 'la'),
#  ('eficazmente', 'la', 'crítica'),
#  ('la', 'crítica', 'o'),
#  ('crítica', 'o', 'el'),
#  ('o', 'el', 'apoyo'),
#  ('el', 'apoyo', 'según'),
#  ('apoyo', 'según', 'dicte'),
#  ('según', 'dicte', 'la'),
#  ('dicte', 'la', 'coherencia'),
#  ('la', 'coherencia', 'con'),
#  ('coherencia', 'con', 'las'),
#  ('con', 'las', 'líneas'),
#  ('las', 'líneas', 'generales'),
#  ('líneas', 'generales', 'de'),
#  ('generales', 'de', 'lo'),
#  ('de', 'lo', 'que'),
#  ('lo', 'que', 'le'),
#  ('que', 'le', 'ofreció'),
#  ('le', 'ofreció', 'al'),
#  ('ofreció', 'al', 'país'),
#  ('al', 'país', 'mientras'),
#  ('país', 'mientras', 'era'),
#  ('mientras', 'era', 'uno'),
#  ('era', 'uno', 'de'),
#  ('uno', 'de', 'los'),
#  ('de', 'los', 'participantes'),
#  ('los', 'participantes', 'del'),
#  ('participantes', 'del', 'proceso'),
#  ('del', 'proceso', 'verónika'),
#  ('proceso', 'verónika', 'mendoza'),
#  ('verónika', 'mendoza', 'es'),
#  ('mendoza', 'es', 'de'),
#  ('es', 'de', 'hecho'),
#  ('de', 'hecho', 'un'),
#  ('hecho', 'un', 'buen'),
#  ('un', 'buen', 'ejemplo'),
#  ('buen', 'ejemplo', 'de'),
#  ('ejemplo', 'de', 'lo'),
#  ('de', 'lo', 'primero'),
#  ('lo', 'primero', 'mientras'),
#  ('primero', 'mientras', 'que'),
#  ('mientras', 'que', 'hernando'),
#  ('que', 'hernando', 'de'),
#  ('hernando', 'de', 'soto'),
#  ('de', 'soto', 'lo'),
#  ('soto', 'lo', 'es'),
#  ('lo', 'es', 'de'),
#  ('es', 'de', 'lo'),
#  ('de', 'lo', 'segundo'),
#  ('lo', 'segundo', 'la'),
#  ('segundo', 'la', 'excandidata'),
#  ('la', 'excandidata', 'presidencial'),
#  ('excandidata', 'presidencial', 'de'),
#  ('presidencial', 'de', 'juntos'),
#  ('de', 'juntos', 'por'),
#  ('juntos', 'por', 'el'),
#  ('por', 'el', 'perú'),
#  ('el', 'perú', 'como'),
#  ('perú', 'como', 'se'),
#  ('como', 'se', 'sabe'),
#  ('se', 'sabe', 'anunció'),
#  ('sabe', 'anunció', 'muy'),
#  ('anunció', 'muy', 'rápidamente'),
#  ('muy', 'rápidamente', 'que'),
#  ('rápidamente', 'que', 'ella'),
#  ('que', 'ella', 'y'),
#  ('ella', 'y', 'la'),
#  ('y', 'la', 'organización'),
#  ('la', 'organización', 'política'),
#  ('organización', 'política', 'que'),
#  ('política', 'que', 'la'),
#  ('que', 'la', 'postuló'),
#  ('la', 'postuló', 'apoyarán'),
#  ('postuló', 'apoyarán', 'en'),
#  ('apoyarán', 'en', 'esta'),
#  ('en', 'esta', 'segunda'),
#  ('esta', 'segunda', 'vuelta'),
#  ('segunda', 'vuelta', 'a'),
#  ('vuelta', 'a', 'pedro'),
#  ('a', 'pedro', 'castillo'),
#  ('pedro', 'castillo', 'una'),
#  ('castillo', 'una', 'consecuencia'),
#  ('una', 'consecuencia', 'previsible'),
#  ('consecuencia', 'previsible', 'de'),
#  ('previsible', 'de', 'la'),
#  ('de', 'la', 'sintonía'),
#  ('la', 'sintonía', 'que'),
#  ('sintonía', 'que', 'guarda'),
#  ('que', 'guarda', 'con'),
#  ('guarda', 'con', 'los'),
#  ('con', 'los', 'planes'),
#  ('los', 'planes', 'estatistas'),
#  ('planes', 'estatistas', 'de'),
#  ('estatistas', 'de', 'perú'),
#  ('de', 'perú', 'libre'),
#  ('perú', 'libre', 'y'),
#  ('libre', 'y', 'su'),
#  ('y', 'su', 'simpatía'),
#  ('su', 'simpatía', 'por'),
#  ('simpatía', 'por', 'los'),
#  ('por', 'los', 'regímenes'),
#  ('los', 'regímenes', 'totalitarios'),
#  ('regímenes', 'totalitarios', 'del'),
#  ('totalitarios', 'del', 'continente'),
#  ('del', 'continente', 'frente'),
#  ('continente', 'frente', 'a'),
#  ('frente', 'a', 'los'),
#  ('a', 'los', 'anuncios'),
#  ('los', 'anuncios', 'de'),
#  ('anuncios', 'de', '“desactivación”'),
#  ('de', '“desactivación”', 'de'),
#  ('“desactivación”', 'de', 'la'),
#  ('de', 'la', 'defensoría'),
#  ('la', 'defensoría', 'del'),
#  ('defensoría', 'del', 'pueblo'),
#  ('del', 'pueblo', 'o'),
#  ('pueblo', 'o', 'la'),
#  ('o', 'la', 'atu'),
#  ('la', 'atu', 'o'),
#  ('atu', 'o', 'de'),
#  ('o', 'de', 'intervención'),
#  ('de', 'intervención', 'en'),
#  ('intervención', 'en', 'la'),
#  ('en', 'la', 'labor'),
#  ('la', 'labor', 'que'),
#  ('labor', 'que', 'viene'),
#  ('que', 'viene', 'llevando'),
#  ('viene', 'llevando', 'adelante'),
#  ('llevando', 'adelante', 'la'),
#  ('adelante', 'la', 'sunedu'),
#  ('la', 'sunedu', 'no'),
#  ('sunedu', 'no', 'obstante'),
#  ('no', 'obstante', 'verónika'),
#  ('obstante', 'verónika', 'mendoza'),
#  ('verónika', 'mendoza', 'no'),
#  ('mendoza', 'no', 'ha'),
#  ('no', 'ha', 'dicho'),
#  ('ha', 'dicho', 'nada'),
#  ('dicho', 'nada', '¿debemos'),
#  ('nada', '¿debemos', 'entender'),
#  ('¿debemos', 'entender', 'que'),
#  ('entender', 'que', 'está'),
#  ('que', 'está', 'conforme'),
#  ('está', 'conforme', 'con'),
#  ('conforme', 'con', 'los'),
#  ('con', 'los', 'planes'),
#  ('los', 'planes', 'de'),
#  ('planes', 'de', 'castillo'),
#  ('de', 'castillo', 'al'),
#  ('castillo', 'al', 'respecto'),
#  ('al', 'respecto', 'o'),
#  ('respecto', 'o', 'que'),
#  ('o', 'que', 'sencillamente'),
#  ('que', 'sencillamente', 'prefiere'),
#  ('sencillamente', 'prefiere', 'callar'),
#  ('prefiere', 'callar', 'para'),
#  ('callar', 'para', 'no'),
#  ('para', 'no', 'afectar'),
#  ('no', 'afectar', 'las'),
#  ('afectar', 'las', 'chances'),
#  ('las', 'chances', 'de'),
#  ('chances', 'de', 'la'),
#  ('de', 'la', 'izquierda'),
#  ('la', 'izquierda', 'el'),
#  ('izquierda', 'el', '6'),
#  ('el', '6', 'de'),
#  ('6', 'de', 'junio'),
#  ('de', 'junio', 'hernando'),
#  ('junio', 'hernando', 'de'),
#  ('hernando', 'de', 'soto'),
#  ('de', 'soto', 'por'),
#  ('soto', 'por', 'otro'),
#  ('por', 'otro', 'lado'),
#  ('otro', 'lado', 'luce'),
#  ('lado', 'luce', 'más'),
#  ('luce', 'más', 'interesado'),
#  ('más', 'interesado', 'en'),
#  ('interesado', 'en', 'tener'),
#  ('en', 'tener', 'un'),
#  ('tener', 'un', 'rol'),
#  ('un', 'rol', 'estelar'),
#  ('rol', 'estelar', 'en'),
#  ('estelar', 'en', 'la'),
#  ('en', 'la', 'segunda'),
#  ('la', 'segunda', 'vuelta'),
#  ('segunda', 'vuelta', 'que'),
#  ('vuelta', 'que', 'en'),
#  ('que', 'en', 'ayudar'),
#  ('en', 'ayudar', 'a'),
#  ('ayudar', 'a', 'sus'),
#  ('a', 'sus', 'antiguos'),
#  ('sus', 'antiguos', 'adherentes'),
#  ('antiguos', 'adherentes', 'a'),
#  ('adherentes', 'a', 'decidir'),
#  ('a', 'decidir', 'qué'),
#  ('decidir', 'qué', 'hacer'),
#  ('qué', 'hacer', 'ahora'),
#  ('hacer', 'ahora', 'con'),
#  ('ahora', 'con', 'su'),
#  ('con', 'su', 'voto'),
#  ('su', 'voto', '“estoy'),
#  ('voto', '“estoy', 'proponiendo'),
#  ('“estoy', 'proponiendo', 'a'),
#  ('proponiendo', 'a', 'la'),
#  ('a', 'la', 'candidata'),
#  ('la', 'candidata', 'fujimori'),
#  ('candidata', 'fujimori', 'una'),
#  ('fujimori', 'una', 'fórmula'),
#  ('una', 'fórmula', 'para'),
#  ('fórmula', 'para', 'que'),
#  ('para', 'que', 'su'),
#  ('que', 'su', 'propuesta'),
#  ('su', 'propuesta', 'sea'),
#  ('propuesta', 'sea', 'inclusiva'),
#  ('sea', 'inclusiva', 'y'),
#  ('inclusiva', 'y', 'no'),
#  ('y', 'no', 'mercantilista'),
#  ('no', 'mercantilista', 'y'),
#  ('mercantilista', 'y', 'al'),
#  ('y', 'al', 'candidato'),
#  ('al', 'candidato', 'castillo'),
#  ('candidato', 'castillo', 'otra'),
#  ('castillo', 'otra', 'fórmula'),
#  ('otra', 'fórmula', 'para'),
#  ('fórmula', 'para', 'que'),
#  ('para', 'que', 'no'),
#  ('que', 'no', 'se'),
#  ('no', 'se', 'politice'),
#  ('se', 'politice', 'la'),
#  ('politice', 'la', 'economía'),
#  ('la', 'economía', 'dentro'),
#  ('economía', 'dentro', 'de'),
#  ('dentro', 'de', 'un'),
#  ('de', 'un', 'régimen'),
#  ('un', 'régimen', 'comunista”'),
#  ('régimen', 'comunista”', 'ha'),
#  ('comunista”', 'ha', 'escrito'),
#  ('ha', 'escrito', 'en'),
#  ('escrito', 'en', 'un'),
#  ('en', 'un', 'comunicado'),
#  ('un', 'comunicado', 'divulgado'),
#  ('comunicado', 'divulgado', 'ayer'),
#  ('divulgado', 'ayer', '¿debemos'),
#  ('ayer', '¿debemos', 'entender'),
#  ('¿debemos', 'entender', 'acaso'),
#  ('entender', 'acaso', 'que'),
#  ('acaso', 'que', 'solo'),
#  ('que', 'solo', 'el'),
#  ('solo', 'el', 'que'),
#  ('el', 'que', 'le'),
#  ('que', 'le', 'dé'),
#  ('le', 'dé', 'la'),
#  ('dé', 'la', 'razón'),
#  ('la', 'razón', 'obtendrá'),
#  ('razón', 'obtendrá', 'la'),
#  ('obtendrá', 'la', 'gracia'),
#  ('la', 'gracia', 'de'),
#  ('gracia', 'de', 'su'),
#  ('de', 'su', 'voto'),
#  ('su', 'voto', 'en'),
#  ('voto', 'en', 'los'),
#  ('en', 'los', 'predios'),
#  ('los', 'predios', 'de'),
#  ('predios', 'de', 'avanza'),
#  ('de', 'avanza', 'país'),
#  ('avanza', 'país', 'mientras'),
#  ('país', 'mientras', 'tanto'),
#  ('mientras', 'tanto', 'parece'),
#  ('tanto', 'parece', 'existir'),
#  ('parece', 'existir', 'la'),
#  ('existir', 'la', 'impresión'),
#  ('la', 'impresión', 'de'),
#  ('impresión', 'de', 'que'),
#  ('de', 'que', 'las'),
#  ('que', 'las', 'urgencias'),
#  ('las', 'urgencias', 'son'),
#  ('urgencias', 'son', 'otras'),
#  ('son', 'otras', 'pues'),
#  ('otras', 'pues', 'la'),
#  ('pues', 'la', 'mayoría'),
#  ('la', 'mayoría', 'de'),
#  ('mayoría', 'de', 'los'),
#  ('de', 'los', 'congresistas'),
#  ('los', 'congresistas', 'elegidos'),
#  ('congresistas', 'elegidos', 'en'),
#  ('elegidos', 'en', 'sus'),
#  ('en', 'sus', 'listas'),
#  ('sus', 'listas', 'ya'),
#  ('listas', 'ya', 'anunció'),
#  ('ya', 'anunció', 'que'),
#  ('anunció', 'que', 'votará'),
#  ('que', 'votará', '“contra'),
#  ('votará', '“contra', 'el'),
#  ('“contra', 'el', 'comunismo”'),
#  ('el', 'comunismo”', 'y'),
#  ('comunismo”', 'y', 'el'),
#  ('y', 'el', 'canciller'),
#  ('el', 'canciller', 'francisco'),
#  ('canciller', 'francisco', 'tudela'),
#  ('francisco', 'tudela', 'hasta'),
#  ('tudela', 'hasta', 'hace'),
#  ('hasta', 'hace', 'poco'),
#  ('hace', 'poco', 'miembro'),
#  ('poco', 'miembro', 'de'),
#  ('miembro', 'de', 'su'),
#  ('de', 'su', '“gabinete'),
#  ('su', '“gabinete', 'en'),
#  ('“gabinete', 'en', 'la'),
#  ('en', 'la', 'sombra”'),
#  ('la', 'sombra”', 'se'),
#  ('sombra”', 'se', 'ha'),
#  ('se', 'ha', 'alejado'),
#  ('ha', 'alejado', 'del'),
#  ('alejado', 'del', 'proyecto'),
#  ('del', 'proyecto', 'político'),
#  ('proyecto', 'político', 'conjunto'),
#  ('político', 'conjunto', 'argumentando'),
#  ('conjunto', 'argumentando', 'que'),
#  ('argumentando', 'que', '“en'),
#  ('que', '“en', 'esta'),
#  ('“en', 'esta', 'hora'),
#  ('esta', 'hora', 'decisiva'),
#  ('hora', 'decisiva', 'no'),
#  ('decisiva', 'no', 'se'),
#  ('no', 'se', 'puede'),
#  ('se', 'puede', 'ser'),
#  ('puede', 'ser', 'indeciso'),
#  ('ser', 'indeciso', 'o'),
#  ('indeciso', 'o', 'esperar'),
#  ('o', 'esperar', 'a'),
#  ('esperar', 'a', 'ver'),
#  ('a', 'ver', 'quién'),
#  ('ver', 'quién', 'gana”'),
#  ('quién', 'gana”', 'una'),
#  ('gana”', 'una', 'severa'),
#  ('una', 'severa', 'llamada'),
#  ('severa', 'llamada', 'de'),
#  ('llamada', 'de', 'atención'),
#  ('de', 'atención', 'en'),
#  ('atención', 'en', 'fin'),
#  ('en', 'fin', 'para'),
#  ('fin', 'para', 'quien'),
#  ('para', 'quien', 'al'),
#  ('quien', 'al', 'igual'),
#  ('al', 'igual', 'que'),
#  ('igual', 'que', 'la'),
#  ('que', 'la', 'señora'),
#  ('la', 'señora', 'mendoza'),
#  ('señora', 'mendoza', 'parecería'),
#  ('mendoza', 'parecería', 'estar'),
#  ('parecería', 'estar', 'dispuesto'),
#  ('estar', 'dispuesto', 'a'),
#  ('dispuesto', 'a', 'actuar'),
#  ('a', 'actuar', 'como'),
#  ('actuar', 'como', 'un'),
#  ('como', 'un', 'convidado'),
#  ('un', 'convidado', 'de'),
#  ('convidado', 'de', 'piedra'),
#  ('de', 'piedra', 'en'),
#  ('piedra', 'en', 'esta'),
#  ('en', 'esta', 'segunda'),
#  ('esta', 'segunda', 'vuelta…'),
#  ('segunda', 'vuelta…', 'a'),
#  ('vuelta…', 'a', 'menos'),
#  ('a', 'menos', 'que'),
#  ('menos', 'que', 'le'),
#  ('que', 'le', 'concedan'),
#  ('le', 'concedan', 'el'),
#  ('concedan', 'el', 'centro'),
#  ('el', 'centro', 'del'),
#  ('centro', 'del', 'escenario'),
#  ('del', 'escenario', 'todo'),
#  ('escenario', 'todo', 'indica'),
#  ('todo', 'indica', 'que'),
#  ('indica', 'que', 'el'),
#  ('que', 'el', 'desencanto'),
#  ('el', 'desencanto', 'de'),
#  ('desencanto', 'de', 'los'),
#  ('de', 'los', 'ciudadanos'),
#  ('los', 'ciudadanos', 'con'),
#  ('ciudadanos', 'con', 'sus'),
#  ('con', 'sus', 'líderes'),
#  ('sus', 'líderes', 'políticos'),
#  ('líderes', 'políticos', 'tiene'),
#  ('políticos', 'tiene', 'una'),
#  ('tiene', 'una', 'explicación'),
#  ('una', 'explicación', 'fácil'),
#  ('explicación', 'fácil', 'pero'),
#  ('fácil', 'pero', 'una'),
#  ('pero', 'una', 'difícil'),
#  ('una', 'difícil', 'solución'),
#  ('en', 'la', 'peor'),
#  ('la', 'peor', 'de'),
#  ('peor', 'de', 'las'),
#  ('de', 'las', 'condiciones'),
#  ('las', 'condiciones', 'posibles'),
#  ('condiciones', 'posibles', 'con'),
#  ('posibles', 'con', 'una'),
#  ('con', 'una', 'pandemia'),
#  ('una', 'pandemia', 'que'),
#  ('pandemia', 'que', 'dificulta'),
#  ('que', 'dificulta', 'el'),
#  ('dificulta', 'el', 'contacto'),
#  ('el', 'contacto', 'entre'),
#  ('contacto', 'entre', 'las'),
#  ('entre', 'las', 'personas'),
#  ('las', 'personas', 'los'),
#  ('personas', 'los', 'peruanos'),
#  ('los', 'peruanos', 'acudimos'),
#  ('peruanos', 'acudimos', 'ayer'),
#  ('acudimos', 'ayer', 'a'),
#  ('ayer', 'a', 'las'),
#  ('a', 'las', 'urnas'),
#  ('las', 'urnas', 'para'),
#  ('urnas', 'para', 'ejercer'),
#  ('para', 'ejercer', 'el'),
#  ('ejercer', 'el', 'más'),
#  ('el', 'más', 'fundamental'),
#  ('más', 'fundamental', 'de'),
#  ('fundamental', 'de', 'nuestros'),
#  ('de', 'nuestros', 'derechos'),
#  ('nuestros', 'derechos', 'democráticos'),
#  ('derechos', 'democráticos', 'elegir'),
#  ('democráticos', 'elegir', 'a'),
#  ('elegir', 'a', 'quienes'),
#  ('a', 'quienes', 'liderarán'),
#  ('quienes', 'liderarán', 'nuestro'),
#  ('liderarán', 'nuestro', 'futuro'),
#  ('nuestro', 'futuro', 'por'),
#  ('futuro', 'por', 'cinco'),
#  ('por', 'cinco', 'años'),
#  ('cinco', 'años', 'la'),
#  ('años', 'la', 'jornada'),
#  ('la', 'jornada', 'empezó'),
#  ('jornada', 'empezó', 'de'),
#  ('empezó', 'de', 'manera'),
#  ('de', 'manera', 'accidentada'),
#  ('manera', 'accidentada', 'particularmente'),
#  ('accidentada', 'particularmente', 'en'),
#  ('particularmente', 'en', 'lima'),
#  ('en', 'lima', 'donde'),
#  ('lima', 'donde', 'múltiples'),
#  ('donde', 'múltiples', 'mesas'),
#  ('múltiples', 'mesas', 'demoraron'),
#  ('mesas', 'demoraron', 'en'),
#  ('demoraron', 'en', 'abrirse'),
#  ('en', 'abrirse', 'por'),
#  ('abrirse', 'por', 'la'),
#  ('por', 'la', 'ausencia'),
#  ('la', 'ausencia', 'de'),
#  ('ausencia', 'de', 'sus'),
#  ('de', 'sus', 'miembros'),
#  ('sus', 'miembros', 'y'),
#  ('miembros', 'y', 'con'),
#  ('y', 'con', 'largas'),
#  ('con', 'largas', 'colas'),
#  ('largas', 'colas', 'formándose'),
#  ('colas', 'formándose', 'en'),
#  ('formándose', 'en', 'el'),
#  ('en', 'el', 'exterior'),
#  ('el', 'exterior', 'de'),
#  ('exterior', 'de', 'los'),
#  ('de', 'los', 'locales'),
#  ('los', 'locales', 'de'),
#  ('locales', 'de', 'sufragio'),
#  ('de', 'sufragio', 'aun'),
#  ('sufragio', 'aun', 'así'),
#  ('aun', 'así', 'para'),
#  ('así', 'para', 'alrededor'),
#  ('para', 'alrededor', 'de'),
#  ('alrededor', 'de', 'las'),
#  ('de', 'las', 'dos'),
#  ('las', 'dos', 'de'),
#  ('dos', 'de', 'la'),
#  ('de', 'la', 'tarde'),
#  ('la', 'tarde', 'el'),
#  ('tarde', 'el', '996'),
#  ('el', '996', 'de'),
#  ('996', 'de', 'las'),
#  ('de', 'las', 'mesas'),
#  ('las', 'mesas', 'ya'),
#  ('mesas', 'ya', 'se'),
#  ('ya', 'se', 'habían'),
#  ('se', 'habían', 'instalado'),
#  ('habían', 'instalado', 'gracias'),
#  ('instalado', 'gracias', 'a'),
#  ('gracias', 'a', 'ciudadanos'),
#  ('a', 'ciudadanos', 'que'),
#  ('ciudadanos', 'que', 'se'),
#  ('que', 'se', 'ofrecieron'),
#  ('se', 'ofrecieron', 'para'),
#  ('ofrecieron', 'para', 'suplir'),
#  ('para', 'suplir', 'a'),
#  ('suplir', 'a', 'los'),
#  ('a', 'los', 'que'),
#  ('los', 'que', 'habían'),
#  ('que', 'habían', 'sido'),
#  ('habían', 'sido', 'asignados'),
#  ('sido', 'asignados', 'y'),
#  ('asignados', 'y', 'no'),
#  ('y', 'no', 'se'),
#  ('no', 'se', 'presentaron'),
#  ('se', 'presentaron', 'así'),
#  ('presentaron', 'así', 'las'),
#  ('así', 'las', 'cosas'),
#  ('las', 'cosas', 'el'),
#  ('cosas', 'el', 'proceso'),
#  ('el', 'proceso', 'fluyó'),
#  ('proceso', 'fluyó', 'de'),
#  ('fluyó', 'de', 'forma'),
#  ('de', 'forma', 'ordenada'),
#  ('forma', 'ordenada', 'y'),
#  ('ordenada', 'y', 'sin'),
#  ('y', 'sin', 'verdaderas'),
#  ('sin', 'verdaderas', 'sorpresas'),
#  ('verdaderas', 'sorpresas', 'y'),
#  ('sorpresas', 'y', 'salvo'),
#  ('y', 'salvo', 'por'),
#  ('salvo', 'por', 'algunas'),
#  ('por', 'algunas', 'pocas'),
#  ('algunas', 'pocas', 'quejas'),
#  ('pocas', 'quejas', 'cuya'),
#  ('quejas', 'cuya', 'pertinencia'),
#  ('cuya', 'pertinencia', 'tendrá'),
#  ('pertinencia', 'tendrá', 'que'),
#  ('tendrá', 'que', 'ser'),
#  ('que', 'ser', 'verificada'),
#  ('ser', 'verificada', 'ajustado'),
#  ('verificada', 'ajustado', 'a'),
#  ('ajustado', 'a', 'la'),
#  ('a', 'la', 'asepsia'),
#  ('la', 'asepsia', 'que'),
#  ('asepsia', 'que', 'todos'),
#  ('que', 'todos', 'esperábamos'),
#  ('todos', 'esperábamos', 'ello'),
#  ('esperábamos', 'ello', 'no'),
#  ('ello', 'no', 'evitó'),
#  ('no', 'evitó', 'que'),
#  ('evitó', 'que', 'como'),
#  ('que', 'como', 'suele'),
#  ('como', 'suele', 'ocurrir'),
#  ('suele', 'ocurrir', 'algunos'),
#  ('ocurrir', 'algunos', 'candidatos'),
#  ('algunos', 'candidatos', 'como'),
#  ('candidatos', 'como', 'el'),
#  ('como', 'el', 'señor'),
#  ('el', 'señor', 'rafael'),
#  ('señor', 'rafael', 'lópez'),
#  ('rafael', 'lópez', 'aliaga'),
#  ('lópez', 'aliaga', 'sugiriesen'),
#  ('aliaga', 'sugiriesen', 'la'),
#  ('sugiriesen', 'la', 'existencia'),
#  ('la', 'existencia', 'de'),
#  ('existencia', 'de', 'irregularidades'),
#  ('de', 'irregularidades', 'en'),
#  ('irregularidades', 'en', 'su'),
#  ('en', 'su', 'contra'),
#  ('su', 'contra', 'sin'),
#  ('contra', 'sin', 'ningún'),
#  ('sin', 'ningún', 'tipo'),
#  ('ningún', 'tipo', 'de'),
#  ('tipo', 'de', 'evidencia'),
#  ('de', 'evidencia', 'para'),
#  ('evidencia', 'para', 'sustentarlo'),
#  ('para', 'sustentarlo', 'los'),
#  ('sustentarlo', 'los', 'verdaderos'),
#  ('los', 'verdaderos', 'sobresaltos'),
#  ('verdaderos', 'sobresaltos', 'recién'),
#  ('sobresaltos', 'recién', 'llegaron'),
#  ('recién', 'llegaron', 'por'),
#  ('llegaron', 'por', 'la'),
#  ('por', 'la', 'noche'),
#  ('la', 'noche', 'cuando'),
#  ('noche', 'cuando', 'los'),
#  ('cuando', 'los', 'noticieros'),
#  ('los', 'noticieros', 'dieron'),
#  ('noticieros', 'dieron', 'a'),
#  ('dieron', 'a', 'conocer'),
#  ('a', 'conocer', 'primero'),
#  ('conocer', 'primero', 'el'),
#  ('primero', 'el', 'flash'),
#  ('el', 'flash', 'electoral'),
#  ('flash', 'electoral', 'a'),
#  ('electoral', 'a', 'boca'),
#  ('a', 'boca', 'de'),
#  ('boca', 'de', 'urna'),
#  ('de', 'urna', 'y'),
#  ('urna', 'y', 'luego'),
#  ('y', 'luego', 'el'),
#  ('luego', 'el', 'conteo'),
#  ('el', 'conteo', 'rápido'),
#  ('conteo', 'rápido', 'de'),
#  ('rápido', 'de', 'ipsos'),
#  ('de', 'ipsos', 'como'),
#  ('ipsos', 'como', 'ya'),
#  ('como', 'ya', 'mostraban'),
#  ('ya', 'mostraban', 'las'),
#  ('mostraban', 'las', 'encuestas'),
#  ('las', 'encuestas', 'que'),
#  ('encuestas', 'que', 'trascendían'),
#  ('que', 'trascendían', 'en'),
#  ('trascendían', 'en', 'la'),
#  ('en', 'la', 'víspera'),
#  ('la', 'víspera', 'el'),
#  ('víspera', 'el', 'candidato'),
#  ('el', 'candidato', 'de'),
#  ('candidato', 'de', 'perú'),
#  ('de', 'perú', 'libre'),
#  ('perú', 'libre', 'pedro'),
#  ('libre', 'pedro', 'castillo'),
#  ('pedro', 'castillo', 'consolidó'),
#  ('castillo', 'consolidó', 'su'),
#  ('consolidó', 'su', 'ascenso'),
#  ('su', 'ascenso', 'y'),
#  ('ascenso', 'y', 'habría'),
#  ('y', 'habría', 'alcanzado'),
#  ('habría', 'alcanzado', 'más'),
#  ('alcanzado', 'más', 'votos'),
#  ('más', 'votos', 'que'),
#  ('votos', 'que', 'cualquier'),
#  ('que', 'cualquier', 'otro'),
#  ('cualquier', 'otro', 'postulante'),
#  ('otro', 'postulante', 'colocándose'),
#  ('postulante', 'colocándose', 'en'),
#  ('colocándose', 'en', 'el'),
#  ('en', 'el', 'primer'),
#  ('el', 'primer', 'puesto'),
#  ('primer', 'puesto', 'con'),
#  ('puesto', 'con', '181'),
#  ('con', '181', 'del'),
#  ('181', 'del', 'voto'),
#  ('del', 'voto', 'al'),
#  ('voto', 'al', '90'),
#  ('al', '90', 'del'),
#  ('90', 'del', 'conteo'),
#  ('del', 'conteo', 'según'),
#  ('conteo', 'según', 'la'),
#  ('según', 'la', 'referida'),
#  ('la', 'referida', 'medición'),
#  ('referida', 'medición', 'de'),
#  ('medición', 'de', 'ipsos'),
#  ('de', 'ipsos', 'lo'),
#  ('ipsos', 'lo', 'siguen'),
#  ('lo', 'siguen', 'keiko'),
#  ('siguen', 'keiko', 'fujimori'),
#  ('keiko', 'fujimori', 'fuerza'),
#  ('fujimori', 'fuerza', 'popular'),
#  ('fuerza', 'popular', 'con'),
#  ('popular', 'con', '144'),
#  ('con', '144', 'y'),
#  ('144', 'y', 'rafael'),
#  ('y', 'rafael', 'lópez'),
#  ('rafael', 'lópez', 'aliaga'),
#  ('lópez', 'aliaga', 'renovación'),
#  ('aliaga', 'renovación', 'popular'),
#  ('renovación', 'popular', 'con'),
#  ('popular', 'con', '124'),
#  ('con', '124', 'hará'),
#  ('124', 'hará', 'falta'),
#  ('hará', 'falta', 'esperar'),
#  ('falta', 'esperar', 'los'),
#  ('esperar', 'los', 'resultados'),
#  ('los', 'resultados', 'de'),
#  ('resultados', 'de', 'la'),
#  ('de', 'la', 'onpe'),
#  ('la', 'onpe', 'al'),
#  ('onpe', 'al', '100'),
#  ('al', '100', 'para'),
#  ('100', 'para', 'saber'),
#  ('para', 'saber', 'el'),
#  ('saber', 'el', 'cuadro'),
#  ('el', 'cuadro', 'final'),
#  ('cuadro', 'final', 'de'),
#  ('final', 'de', 'candidatos'),
#  ('de', 'candidatos', 'tras'),
#  ('candidatos', 'tras', 'una'),
#  ('tras', 'una', 'campaña'),
#  ('una', 'campaña', 'marcada'),
#  ('campaña', 'marcada', 'por'),
#  ('marcada', 'por', 'la'),
#  ('por', 'la', 'polarización'),
#  ('la', 'polarización', '–por'),
#  ('polarización', '–por', 'la'),
#  ('–por', 'la', 'presencia'),
#  ('la', 'presencia', 'de'),
#  ('presencia', 'de', 'posiciones'),
#  ('de', 'posiciones', 'extremas–'),
#  ('posiciones', 'extremas–', 'y'),
#  ('extremas–', 'y', 'la'),
#  ('y', 'la', 'atomización'),
#  ('la', 'atomización', '–por'),
#  ('atomización', '–por', 'lo'),
#  ('–por', 'lo', 'pequeño'),
#  ('lo', 'pequeño', 'del'),
#  ('pequeño', 'del', 'apoyo'),
#  ('del', 'apoyo', 'que'),
#  ('apoyo', 'que', 'recibió'),
#  ('que', 'recibió', 'cada'),
#  ('recibió', 'cada', 'aspirante'),
#  ('cada', 'aspirante', 'al'),
#  ('aspirante', 'al', 'sillón'),
#  ('al', 'sillón', 'de'),
#  ('sillón', 'de', 'pizarro–'),
#  ('de', 'pizarro–', 'este'),
#  ('pizarro–', 'este', 'desenlace'),
#  ('este', 'desenlace', 'solo'),
#  ('desenlace', 'solo', 'augura'),
#  ('solo', 'augura', 'aún'),
#  ('augura', 'aún', 'más'),
#  ('aún', 'más', 'división'),
#  ('más', 'división', 'en'),
#  ('división', 'en', 'el'),
#  ('en', 'el', 'camino'),
#  ('el', 'camino', 'a'),
#  ...]

# %%
triWords_EC_clean = [gram for gram in triWords_EC if not any(stop in gram for stop in spanish_stopwords)]
print(triWords_EC_clean)
# Out:
# [('determinados', 'sectores', 'ciudadanos'), ('corresponde', 'efectivamente', 'velar'), ('dos', 'aspirantes', 'todavía'), ('liza', 'prefieren', 'ignorar'), ('disputa', 'debería', 'ser'), ('otorgado', 'podrían', 'sentirse'), ('podrían', 'sentirse', 'defraudados'), ('expostulante', 'ejerza', 'eficazmente'), ('apoyo', 'según', 'dicte'), ('proceso', 'verónika', 'mendoza'), ('viene', 'llevando', 'adelante'), ('obstante', 'verónika', 'mendoza'), ('sencillamente', 'prefiere', 'callar'), ('voto', '“estoy', 'proponiendo'), ('comunicado', 'divulgado', 'ayer'), ('divulgado', 'ayer', '¿debemos'), ('ayer', '¿debemos', 'entender'), ('¿debemos', 'entender', 'acaso'), ('avanza', 'país', 'mientras'), ('canciller', 'francisco', 'tudela'), ('proyecto', 'político', 'conjunto'), ('político', 'conjunto', 'argumentando'), ('puede', 'ser', 'indeciso'), ('ver', 'quién', 'gana”'), ('señora', 'mendoza', 'parecería'), ('peruanos', 'acudimos', 'ayer'), ('derechos', 'democráticos', 'elegir'), ('manera', 'accidentada', 'particularmente'), ('múltiples', 'mesas', 'demoraron'), ('largas', 'colas', 'formándose'), ('sufragio', 'aun', 'así'), ('pocas', 'quejas', 'cuya'), ('quejas', 'cuya', 'pertinencia'), ('ser', 'verificada', 'ajustado'), ('señor', 'rafael', 'lópez'), ('rafael', 'lópez', 'aliaga'), ('lópez', 'aliaga', 'sugiriesen'), ('verdaderos', 'sobresaltos', 'recién'), ('sobresaltos', 'recién', 'llegaron'), ('perú', 'libre', 'pedro'), ('libre', 'pedro', 'castillo'), ('pedro', 'castillo', 'consolidó'), ('siguen', 'keiko', 'fujimori'), ('keiko', 'fujimori', 'fuerza'), ('fujimori', 'fuerza', 'popular'), ('rafael', 'lópez', 'aliaga'), ('lópez', 'aliaga', 'renovación'), ('aliaga', 'renovación', 'popular'), ('124', 'hará', 'falta'), ('hará', 'falta', 'esperar'), ('recibió', 'cada', 'aspirante'), ('desenlace', 'solo', 'augura'), ('solo', 'augura', 'aún'), ('izquierda', 'radical', 'partidaria'), ('dos', 'opciones', 'diametralmente'), ('opciones', 'diametralmente', 'distintas'), ('diametralmente', 'distintas', 'ello'), ('cómo', 'debe', 'conducirse'), ('decirlo', 'profesa', 'perspectivas'), ('profesa', 'perspectivas', 'antojadizas'), ('sistema', 'político', 'debe'), ('político', 'debe', 'funcionar'), ('gobierno', 'abiertamente', 'agresivo'), ('representación', 'parlamentaria', 'fragmentada'), ('gobernanza', 'dependerá', 'gane'), ('carrera', 'hacia', 'palacio'), ('ventilar', 'supuestas', 'conspiraciones'), ('generar', 'ganancias', 'indebidas'), ('excongresista', 'marisa', 'glave'), ('marisa', 'glave', 'cercana'), ('excandidata', 'presidencial', 'verónika'), ('presidencial', 'verónika', 'mendoza'), ('presente', 'coyuntura', 'vale'), ('coyuntura', 'vale', 'señalar'), ('procesos', 'electorales', 'anteriores'), ('bcrp', 'debe', 'intentar'), ('menos', 'marcadas', '–es'), ('marcadas', '–es', 'decir'), ('–es', 'decir', 'evitar'), ('decir', 'evitar', 'incrementos'), ('contracciones', 'demasiado', 'bruscas'), ('reporte', 'oficial', 'publicado'), ('precio', 'suba', 'menos'), ('entidad', 'pueden', 'evitar'), ('pedro', 'castillo', 'candidato'), ('mercados', 'financieros', 'tan'), ('financieros', 'tan', 'solo'), ('tan', 'solo', 'atenuarlos'), ('dos', 'directores', 'cercanos'), ('fujimorismo', 'rafael', 'rey'), ('josé', 'chlimper', 'hacen'), ('poca', 'solidez', 'aun'), ('solidez', 'aun', 'si'), ('directores', 'quisieran', 'dirigir'), ('queda', 'claro', 'cómo'), ('claro', 'cómo', 'lograrían'), ('técnicos', 'altamente', 'calificados'), ('altamente', 'calificados', 'arriesgar'), ('lamentable', 'julio', 'velarde'), ('julio', 'velarde', '–cabeza'), ('mejor', 'banquero', 'central'), ('muerto', 'cada', 'cinco'), ('cada', 'cinco', 'minutos'), ('cinco', 'mil', 'compatriotas'), ('cifras', 'hacen', 'evidente'), ('iceberg', 'toda', 'vez'), ('aún', 'existen', 'marcadas'), ('existen', 'marcadas', 'diferencias'), ('cansancio', 'parece', 'haberse'), ('parece', 'haberse', 'instalado'), ('medidas', 'aún', 'vigentes'), ('días', 'parece', 'demostrar'), ('acciones', 'pueden', 'tomarse'), ('hace', 'difíc ...

# %%
from collections import Counter

trigramsCount_dict_EC = Counter(triWords_EC_clean) #generate counter

# Turn bigramsCount_dict  into dataframe, naming columns
trigramsCount_EC = pd.DataFrame(trigramsCount_dict_EC.most_common(),
                        columns=['trigrama', 'peso'])
trigramsCount_EC
# Out:
#                                  trigrama  peso
# 0    (determinados, sectores, ciudadanos)     2
# 1                 (rafael, lópez, aliaga)     2
# 2                    (perú, libre, pedro)     2
# 3                (libre, pedro, castillo)     2
# 4               (keiko, fujimori, fuerza)     2
# ..                                    ...   ...
# 813          (ningún, demócrata, debería)     1
# 814           (demócrata, debería, abrir)     1
# 815             (venezuela, además, cita)     1
# 816              (vladimir, lenin, fidel)     1
# 817                (lenin, fidel, castro)     1
#
# [818 rows x 2 columns]

# %%
trigramsCount_EC['palabra 1'], trigramsCount_EC['palabra 2'], trigramsCount_EC['palabra 3'] = zip(*trigramsCount_EC['trigrama'])
trigramsCount_EC
# Out:
#                                  trigrama  peso     palabra 1  palabra 2  \
# 0    (determinados, sectores, ciudadanos)     2  determinados   sectores
# 1                 (rafael, lópez, aliaga)     2        rafael      lópez
# 2                    (perú, libre, pedro)     2          perú      libre
# 3                (libre, pedro, castillo)     2         libre      pedro
# 4               (keiko, fujimori, fuerza)     2         keiko   fujimori
# ..                                    ...   ...           ...        ...
# 813          (ningún, demócrata, debería)     1        ningún  demócrata
# 814           (demócrata, debería, abrir)     1     demócrata    debería
# 815             (venezuela, además, cita)     1     venezuela     además
# 816              (vladimir, lenin, fidel)     1      vladimir      lenin
# 817                (lenin, fidel, castro)     1         lenin      fidel
#
#       palabra 3
# 0    ciudadanos
# 1        aliaga
# 2         pedro
# 3      castillo
# 4        fuerza
# ..          ...
# 813     debería
# 814       abrir
# 815        cita
# 816       fidel
# 817      castro
#
# [818 rows x 5 columns]

# %%
filtered_trigrams = trigramsCount_EC[trigramsCount_EC['peso'] >= 2]

# %%
import pandas as pd
import networkx as nx

# Preparar el DataFrame para NetworkX
edges = pd.concat([
    filtered_trigrams[['palabra 1', 'palabra 2', 'peso']].rename(columns={'palabra 1': 'source', 'palabra 2': 'target'}),
    filtered_trigrams[['palabra 2', 'palabra 3', 'peso']].rename(columns={'palabra 2': 'source', 'palabra 3': 'target'})
])

# Crear el grafo desde el DataFrame de aristas
G_trigram_EC = nx.from_pandas_edgelist(df=edges, source='source', target='target', edge_attr=["peso"])

# %%
nx.draw_networkx(G_trigram_EC)

# %%
import matplotlib.pyplot as plt

pos = nx.spring_layout(G_trigram_EC, k=0.4, iterations=40)  # Ajusta k para cambiar la distancia entre nodos
nx.draw_networkx(G_trigram_EC, pos, font_size=6)
plt.show()

# %% [markdown]
# # Reto: 4-gramas

# %%
the4grams_EC = [list(ngrams(eachTW.split(), 4)) for eachTW in df_textos['texto']]

# %%
tetraWords_EC = list(chain(*the4grams_EC))
tetraWords_EC
# Out:
# [('la', 'segunda', 'vuelta', 'no'),
#  ('segunda', 'vuelta', 'no', 'es'),
#  ('vuelta', 'no', 'es', 'un'),
#  ('no', 'es', 'un', 'proceso'),
#  ('es', 'un', 'proceso', 'de'),
#  ('un', 'proceso', 'de', 'definiciones'),
#  ('proceso', 'de', 'definiciones', 'políticas'),
#  ('de', 'definiciones', 'políticas', 'que'),
#  ('definiciones', 'políticas', 'que', 'compromete'),
#  ('políticas', 'que', 'compromete', 'solo'),
#  ('que', 'compromete', 'solo', 'a'),
#  ('compromete', 'solo', 'a', 'los'),
#  ('solo', 'a', 'los', 'dos'),
#  ('a', 'los', 'dos', 'candidatos'),
#  ('los', 'dos', 'candidatos', 'que'),
#  ('dos', 'candidatos', 'que', 'continúan'),
#  ('candidatos', 'que', 'continúan', 'compitiendo'),
#  ('que', 'continúan', 'compitiendo', 'por'),
#  ('continúan', 'compitiendo', 'por', 'acceder'),
#  ('compitiendo', 'por', 'acceder', 'a'),
#  ('por', 'acceder', 'a', 'la'),
#  ('acceder', 'a', 'la', 'presidencia'),
#  ('a', 'la', 'presidencia', 'o'),
#  ('la', 'presidencia', 'o', 'a'),
#  ('presidencia', 'o', 'a', 'sus'),
#  ('o', 'a', 'sus', 'partidos'),
#  ('a', 'sus', 'partidos', 'también'),
#  ('sus', 'partidos', 'también', 'los'),
#  ('partidos', 'también', 'los', 'postulantes'),
#  ('también', 'los', 'postulantes', 'que'),
#  ('los', 'postulantes', 'que', 'quedaron'),
#  ('postulantes', 'que', 'quedaron', 'fuera'),
#  ('que', 'quedaron', 'fuera', 'de'),
#  ('quedaron', 'fuera', 'de', 'carrera'),
#  ('fuera', 'de', 'carrera', 'tras'),
#  ('de', 'carrera', 'tras', 'la'),
#  ('carrera', 'tras', 'la', 'votación'),
#  ('tras', 'la', 'votación', 'del'),
#  ('la', 'votación', 'del', '11'),
#  ('votación', 'del', '11', 'de'),
#  ('del', '11', 'de', 'abril'),
#  ('11', 'de', 'abril', 'tienen'),
#  ('de', 'abril', 'tienen', 'responsabilidades'),
#  ('abril', 'tienen', 'responsabilidades', 'que'),
#  ('tienen', 'responsabilidades', 'que', 'no'),
#  ('responsabilidades', 'que', 'no', 'deberían'),
#  ('que', 'no', 'deberían', 'eludir'),
#  ('no', 'deberían', 'eludir', 'en'),
#  ('deberían', 'eludir', 'en', 'la'),
#  ('eludir', 'en', 'la', 'medida'),
#  ('en', 'la', 'medida', 'en'),
#  ('la', 'medida', 'en', 'que'),
#  ('medida', 'en', 'que', 'representaron'),
#  ('en', 'que', 'representaron', 'a'),
#  ('que', 'representaron', 'a', 'determinados'),
#  ('representaron', 'a', 'determinados', 'sectores'),
#  ('a', 'determinados', 'sectores', 'ciudadanos'),
#  ('determinados', 'sectores', 'ciudadanos', 'en'),
#  ('sectores', 'ciudadanos', 'en', 'la'),
#  ('ciudadanos', 'en', 'la', 'primera'),
#  ('en', 'la', 'primera', 'etapa'),
#  ('la', 'primera', 'etapa', 'de'),
#  ('primera', 'etapa', 'de', 'la'),
#  ('etapa', 'de', 'la', 'contienda'),
#  ('de', 'la', 'contienda', 'les'),
#  ('la', 'contienda', 'les', 'corresponde'),
#  ('contienda', 'les', 'corresponde', 'efectivamente'),
#  ('les', 'corresponde', 'efectivamente', 'velar'),
#  ('corresponde', 'efectivamente', 'velar', 'por'),
#  ('efectivamente', 'velar', 'por', 'lo'),
#  ('velar', 'por', 'lo', 'que'),
#  ('por', 'lo', 'que', 'suceda'),
#  ('lo', 'que', 'suceda', 'con'),
#  ('que', 'suceda', 'con', 'los'),
#  ('suceda', 'con', 'los', 'intereses'),
#  ('con', 'los', 'intereses', 'y'),
#  ('los', 'intereses', 'y', 'valores'),
#  ('intereses', 'y', 'valores', 'de'),
#  ('y', 'valores', 'de', 'tales'),
#  ('valores', 'de', 'tales', 'sectores'),
#  ('de', 'tales', 'sectores', 'en'),
#  ('tales', 'sectores', 'en', 'la'),
#  ('sectores', 'en', 'la', 'segunda'),
#  ('en', 'la', 'segunda', 'algunos'),
#  ('la', 'segunda', 'algunos', 'de'),
#  ('segunda', 'algunos', 'de', 'ellos'),
#  ('algunos', 'de', 'ellos', 'sin'),
#  ('de', 'ellos', 'sin', 'embargo'),
#  ('ellos', 'sin', 'embargo', 'dolidos'),
#  ('sin', 'embargo', 'dolidos', 'por'),
#  ('embargo', 'dolidos', 'por', 'las'),
#  ('dolidos', 'por', 'las', 'noticias'),
#  ('por', 'las', 'noticias', 'que'),
#  ('las', 'noticias', 'que', 'les'),
#  ('noticias', 'que', 'les', 'trajo'),
#  ('que', 'les', 'trajo', 'el'),
#  ('les', 'trajo', 'el', 'conteo'),
#  ('trajo', 'el', 'conteo', 'de'),
#  ('el', 'conteo', 'de', 'votos'),
#  ('conteo', 'de', 'votos', 'o'),
#  ('de', 'votos', 'o', 'temerosos'),
#  ('votos', 'o', 'temerosos', 'de'),
#  ('o', 'temerosos', 'de', 'perjudicarse'),
#  ('temerosos', 'de', 'perjudicarse', 'si'),
#  ('de', 'perjudicarse', 'si', 'se'),
#  ('perjudicarse', 'si', 'se', 'involucran'),
#  ('si', 'se', 'involucran', 'demasiado'),
#  ('se', 'involucran', 'demasiado', 'en'),
#  ('involucran', 'demasiado', 'en', 'el'),
#  ('demasiado', 'en', 'el', 'respaldo'),
#  ('en', 'el', 'respaldo', 'o'),
#  ('el', 'respaldo', 'o', 'rechazo'),
#  ('respaldo', 'o', 'rechazo', 'a'),
#  ('o', 'rechazo', 'a', 'las'),
#  ('rechazo', 'a', 'las', 'posiciones'),
#  ('a', 'las', 'posiciones', 'de'),
#  ('las', 'posiciones', 'de', 'los'),
#  ('posiciones', 'de', 'los', 'dos'),
#  ('de', 'los', 'dos', 'aspirantes'),
#  ('los', 'dos', 'aspirantes', 'todavía'),
#  ('dos', 'aspirantes', 'todavía', 'en'),
#  ('aspirantes', 'todavía', 'en', 'liza'),
#  ('todavía', 'en', 'liza', 'prefieren'),
#  ('en', 'liza', 'prefieren', 'ignorar'),
#  ('liza', 'prefieren', 'ignorar', 'las'),
#  ('prefieren', 'ignorar', 'las', 'demandas'),
#  ('ignorar', 'las', 'demandas', 'que'),
#  ('las', 'demandas', 'que', 'la'),
#  ('demandas', 'que', 'la', 'situación'),
#  ('que', 'la', 'situación', 'les'),
#  ('la', 'situación', 'les', 'plantea'),
#  ('situación', 'les', 'plantea', 'no'),
#  ('les', 'plantea', 'no', 'se'),
#  ('plantea', 'no', 'se', 'trata'),
#  ('no', 'se', 'trata', 'por'),
#  ('se', 'trata', 'por', 'cierto'),
#  ('trata', 'por', 'cierto', 'de'),
#  ('por', 'cierto', 'de', 'que'),
#  ('cierto', 'de', 'que', 'forzosamente'),
#  ('de', 'que', 'forzosamente', 'endosen'),
#  ('que', 'forzosamente', 'endosen', 'una'),
#  ('forzosamente', 'endosen', 'una', 'candidatura'),
#  ('endosen', 'una', 'candidatura', 'o'),
#  ('una', 'candidatura', 'o', 'la'),
#  ('candidatura', 'o', 'la', 'otra'),
#  ('o', 'la', 'otra', 'sino'),
#  ('la', 'otra', 'sino', 'de'),
#  ('otra', 'sino', 'de', 'que'),
#  ('sino', 'de', 'que', 'señalen'),
#  ('de', 'que', 'señalen', 'los'),
#  ('que', 'señalen', 'los', 'riesgos'),
#  ('señalen', 'los', 'riesgos', 'que'),
#  ('los', 'riesgos', 'que', 'cada'),
#  ('riesgos', 'que', 'cada', 'una'),
#  ('que', 'cada', 'una', 'de'),
#  ('cada', 'una', 'de', 'ellas'),
#  ('una', 'de', 'ellas', 'entraña'),
#  ('de', 'ellas', 'entraña', 'para'),
#  ('ellas', 'entraña', 'para', 'orientar'),
#  ('entraña', 'para', 'orientar', 'de'),
#  ('para', 'orientar', 'de', 'esa'),
#  ('orientar', 'de', 'esa', 'manera'),
#  ('de', 'esa', 'manera', 'a'),
#  ('esa', 'manera', 'a', 'quienes'),
#  ('manera', 'a', 'quienes', 'confiaron'),
#  ('a', 'quienes', 'confiaron', 'en'),
#  ('quienes', 'confiaron', 'en', 'ellos'),
#  ('confiaron', 'en', 'ellos', 'en'),
#  ('en', 'ellos', 'en', 'la'),
#  ('ellos', 'en', 'la', 'primera'),
#  ('en', 'la', 'primera', 'vuelta'),
#  ('la', 'primera', 'vuelta', 'en'),
#  ('primera', 'vuelta', 'en', 'eso'),
#  ('vuelta', 'en', 'eso', 'consiste'),
#  ('en', 'eso', 'consiste', 'precisamente'),
#  ('eso', 'consiste', 'precisamente', 'la'),
#  ('consiste', 'precisamente', 'la', 'tarea'),
#  ('precisamente', 'la', 'tarea', 'de'),
#  ('la', 'tarea', 'de', 'un'),
#  ('tarea', 'de', 'un', 'líder'),
#  ('de', 'un', 'líder', 'político'),
#  ('un', 'líder', 'político', 'en'),
#  ('líder', 'político', 'en', 'liderar'),
#  ('político', 'en', 'liderar', 'en'),
#  ('en', 'liderar', 'en', 'ese'),
#  ('liderar', 'en', 'ese', 'sentido'),
#  ('en', 'ese', 'sentido', 'el'),
#  ('ese', 'sentido', 'el', 'eventual'),
#  ('sentido', 'el', 'eventual', 'respaldo'),
#  ('el', 'eventual', 'respaldo', 'a'),
#  ('eventual', 'respaldo', 'a', 'una'),
#  ('respaldo', 'a', 'una', 'de'),
#  ('a', 'una', 'de', 'las'),
#  ('una', 'de', 'las', 'dos'),
#  ('de', 'las', 'dos', 'opciones'),
#  ('las', 'dos', 'opciones', 'en'),
#  ('dos', 'opciones', 'en', 'disputa'),
#  ('opciones', 'en', 'disputa', 'debería'),
#  ('en', 'disputa', 'debería', 'ser'),
#  ('disputa', 'debería', 'ser', 'para'),
#  ('debería', 'ser', 'para', 'los'),
#  ('ser', 'para', 'los', 'excandidatos'),
#  ('para', 'los', 'excandidatos', 'un'),
#  ('los', 'excandidatos', 'un', 'corolario'),
#  ('excandidatos', 'un', 'corolario', 'y'),
#  ('un', 'corolario', 'y', 'no'),
#  ('corolario', 'y', 'no', 'una'),
#  ('y', 'no', 'una', 'premisa'),
#  ('no', 'una', 'premisa', 'lamentablemente'),
#  ('una', 'premisa', 'lamentablemente', 'lo'),
#  ('premisa', 'lamentablemente', 'lo', 'que'),
#  ('lamentablemente', 'lo', 'que', 'estamos'),
#  ('lo', 'que', 'estamos', 'viendo'),
#  ('que', 'estamos', 'viendo', 'en'),
#  ('estamos', 'viendo', 'en', 'una'),
#  ('viendo', 'en', 'una', 'mayoría'),
#  ('en', 'una', 'mayoría', 'de'),
#  ('una', 'mayoría', 'de', 'casos'),
#  ('mayoría', 'de', 'casos', 'no'),
#  ('de', 'casos', 'no', 'se'),
#  ('casos', 'no', 'se', 'ajusta'),
#  ('no', 'se', 'ajusta', 'a'),
#  ('se', 'ajusta', 'a', 'esa'),
#  ('ajusta', 'a', 'esa', 'descripción'),
#  ('a', 'esa', 'descripción', 'o'),
#  ('esa', 'descripción', 'o', 'bien'),
#  ('descripción', 'o', 'bien', 'el'),
#  ('o', 'bien', 'el', 'endose'),
#  ('bien', 'el', 'endose', 'se'),
#  ('el', 'endose', 'se', 'ha'),
#  ('endose', 'se', 'ha', 'producido'),
#  ('se', 'ha', 'producido', 'de'),
#  ('ha', 'producido', 'de', 'manera'),
#  ('producido', 'de', 'manera', 'sumaria'),
#  ('de', 'manera', 'sumaria', 'y'),
#  ('manera', 'sumaria', 'y', 'sin'),
#  ('sumaria', 'y', 'sin', 'acompañarlo'),
#  ('y', 'sin', 'acompañarlo', 'luego'),
#  ('sin', 'acompañarlo', 'luego', 'de'),
#  ('acompañarlo', 'luego', 'de', 'una'),
#  ('luego', 'de', 'una', 'crítica'),
#  ('de', 'una', 'crítica', 'a'),
#  ('una', 'crítica', 'a', 'los'),
#  ('crítica', 'a', 'los', 'asuntos'),
#  ('a', 'los', 'asuntos', 'en'),
#  ('los', 'asuntos', 'en', 'los'),
#  ('asuntos', 'en', 'los', 'que'),
#  ('en', 'los', 'que', 'los'),
#  ('los', 'que', 'los', 'votantes'),
#  ('que', 'los', 'votantes', 'del'),
#  ('los', 'votantes', 'del', 'expostulante'),
#  ('votantes', 'del', 'expostulante', 'que'),
#  ('del', 'expostulante', 'que', 'lo'),
#  ('expostulante', 'que', 'lo', 'ha'),
#  ('que', 'lo', 'ha', 'otorgado'),
#  ('lo', 'ha', 'otorgado', 'podrían'),
#  ('ha', 'otorgado', 'podrían', 'sentirse'),
#  ('otorgado', 'podrían', 'sentirse', 'defraudados'),
#  ('podrían', 'sentirse', 'defraudados', 'o'),
#  ('sentirse', 'defraudados', 'o', 'bien'),
#  ('defraudados', 'o', 'bien', 'la'),
#  ('o', 'bien', 'la', 'imposibilidad'),
#  ('bien', 'la', 'imposibilidad', 'de'),
#  ('la', 'imposibilidad', 'de', 'renunciar'),
#  ('imposibilidad', 'de', 'renunciar', 'al'),
#  ('de', 'renunciar', 'al', 'protagonismo'),
#  ('renunciar', 'al', 'protagonismo', 'alcanzado'),
#  ('al', 'protagonismo', 'alcanzado', 'en'),
#  ('protagonismo', 'alcanzado', 'en', 'la'),
#  ('alcanzado', 'en', 'la', 'primera'),
#  ('en', 'la', 'primera', 'parte'),
#  ('la', 'primera', 'parte', 'de'),
#  ('primera', 'parte', 'de', 'la'),
#  ('parte', 'de', 'la', 'campaña'),
#  ('de', 'la', 'campaña', 'se'),
#  ('la', 'campaña', 'se', 'convierte'),
#  ('campaña', 'se', 'convierte', 'en'),
#  ('se', 'convierte', 'en', 'un'),
#  ('convierte', 'en', 'un', 'obstáculo'),
#  ('en', 'un', 'obstáculo', 'para'),
#  ('un', 'obstáculo', 'para', 'que'),
#  ('obstáculo', 'para', 'que', 'el'),
#  ('para', 'que', 'el', 'expostulante'),
#  ('que', 'el', 'expostulante', 'ejerza'),
#  ('el', 'expostulante', 'ejerza', 'eficazmente'),
#  ('expostulante', 'ejerza', 'eficazmente', 'la'),
#  ('ejerza', 'eficazmente', 'la', 'crítica'),
#  ('eficazmente', 'la', 'crítica', 'o'),
#  ('la', 'crítica', 'o', 'el'),
#  ('crítica', 'o', 'el', 'apoyo'),
#  ('o', 'el', 'apoyo', 'según'),
#  ('el', 'apoyo', 'según', 'dicte'),
#  ('apoyo', 'según', 'dicte', 'la'),
#  ('según', 'dicte', 'la', 'coherencia'),
#  ('dicte', 'la', 'coherencia', 'con'),
#  ('la', 'coherencia', 'con', 'las'),
#  ('coherencia', 'con', 'las', 'líneas'),
#  ('con', 'las', 'líneas', 'generales'),
#  ('las', 'líneas', 'generales', 'de'),
#  ('líneas', 'generales', 'de', 'lo'),
#  ('generales', 'de', 'lo', 'que'),
#  ('de', 'lo', 'que', 'le'),
#  ('lo', 'que', 'le', 'ofreció'),
#  ('que', 'le', 'ofreció', 'al'),
#  ('le', 'ofreció', 'al', 'país'),
#  ('ofreció', 'al', 'país', 'mientras'),
#  ('al', 'país', 'mientras', 'era'),
#  ('país', 'mientras', 'era', 'uno'),
#  ('mientras', 'era', 'uno', 'de'),
#  ('era', 'uno', 'de', 'los'),
#  ('uno', 'de', 'los', 'participantes'),
#  ('de', 'los', 'participantes', 'del'),
#  ('los', 'participantes', 'del', 'proceso'),
#  ('participantes', 'del', 'proceso', 'verónika'),
#  ('del', 'proceso', 'verónika', 'mendoza'),
#  ('proceso', 'verónika', 'mendoza', 'es'),
#  ('verónika', 'mendoza', 'es', 'de'),
#  ('mendoza', 'es', 'de', 'hecho'),
#  ('es', 'de', 'hecho', 'un'),
#  ('de', 'hecho', 'un', 'buen'),
#  ('hecho', 'un', 'buen', 'ejemplo'),
#  ('un', 'buen', 'ejemplo', 'de'),
#  ('buen', 'ejemplo', 'de', 'lo'),
#  ('ejemplo', 'de', 'lo', 'primero'),
#  ('de', 'lo', 'primero', 'mientras'),
#  ('lo', 'primero', 'mientras', 'que'),
#  ('primero', 'mientras', 'que', 'hernando'),
#  ('mientras', 'que', 'hernando', 'de'),
#  ('que', 'hernando', 'de', 'soto'),
#  ('hernando', 'de', 'soto', 'lo'),
#  ('de', 'soto', 'lo', 'es'),
#  ('soto', 'lo', 'es', 'de'),
#  ('lo', 'es', 'de', 'lo'),
#  ('es', 'de', 'lo', 'segundo'),
#  ('de', 'lo', 'segundo', 'la'),
#  ('lo', 'segundo', 'la', 'excandidata'),
#  ('segundo', 'la', 'excandidata', 'presidencial'),
#  ('la', 'excandidata', 'presidencial', 'de'),
#  ('excandidata', 'presidencial', 'de', 'juntos'),
#  ('presidencial', 'de', 'juntos', 'por'),
#  ('de', 'juntos', 'por', 'el'),
#  ('juntos', 'por', 'el', 'perú'),
#  ('por', 'el', 'perú', 'como'),
#  ('el', 'perú', 'como', 'se'),
#  ('perú', 'como', 'se', 'sabe'),
#  ('como', 'se', 'sabe', 'anunció'),
#  ('se', 'sabe', 'anunció', 'muy'),
#  ('sabe', 'anunció', 'muy', 'rápidamente'),
#  ('anunció', 'muy', 'rápidamente', 'que'),
#  ('muy', 'rápidamente', 'que', 'ella'),
#  ('rápidamente', 'que', 'ella', 'y'),
#  ('que', 'ella', 'y', 'la'),
#  ('ella', 'y', 'la', 'organización'),
#  ('y', 'la', 'organización', 'política'),
#  ('la', 'organización', 'política', 'que'),
#  ('organización', 'política', 'que', 'la'),
#  ('política', 'que', 'la', 'postuló'),
#  ('que', 'la', 'postuló', 'apoyarán'),
#  ('la', 'postuló', 'apoyarán', 'en'),
#  ('postuló', 'apoyarán', 'en', 'esta'),
#  ('apoyarán', 'en', 'esta', 'segunda'),
#  ('en', 'esta', 'segunda', 'vuelta'),
#  ('esta', 'segunda', 'vuelta', 'a'),
#  ('segunda', 'vuelta', 'a', 'pedro'),
#  ('vuelta', 'a', 'pedro', 'castillo'),
#  ('a', 'pedro', 'castillo', 'una'),
#  ('pedro', 'castillo', 'una', 'consecuencia'),
#  ('castillo', 'una', 'consecuencia', 'previsible'),
#  ('una', 'consecuencia', 'previsible', 'de'),
#  ('consecuencia', 'previsible', 'de', 'la'),
#  ('previsible', 'de', 'la', 'sintonía'),
#  ('de', 'la', 'sintonía', 'que'),
#  ('la', 'sintonía', 'que', 'guarda'),
#  ('sintonía', 'que', 'guarda', 'con'),
#  ('que', 'guarda', 'con', 'los'),
#  ('guarda', 'con', 'los', 'planes'),
#  ('con', 'los', 'planes', 'estatistas'),
#  ('los', 'planes', 'estatistas', 'de'),
#  ('planes', 'estatistas', 'de', 'perú'),
#  ('estatistas', 'de', 'perú', 'libre'),
#  ('de', 'perú', 'libre', 'y'),
#  ('perú', 'libre', 'y', 'su'),
#  ('libre', 'y', 'su', 'simpatía'),
#  ('y', 'su', 'simpatía', 'por'),
#  ('su', 'simpatía', 'por', 'los'),
#  ('simpatía', 'por', 'los', 'regímenes'),
#  ('por', 'los', 'regímenes', 'totalitarios'),
#  ('los', 'regímenes', 'totalitarios', 'del'),
#  ('regímenes', 'totalitarios', 'del', 'continente'),
#  ('totalitarios', 'del', 'continente', 'frente'),
#  ('del', 'continente', 'frente', 'a'),
#  ('continente', 'frente', 'a', 'los'),
#  ('frente', 'a', 'los', 'anuncios'),
#  ('a', 'los', 'anuncios', 'de'),
#  ('los', 'anuncios', 'de', '“desactivación”'),
#  ('anuncios', 'de', '“desactivación”', 'de'),
#  ('de', '“desactivación”', 'de', 'la'),
#  ('“desactivación”', 'de', 'la', 'defensoría'),
#  ('de', 'la', 'defensoría', 'del'),
#  ('la', 'defensoría', 'del', 'pueblo'),
#  ('defensoría', 'del', 'pueblo', 'o'),
#  ('del', 'pueblo', 'o', 'la'),
#  ('pueblo', 'o', 'la', 'atu'),
#  ('o', 'la', 'atu', 'o'),
#  ('la', 'atu', 'o', 'de'),
#  ('atu', 'o', 'de', 'intervención'),
#  ('o', 'de', 'intervención', 'en'),
#  ('de', 'intervención', 'en', 'la'),
#  ('intervención', 'en', 'la', 'labor'),
#  ('en', 'la', 'labor', 'que'),
#  ('la', 'labor', 'que', 'viene'),
#  ('labor', 'que', 'viene', 'llevando'),
#  ('que', 'viene', 'llevando', 'adelante'),
#  ('viene', 'llevando', 'adelante', 'la'),
#  ('llevando', 'adelante', 'la', 'sunedu'),
#  ('adelante', 'la', 'sunedu', 'no'),
#  ('la', 'sunedu', 'no', 'obstante'),
#  ('sunedu', 'no', 'obstante', 'verónika'),
#  ('no', 'obstante', 'verónika', 'mendoza'),
#  ('obstante', 'verónika', 'mendoza', 'no'),
#  ('verónika', 'mendoza', 'no', 'ha'),
#  ('mendoza', 'no', 'ha', 'dicho'),
#  ('no', 'ha', 'dicho', 'nada'),
#  ('ha', 'dicho', 'nada', '¿debemos'),
#  ('dicho', 'nada', '¿debemos', 'entender'),
#  ('nada', '¿debemos', 'entender', 'que'),
#  ('¿debemos', 'entender', 'que', 'está'),
#  ('entender', 'que', 'está', 'conforme'),
#  ('que', 'está', 'conforme', 'con'),
#  ('está', 'conforme', 'con', 'los'),
#  ('conforme', 'con', 'los', 'planes'),
#  ('con', 'los', 'planes', 'de'),
#  ('los', 'planes', 'de', 'castillo'),
#  ('planes', 'de', 'castillo', 'al'),
#  ('de', 'castillo', 'al', 'respecto'),
#  ('castillo', 'al', 'respecto', 'o'),
#  ('al', 'respecto', 'o', 'que'),
#  ('respecto', 'o', 'que', 'sencillamente'),
#  ('o', 'que', 'sencillamente', 'prefiere'),
#  ('que', 'sencillamente', 'prefiere', 'callar'),
#  ('sencillamente', 'prefiere', 'callar', 'para'),
#  ('prefiere', 'callar', 'para', 'no'),
#  ('callar', 'para', 'no', 'afectar'),
#  ('para', 'no', 'afectar', 'las'),
#  ('no', 'afectar', 'las', 'chances'),
#  ('afectar', 'las', 'chances', 'de'),
#  ('las', 'chances', 'de', 'la'),
#  ('chances', 'de', 'la', 'izquierda'),
#  ('de', 'la', 'izquierda', 'el'),
#  ('la', 'izquierda', 'el', '6'),
#  ('izquierda', 'el', '6', 'de'),
#  ('el', '6', 'de', 'junio'),
#  ('6', 'de', 'junio', 'hernando'),
#  ('de', 'junio', 'hernando', 'de'),
#  ('junio', 'hernando', 'de', 'soto'),
#  ('hernando', 'de', 'soto', 'por'),
#  ('de', 'soto', 'por', 'otro'),
#  ('soto', 'por', 'otro', 'lado'),
#  ('por', 'otro', 'lado', 'luce'),
#  ('otro', 'lado', 'luce', 'más'),
#  ('lado', 'luce', 'más', 'interesado'),
#  ('luce', 'más', 'interesado', 'en'),
#  ('más', 'interesado', 'en', 'tener'),
#  ('interesado', 'en', 'tener', 'un'),
#  ('en', 'tener', 'un', 'rol'),
#  ('tener', 'un', 'rol', 'estelar'),
#  ('un', 'rol', 'estelar', 'en'),
#  ('rol', 'estelar', 'en', 'la'),
#  ('estelar', 'en', 'la', 'segunda'),
#  ('en', 'la', 'segunda', 'vuelta'),
#  ('la', 'segunda', 'vuelta', 'que'),
#  ('segunda', 'vuelta', 'que', 'en'),
#  ('vuelta', 'que', 'en', 'ayudar'),
#  ('que', 'en', 'ayudar', 'a'),
#  ('en', 'ayudar', 'a', 'sus'),
#  ('ayudar', 'a', 'sus', 'antiguos'),
#  ('a', 'sus', 'antiguos', 'adherentes'),
#  ('sus', 'antiguos', 'adherentes', 'a'),
#  ('antiguos', 'adherentes', 'a', 'decidir'),
#  ('adherentes', 'a', 'decidir', 'qué'),
#  ('a', 'decidir', 'qué', 'hacer'),
#  ('decidir', 'qué', 'hacer', 'ahora'),
#  ('qué', 'hacer', 'ahora', 'con'),
#  ('hacer', 'ahora', 'con', 'su'),
#  ('ahora', 'con', 'su', 'voto'),
#  ('con', 'su', 'voto', '“estoy'),
#  ('su', 'voto', '“estoy', 'proponiendo'),
#  ('voto', '“estoy', 'proponiendo', 'a'),
#  ('“estoy', 'proponiendo', 'a', 'la'),
#  ('proponiendo', 'a', 'la', 'candidata'),
#  ('a', 'la', 'candidata', 'fujimori'),
#  ('la', 'candidata', 'fujimori', 'una'),
#  ('candidata', 'fujimori', 'una', 'fórmula'),
#  ('fujimori', 'una', 'fórmula', 'para'),
#  ('una', 'fórmula', 'para', 'que'),
#  ('fórmula', 'para', 'que', 'su'),
#  ('para', 'que', 'su', 'propuesta'),
#  ('que', 'su', 'propuesta', 'sea'),
#  ('su', 'propuesta', 'sea', 'inclusiva'),
#  ('propuesta', 'sea', 'inclusiva', 'y'),
#  ('sea', 'inclusiva', 'y', 'no'),
#  ('inclusiva', 'y', 'no', 'mercantilista'),
#  ('y', 'no', 'mercantilista', 'y'),
#  ('no', 'mercantilista', 'y', 'al'),
#  ('mercantilista', 'y', 'al', 'candidato'),
#  ('y', 'al', 'candidato', 'castillo'),
#  ('al', 'candidato', 'castillo', 'otra'),
#  ('candidato', 'castillo', 'otra', 'fórmula'),
#  ('castillo', 'otra', 'fórmula', 'para'),
#  ('otra', 'fórmula', 'para', 'que'),
#  ('fórmula', 'para', 'que', 'no'),
#  ('para', 'que', 'no', 'se'),
#  ('que', 'no', 'se', 'politice'),
#  ('no', 'se', 'politice', 'la'),
#  ('se', 'politice', 'la', 'economía'),
#  ('politice', 'la', 'economía', 'dentro'),
#  ('la', 'economía', 'dentro', 'de'),
#  ('economía', 'dentro', 'de', 'un'),
#  ('dentro', 'de', 'un', 'régimen'),
#  ('de', 'un', 'régimen', 'comunista”'),
#  ('un', 'régimen', 'comunista”', 'ha'),
#  ('régimen', 'comunista”', 'ha', 'escrito'),
#  ('comunista”', 'ha', 'escrito', 'en'),
#  ('ha', 'escrito', 'en', 'un'),
#  ('escrito', 'en', 'un', 'comunicado'),
#  ('en', 'un', 'comunicado', 'divulgado'),
#  ('un', 'comunicado', 'divulgado', 'ayer'),
#  ('comunicado', 'divulgado', 'ayer', '¿debemos'),
#  ('divulgado', 'ayer', '¿debemos', 'entender'),
#  ('ayer', '¿debemos', 'entender', 'acaso'),
#  ('¿debemos', 'entender', 'acaso', 'que'),
#  ('entender', 'acaso', 'que', 'solo'),
#  ('acaso', 'que', 'solo', 'el'),
#  ('que', 'solo', 'el', 'que'),
#  ('solo', 'el', 'que', 'le'),
#  ('el', 'que', 'le', 'dé'),
#  ('que', 'le', 'dé', 'la'),
#  ('le', 'dé', 'la', 'razón'),
#  ('dé', 'la', 'razón', 'obtendrá'),
#  ('la', 'razón', 'obtendrá', 'la'),
#  ('razón', 'obtendrá', 'la', 'gracia'),
#  ('obtendrá', 'la', 'gracia', 'de'),
#  ('la', 'gracia', 'de', 'su'),
#  ('gracia', 'de', 'su', 'voto'),
#  ('de', 'su', 'voto', 'en'),
#  ('su', 'voto', 'en', 'los'),
#  ('voto', 'en', 'los', 'predios'),
#  ('en', 'los', 'predios', 'de'),
#  ('los', 'predios', 'de', 'avanza'),
#  ('predios', 'de', 'avanza', 'país'),
#  ('de', 'avanza', 'país', 'mientras'),
#  ('avanza', 'país', 'mientras', 'tanto'),
#  ('país', 'mientras', 'tanto', 'parece'),
#  ('mientras', 'tanto', 'parece', 'existir'),
#  ('tanto', 'parece', 'existir', 'la'),
#  ('parece', 'existir', 'la', 'impresión'),
#  ('existir', 'la', 'impresión', 'de'),
#  ('la', 'impresión', 'de', 'que'),
#  ('impresión', 'de', 'que', 'las'),
#  ('de', 'que', 'las', 'urgencias'),
#  ('que', 'las', 'urgencias', 'son'),
#  ('las', 'urgencias', 'son', 'otras'),
#  ('urgencias', 'son', 'otras', 'pues'),
#  ('son', 'otras', 'pues', 'la'),
#  ('otras', 'pues', 'la', 'mayoría'),
#  ('pues', 'la', 'mayoría', 'de'),
#  ('la', 'mayoría', 'de', 'los'),
#  ('mayoría', 'de', 'los', 'congresistas'),
#  ('de', 'los', 'congresistas', 'elegidos'),
#  ('los', 'congresistas', 'elegidos', 'en'),
#  ('congresistas', 'elegidos', 'en', 'sus'),
#  ('elegidos', 'en', 'sus', 'listas'),
#  ('en', 'sus', 'listas', 'ya'),
#  ('sus', 'listas', 'ya', 'anunció'),
#  ('listas', 'ya', 'anunció', 'que'),
#  ('ya', 'anunció', 'que', 'votará'),
#  ('anunció', 'que', 'votará', '“contra'),
#  ('que', 'votará', '“contra', 'el'),
#  ('votará', '“contra', 'el', 'comunismo”'),
#  ('“contra', 'el', 'comunismo”', 'y'),
#  ('el', 'comunismo”', 'y', 'el'),
#  ('comunismo”', 'y', 'el', 'canciller'),
#  ('y', 'el', 'canciller', 'francisco'),
#  ('el', 'canciller', 'francisco', 'tudela'),
#  ('canciller', 'francisco', 'tudela', 'hasta'),
#  ('francisco', 'tudela', 'hasta', 'hace'),
#  ('tudela', 'hasta', 'hace', 'poco'),
#  ('hasta', 'hace', 'poco', 'miembro'),
#  ('hace', 'poco', 'miembro', 'de'),
#  ('poco', 'miembro', 'de', 'su'),
#  ('miembro', 'de', 'su', '“gabinete'),
#  ('de', 'su', '“gabinete', 'en'),
#  ('su', '“gabinete', 'en', 'la'),
#  ('“gabinete', 'en', 'la', 'sombra”'),
#  ('en', 'la', 'sombra”', 'se'),
#  ('la', 'sombra”', 'se', 'ha'),
#  ('sombra”', 'se', 'ha', 'alejado'),
#  ('se', 'ha', 'alejado', 'del'),
#  ('ha', 'alejado', 'del', 'proyecto'),
#  ('alejado', 'del', 'proyecto', 'político'),
#  ('del', 'proyecto', 'político', 'conjunto'),
#  ('proyecto', 'político', 'conjunto', 'argumentando'),
#  ('político', 'conjunto', 'argumentando', 'que'),
#  ('conjunto', 'argumentando', 'que', '“en'),
#  ('argumentando', 'que', '“en', 'esta'),
#  ('que', '“en', 'esta', 'hora'),
#  ('“en', 'esta', 'hora', 'decisiva'),
#  ('esta', 'hora', 'decisiva', 'no'),
#  ('hora', 'decisiva', 'no', 'se'),
#  ('decisiva', 'no', 'se', 'puede'),
#  ('no', 'se', 'puede', 'ser'),
#  ('se', 'puede', 'ser', 'indeciso'),
#  ('puede', 'ser', 'indeciso', 'o'),
#  ('ser', 'indeciso', 'o', 'esperar'),
#  ('indeciso', 'o', 'esperar', 'a'),
#  ('o', 'esperar', 'a', 'ver'),
#  ('esperar', 'a', 'ver', 'quién'),
#  ('a', 'ver', 'quién', 'gana”'),
#  ('ver', 'quién', 'gana”', 'una'),
#  ('quién', 'gana”', 'una', 'severa'),
#  ('gana”', 'una', 'severa', 'llamada'),
#  ('una', 'severa', 'llamada', 'de'),
#  ('severa', 'llamada', 'de', 'atención'),
#  ('llamada', 'de', 'atención', 'en'),
#  ('de', 'atención', 'en', 'fin'),
#  ('atención', 'en', 'fin', 'para'),
#  ('en', 'fin', 'para', 'quien'),
#  ('fin', 'para', 'quien', 'al'),
#  ('para', 'quien', 'al', 'igual'),
#  ('quien', 'al', 'igual', 'que'),
#  ('al', 'igual', 'que', 'la'),
#  ('igual', 'que', 'la', 'señora'),
#  ('que', 'la', 'señora', 'mendoza'),
#  ('la', 'señora', 'mendoza', 'parecería'),
#  ('señora', 'mendoza', 'parecería', 'estar'),
#  ('mendoza', 'parecería', 'estar', 'dispuesto'),
#  ('parecería', 'estar', 'dispuesto', 'a'),
#  ('estar', 'dispuesto', 'a', 'actuar'),
#  ('dispuesto', 'a', 'actuar', 'como'),
#  ('a', 'actuar', 'como', 'un'),
#  ('actuar', 'como', 'un', 'convidado'),
#  ('como', 'un', 'convidado', 'de'),
#  ('un', 'convidado', 'de', 'piedra'),
#  ('convidado', 'de', 'piedra', 'en'),
#  ('de', 'piedra', 'en', 'esta'),
#  ('piedra', 'en', 'esta', 'segunda'),
#  ('en', 'esta', 'segunda', 'vuelta…'),
#  ('esta', 'segunda', 'vuelta…', 'a'),
#  ('segunda', 'vuelta…', 'a', 'menos'),
#  ('vuelta…', 'a', 'menos', 'que'),
#  ('a', 'menos', 'que', 'le'),
#  ('menos', 'que', 'le', 'concedan'),
#  ('que', 'le', 'concedan', 'el'),
#  ('le', 'concedan', 'el', 'centro'),
#  ('concedan', 'el', 'centro', 'del'),
#  ('el', 'centro', 'del', 'escenario'),
#  ('centro', 'del', 'escenario', 'todo'),
#  ('del', 'escenario', 'todo', 'indica'),
#  ('escenario', 'todo', 'indica', 'que'),
#  ('todo', 'indica', 'que', 'el'),
#  ('indica', 'que', 'el', 'desencanto'),
#  ('que', 'el', 'desencanto', 'de'),
#  ('el', 'desencanto', 'de', 'los'),
#  ('desencanto', 'de', 'los', 'ciudadanos'),
#  ('de', 'los', 'ciudadanos', 'con'),
#  ('los', 'ciudadanos', 'con', 'sus'),
#  ('ciudadanos', 'con', 'sus', 'líderes'),
#  ('con', 'sus', 'líderes', 'políticos'),
#  ('sus', 'líderes', 'políticos', 'tiene'),
#  ('líderes', 'políticos', 'tiene', 'una'),
#  ('políticos', 'tiene', 'una', 'explicación'),
#  ('tiene', 'una', 'explicación', 'fácil'),
#  ('una', 'explicación', 'fácil', 'pero'),
#  ('explicación', 'fácil', 'pero', 'una'),
#  ('fácil', 'pero', 'una', 'difícil'),
#  ('pero', 'una', 'difícil', 'solución'),
#  ('en', 'la', 'peor', 'de'),
#  ('la', 'peor', 'de', 'las'),
#  ('peor', 'de', 'las', 'condiciones'),
#  ('de', 'las', 'condiciones', 'posibles'),
#  ('las', 'condiciones', 'posibles', 'con'),
#  ('condiciones', 'posibles', 'con', 'una'),
#  ('posibles', 'con', 'una', 'pandemia'),
#  ('con', 'una', 'pandemia', 'que'),
#  ('una', 'pandemia', 'que', 'dificulta'),
#  ('pandemia', 'que', 'dificulta', 'el'),
#  ('que', 'dificulta', 'el', 'contacto'),
#  ('dificulta', 'el', 'contacto', 'entre'),
#  ('el', 'contacto', 'entre', 'las'),
#  ('contacto', 'entre', 'las', 'personas'),
#  ('entre', 'las', 'personas', 'los'),
#  ('las', 'personas', 'los', 'peruanos'),
#  ('personas', 'los', 'peruanos', 'acudimos'),
#  ('los', 'peruanos', 'acudimos', 'ayer'),
#  ('peruanos', 'acudimos', 'ayer', 'a'),
#  ('acudimos', 'ayer', 'a', 'las'),
#  ('ayer', 'a', 'las', 'urnas'),
#  ('a', 'las', 'urnas', 'para'),
#  ('las', 'urnas', 'para', 'ejercer'),
#  ('urnas', 'para', 'ejercer', 'el'),
#  ('para', 'ejercer', 'el', 'más'),
#  ('ejercer', 'el', 'más', 'fundamental'),
#  ('el', 'más', 'fundamental', 'de'),
#  ('más', 'fundamental', 'de', 'nuestros'),
#  ('fundamental', 'de', 'nuestros', 'derechos'),
#  ('de', 'nuestros', 'derechos', 'democráticos'),
#  ('nuestros', 'derechos', 'democráticos', 'elegir'),
#  ('derechos', 'democráticos', 'elegir', 'a'),
#  ('democráticos', 'elegir', 'a', 'quienes'),
#  ('elegir', 'a', 'quienes', 'liderarán'),
#  ('a', 'quienes', 'liderarán', 'nuestro'),
#  ('quienes', 'liderarán', 'nuestro', 'futuro'),
#  ('liderarán', 'nuestro', 'futuro', 'por'),
#  ('nuestro', 'futuro', 'por', 'cinco'),
#  ('futuro', 'por', 'cinco', 'años'),
#  ('por', 'cinco', 'años', 'la'),
#  ('cinco', 'años', 'la', 'jornada'),
#  ('años', 'la', 'jornada', 'empezó'),
#  ('la', 'jornada', 'empezó', 'de'),
#  ('jornada', 'empezó', 'de', 'manera'),
#  ('empezó', 'de', 'manera', 'accidentada'),
#  ('de', 'manera', 'accidentada', 'particularmente'),
#  ('manera', 'accidentada', 'particularmente', 'en'),
#  ('accidentada', 'particularmente', 'en', 'lima'),
#  ('particularmente', 'en', 'lima', 'donde'),
#  ('en', 'lima', 'donde', 'múltiples'),
#  ('lima', 'donde', 'múltiples', 'mesas'),
#  ('donde', 'múltiples', 'mesas', 'demoraron'),
#  ('múltiples', 'mesas', 'demoraron', 'en'),
#  ('mesas', 'demoraron', 'en', 'abrirse'),
#  ('demoraron', 'en', 'abrirse', 'por'),
#  ('en', 'abrirse', 'por', 'la'),
#  ('abrirse', 'por', 'la', 'ausencia'),
#  ('por', 'la', 'ausencia', 'de'),
#  ('la', 'ausencia', 'de', 'sus'),
#  ('ausencia', 'de', 'sus', 'miembros'),
#  ('de', 'sus', 'miembros', 'y'),
#  ('sus', 'miembros', 'y', 'con'),
#  ('miembros', 'y', 'con', 'largas'),
#  ('y', 'con', 'largas', 'colas'),
#  ('con', 'largas', 'colas', 'formándose'),
#  ('largas', 'colas', 'formándose', 'en'),
#  ('colas', 'formándose', 'en', 'el'),
#  ('formándose', 'en', 'el', 'exterior'),
#  ('en', 'el', 'exterior', 'de'),
#  ('el', 'exterior', 'de', 'los'),
#  ('exterior', 'de', 'los', 'locales'),
#  ('de', 'los', 'locales', 'de'),
#  ('los', 'locales', 'de', 'sufragio'),
#  ('locales', 'de', 'sufragio', 'aun'),
#  ('de', 'sufragio', 'aun', 'así'),
#  ('sufragio', 'aun', 'así', 'para'),
#  ('aun', 'así', 'para', 'alrededor'),
#  ('así', 'para', 'alrededor', 'de'),
#  ('para', 'alrededor', 'de', 'las'),
#  ('alrededor', 'de', 'las', 'dos'),
#  ('de', 'las', 'dos', 'de'),
#  ('las', 'dos', 'de', 'la'),
#  ('dos', 'de', 'la', 'tarde'),
#  ('de', 'la', 'tarde', 'el'),
#  ('la', 'tarde', 'el', '996'),
#  ('tarde', 'el', '996', 'de'),
#  ('el', '996', 'de', 'las'),
#  ('996', 'de', 'las', 'mesas'),
#  ('de', 'las', 'mesas', 'ya'),
#  ('las', 'mesas', 'ya', 'se'),
#  ('mesas', 'ya', 'se', 'habían'),
#  ('ya', 'se', 'habían', 'instalado'),
#  ('se', 'habían', 'instalado', 'gracias'),
#  ('habían', 'instalado', 'gracias', 'a'),
#  ('instalado', 'gracias', 'a', 'ciudadanos'),
#  ('gracias', 'a', 'ciudadanos', 'que'),
#  ('a', 'ciudadanos', 'que', 'se'),
#  ('ciudadanos', 'que', 'se', 'ofrecieron'),
#  ('que', 'se', 'ofrecieron', 'para'),
#  ('se', 'ofrecieron', 'para', 'suplir'),
#  ('ofrecieron', 'para', 'suplir', 'a'),
#  ('para', 'suplir', 'a', 'los'),
#  ('suplir', 'a', 'los', 'que'),
#  ('a', 'los', 'que', 'habían'),
#  ('los', 'que', 'habían', 'sido'),
#  ('que', 'habían', 'sido', 'asignados'),
#  ('habían', 'sido', 'asignados', 'y'),
#  ('sido', 'asignados', 'y', 'no'),
#  ('asignados', 'y', 'no', 'se'),
#  ('y', 'no', 'se', 'presentaron'),
#  ('no', 'se', 'presentaron', 'así'),
#  ('se', 'presentaron', 'así', 'las'),
#  ('presentaron', 'así', 'las', 'cosas'),
#  ('así', 'las', 'cosas', 'el'),
#  ('las', 'cosas', 'el', 'proceso'),
#  ('cosas', 'el', 'proceso', 'fluyó'),
#  ('el', 'proceso', 'fluyó', 'de'),
#  ('proceso', 'fluyó', 'de', 'forma'),
#  ('fluyó', 'de', 'forma', 'ordenada'),
#  ('de', 'forma', 'ordenada', 'y'),
#  ('forma', 'ordenada', 'y', 'sin'),
#  ('ordenada', 'y', 'sin', 'verdaderas'),
#  ('y', 'sin', 'verdaderas', 'sorpresas'),
#  ('sin', 'verdaderas', 'sorpresas', 'y'),
#  ('verdaderas', 'sorpresas', 'y', 'salvo'),
#  ('sorpresas', 'y', 'salvo', 'por'),
#  ('y', 'salvo', 'por', 'algunas'),
#  ('salvo', 'por', 'algunas', 'pocas'),
#  ('por', 'algunas', 'pocas', 'quejas'),
#  ('algunas', 'pocas', 'quejas', 'cuya'),
#  ('pocas', 'quejas', 'cuya', 'pertinencia'),
#  ('quejas', 'cuya', 'pertinencia', 'tendrá'),
#  ('cuya', 'pertinencia', 'tendrá', 'que'),
#  ('pertinencia', 'tendrá', 'que', 'ser'),
#  ('tendrá', 'que', 'ser', 'verificada'),
#  ('que', 'ser', 'verificada', 'ajustado'),
#  ('ser', 'verificada', 'ajustado', 'a'),
#  ('verificada', 'ajustado', 'a', 'la'),
#  ('ajustado', 'a', 'la', 'asepsia'),
#  ('a', 'la', 'asepsia', 'que'),
#  ('la', 'asepsia', 'que', 'todos'),
#  ('asepsia', 'que', 'todos', 'esperábamos'),
#  ('que', 'todos', 'esperábamos', 'ello'),
#  ('todos', 'esperábamos', 'ello', 'no'),
#  ('esperábamos', 'ello', 'no', 'evitó'),
#  ('ello', 'no', 'evitó', 'que'),
#  ('no', 'evitó', 'que', 'como'),
#  ('evitó', 'que', 'como', 'suele'),
#  ('que', 'como', 'suele', 'ocurrir'),
#  ('como', 'suele', 'ocurrir', 'algunos'),
#  ('suele', 'ocurrir', 'algunos', 'candidatos'),
#  ('ocurrir', 'algunos', 'candidatos', 'como'),
#  ('algunos', 'candidatos', 'como', 'el'),
#  ('candidatos', 'como', 'el', 'señor'),
#  ('como', 'el', 'señor', 'rafael'),
#  ('el', 'señor', 'rafael', 'lópez'),
#  ('señor', 'rafael', 'lópez', 'aliaga'),
#  ('rafael', 'lópez', 'aliaga', 'sugiriesen'),
#  ('lópez', 'aliaga', 'sugiriesen', 'la'),
#  ('aliaga', 'sugiriesen', 'la', 'existencia'),
#  ('sugiriesen', 'la', 'existencia', 'de'),
#  ('la', 'existencia', 'de', 'irregularidades'),
#  ('existencia', 'de', 'irregularidades', 'en'),
#  ('de', 'irregularidades', 'en', 'su'),
#  ('irregularidades', 'en', 'su', 'contra'),
#  ('en', 'su', 'contra', 'sin'),
#  ('su', 'contra', 'sin', 'ningún'),
#  ('contra', 'sin', 'ningún', 'tipo'),
#  ('sin', 'ningún', 'tipo', 'de'),
#  ('ningún', 'tipo', 'de', 'evidencia'),
#  ('tipo', 'de', 'evidencia', 'para'),
#  ('de', 'evidencia', 'para', 'sustentarlo'),
#  ('evidencia', 'para', 'sustentarlo', 'los'),
#  ('para', 'sustentarlo', 'los', 'verdaderos'),
#  ('sustentarlo', 'los', 'verdaderos', 'sobresaltos'),
#  ('los', 'verdaderos', 'sobresaltos', 'recién'),
#  ('verdaderos', 'sobresaltos', 'recién', 'llegaron'),
#  ('sobresaltos', 'recién', 'llegaron', 'por'),
#  ('recién', 'llegaron', 'por', 'la'),
#  ('llegaron', 'por', 'la', 'noche'),
#  ('por', 'la', 'noche', 'cuando'),
#  ('la', 'noche', 'cuando', 'los'),
#  ('noche', 'cuando', 'los', 'noticieros'),
#  ('cuando', 'los', 'noticieros', 'dieron'),
#  ('los', 'noticieros', 'dieron', 'a'),
#  ('noticieros', 'dieron', 'a', 'conocer'),
#  ('dieron', 'a', 'conocer', 'primero'),
#  ('a', 'conocer', 'primero', 'el'),
#  ('conocer', 'primero', 'el', 'flash'),
#  ('primero', 'el', 'flash', 'electoral'),
#  ('el', 'flash', 'electoral', 'a'),
#  ('flash', 'electoral', 'a', 'boca'),
#  ('electoral', 'a', 'boca', 'de'),
#  ('a', 'boca', 'de', 'urna'),
#  ('boca', 'de', 'urna', 'y'),
#  ('de', 'urna', 'y', 'luego'),
#  ('urna', 'y', 'luego', 'el'),
#  ('y', 'luego', 'el', 'conteo'),
#  ('luego', 'el', 'conteo', 'rápido'),
#  ('el', 'conteo', 'rápido', 'de'),
#  ('conteo', 'rápido', 'de', 'ipsos'),
#  ('rápido', 'de', 'ipsos', 'como'),
#  ('de', 'ipsos', 'como', 'ya'),
#  ('ipsos', 'como', 'ya', 'mostraban'),
#  ('como', 'ya', 'mostraban', 'las'),
#  ('ya', 'mostraban', 'las', 'encuestas'),
#  ('mostraban', 'las', 'encuestas', 'que'),
#  ('las', 'encuestas', 'que', 'trascendían'),
#  ('encuestas', 'que', 'trascendían', 'en'),
#  ('que', 'trascendían', 'en', 'la'),
#  ('trascendían', 'en', 'la', 'víspera'),
#  ('en', 'la', 'víspera', 'el'),
#  ('la', 'víspera', 'el', 'candidato'),
#  ('víspera', 'el', 'candidato', 'de'),
#  ('el', 'candidato', 'de', 'perú'),
#  ('candidato', 'de', 'perú', 'libre'),
#  ('de', 'perú', 'libre', 'pedro'),
#  ('perú', 'libre', 'pedro', 'castillo'),
#  ('libre', 'pedro', 'castillo', 'consolidó'),
#  ('pedro', 'castillo', 'consolidó', 'su'),
#  ('castillo', 'consolidó', 'su', 'ascenso'),
#  ('consolidó', 'su', 'ascenso', 'y'),
#  ('su', 'ascenso', 'y', 'habría'),
#  ('ascenso', 'y', 'habría', 'alcanzado'),
#  ('y', 'habría', 'alcanzado', 'más'),
#  ('habría', 'alcanzado', 'más', 'votos'),
#  ('alcanzado', 'más', 'votos', 'que'),
#  ('más', 'votos', 'que', 'cualquier'),
#  ('votos', 'que', 'cualquier', 'otro'),
#  ('que', 'cualquier', 'otro', 'postulante'),
#  ('cualquier', 'otro', 'postulante', 'colocándose'),
#  ('otro', 'postulante', 'colocándose', 'en'),
#  ('postulante', 'colocándose', 'en', 'el'),
#  ('colocándose', 'en', 'el', 'primer'),
#  ('en', 'el', 'primer', 'puesto'),
#  ('el', 'primer', 'puesto', 'con'),
#  ('primer', 'puesto', 'con', '181'),
#  ('puesto', 'con', '181', 'del'),
#  ('con', '181', 'del', 'voto'),
#  ('181', 'del', 'voto', 'al'),
#  ('del', 'voto', 'al', '90'),
#  ('voto', 'al', '90', 'del'),
#  ('al', '90', 'del', 'conteo'),
#  ('90', 'del', 'conteo', 'según'),
#  ('del', 'conteo', 'según', 'la'),
#  ('conteo', 'según', 'la', 'referida'),
#  ('según', 'la', 'referida', 'medición'),
#  ('la', 'referida', 'medición', 'de'),
#  ('referida', 'medición', 'de', 'ipsos'),
#  ('medición', 'de', 'ipsos', 'lo'),
#  ('de', 'ipsos', 'lo', 'siguen'),
#  ('ipsos', 'lo', 'siguen', 'keiko'),
#  ('lo', 'siguen', 'keiko', 'fujimori'),
#  ('siguen', 'keiko', 'fujimori', 'fuerza'),
#  ('keiko', 'fujimori', 'fuerza', 'popular'),
#  ('fujimori', 'fuerza', 'popular', 'con'),
#  ('fuerza', 'popular', 'con', '144'),
#  ('popular', 'con', '144', 'y'),
#  ('con', '144', 'y', 'rafael'),
#  ('144', 'y', 'rafael', 'lópez'),
#  ('y', 'rafael', 'lópez', 'aliaga'),
#  ('rafael', 'lópez', 'aliaga', 'renovación'),
#  ('lópez', 'aliaga', 'renovación', 'popular'),
#  ('aliaga', 'renovación', 'popular', 'con'),
#  ('renovación', 'popular', 'con', '124'),
#  ('popular', 'con', '124', 'hará'),
#  ('con', '124', 'hará', 'falta'),
#  ('124', 'hará', 'falta', 'esperar'),
#  ('hará', 'falta', 'esperar', 'los'),
#  ('falta', 'esperar', 'los', 'resultados'),
#  ('esperar', 'los', 'resultados', 'de'),
#  ('los', 'resultados', 'de', 'la'),
#  ('resultados', 'de', 'la', 'onpe'),
#  ('de', 'la', 'onpe', 'al'),
#  ('la', 'onpe', 'al', '100'),
#  ('onpe', 'al', '100', 'para'),
#  ('al', '100', 'para', 'saber'),
#  ('100', 'para', 'saber', 'el'),
#  ('para', 'saber', 'el', 'cuadro'),
#  ('saber', 'el', 'cuadro', 'final'),
#  ('el', 'cuadro', 'final', 'de'),
#  ('cuadro', 'final', 'de', 'candidatos'),
#  ('final', 'de', 'candidatos', 'tras'),
#  ('de', 'candidatos', 'tras', 'una'),
#  ('candidatos', 'tras', 'una', 'campaña'),
#  ('tras', 'una', 'campaña', 'marcada'),
#  ('una', 'campaña', 'marcada', 'por'),
#  ('campaña', 'marcada', 'por', 'la'),
#  ('marcada', 'por', 'la', 'polarización'),
#  ('por', 'la', 'polarización', '–por'),
#  ('la', 'polarización', '–por', 'la'),
#  ('polarización', '–por', 'la', 'presencia'),
#  ('–por', 'la', 'presencia', 'de'),
#  ('la', 'presencia', 'de', 'posiciones'),
#  ('presencia', 'de', 'posiciones', 'extremas–'),
#  ('de', 'posiciones', 'extremas–', 'y'),
#  ('posiciones', 'extremas–', 'y', 'la'),
#  ('extremas–', 'y', 'la', 'atomización'),
#  ('y', 'la', 'atomización', '–por'),
#  ('la', 'atomización', '–por', 'lo'),
#  ('atomización', '–por', 'lo', 'pequeño'),
#  ('–por', 'lo', 'pequeño', 'del'),
#  ('lo', 'pequeño', 'del', 'apoyo'),
#  ('pequeño', 'del', 'apoyo', 'que'),
#  ('del', 'apoyo', 'que', 'recibió'),
#  ('apoyo', 'que', 'recibió', 'cada'),
#  ('que', 'recibió', 'cada', 'aspirante'),
#  ('recibió', 'cada', 'aspirante', 'al'),
#  ('cada', 'aspirante', 'al', 'sillón'),
#  ('aspirante', 'al', 'sillón', 'de'),
#  ('al', 'sillón', 'de', 'pizarro–'),
#  ('sillón', 'de', 'pizarro–', 'este'),
#  ('de', 'pizarro–', 'este', 'desenlace'),
#  ('pizarro–', 'este', 'desenlace', 'solo'),
#  ('este', 'desenlace', 'solo', 'augura'),
#  ('desenlace', 'solo', 'augura', 'aún'),
#  ('solo', 'augura', 'aún', 'más'),
#  ('augura', 'aún', 'más', 'división'),
#  ('aún', 'más', 'división', 'en'),
#  ('más', 'división', 'en', 'el'),
#  ('división', 'en', 'el', 'camino'),
#  ('en', 'el', 'camino', 'a'),
#  ('el', 'camino', 'a', 'la'),
#  ('camino', 'a', 'la', 'segunda'),
#  ...]

# %%
tetraWords_EC_clean = [gram for gram in tetraWords_EC if not any(stop in gram for stop in spanish_stopwords)]
print(tetraWords_EC_clean)
# Out:
# [('otorgado', 'podrían', 'sentirse', 'defraudados'), ('comunicado', 'divulgado', 'ayer', '¿debemos'), ('divulgado', 'ayer', '¿debemos', 'entender'), ('ayer', '¿debemos', 'entender', 'acaso'), ('proyecto', 'político', 'conjunto', 'argumentando'), ('pocas', 'quejas', 'cuya', 'pertinencia'), ('señor', 'rafael', 'lópez', 'aliaga'), ('rafael', 'lópez', 'aliaga', 'sugiriesen'), ('verdaderos', 'sobresaltos', 'recién', 'llegaron'), ('perú', 'libre', 'pedro', 'castillo'), ('libre', 'pedro', 'castillo', 'consolidó'), ('siguen', 'keiko', 'fujimori', 'fuerza'), ('keiko', 'fujimori', 'fuerza', 'popular'), ('rafael', 'lópez', 'aliaga', 'renovación'), ('lópez', 'aliaga', 'renovación', 'popular'), ('124', 'hará', 'falta', 'esperar'), ('desenlace', 'solo', 'augura', 'aún'), ('dos', 'opciones', 'diametralmente', 'distintas'), ('opciones', 'diametralmente', 'distintas', 'ello'), ('decirlo', 'profesa', 'perspectivas', 'antojadizas'), ('sistema', 'político', 'debe', 'funcionar'), ('excongresista', 'marisa', 'glave', 'cercana'), ('excandidata', 'presidencial', 'verónika', 'mendoza'), ('presente', 'coyuntura', 'vale', 'señalar'), ('menos', 'marcadas', '–es', 'decir'), ('marcadas', '–es', 'decir', 'evitar'), ('–es', 'decir', 'evitar', 'incrementos'), ('mercados', 'financieros', 'tan', 'solo'), ('financieros', 'tan', 'solo', 'atenuarlos'), ('poca', 'solidez', 'aun', 'si'), ('queda', 'claro', 'cómo', 'lograrían'), ('técnicos', 'altamente', 'calificados', 'arriesgar'), ('lamentable', 'julio', 'velarde', '–cabeza'), ('muerto', 'cada', 'cinco', 'minutos'), ('aún', 'existen', 'marcadas', 'diferencias'), ('cansancio', 'parece', 'haberse', 'instalado'), ('nueva', 'cuarentena', 'tan', 'severa'), ('insostenible', 'crisis', 'económica', 'generada'), ('decano', 'nacional', 'miguel', 'palacios'), ('nacional', 'miguel', 'palacios', 'celi'), ('manera', 'masiva”', 'acciones', 'válidas'), ('menor', 'tiempo', 'posible', 'ninguno'), ('cliché', 'decirlo', 'seguirnos', 'cuidando'), ('peruano', 'muere', 'cada', 'cuatro'), ('muere', 'cada', 'cuatro', 'minutos'), ('prevenir', 'nuevos', 'contagios', 'sino'), ('año', 'viajaban', '10', 'mil'), ('viajaban', '10', 'mil', 'peruanos'), ('peruanos', '–que', 'debería', 'ser'), ('–que', 'debería', 'ser', 'siempre'), ('debería', 'ser', 'siempre', 'celebrada–'), ('ser', 'siempre', 'celebrada–', 'parece'), ('minsa', 'óscar', 'ugarte', '“hay'), ('registrarán', 'menos', 'muertes', 'solo'), ('semana', 'pasada', 'tan', 'solo'), ('pasada', 'tan', 'solo', '11'), ('tan', 'solo', '11', 'regiones'), ('cuya', 'primera', 'vuelta', 'ninguno'), ('solo', 'dos', 'aspirantes', 'presidenciales'), ('menos', 'así', 'debería', 'ser'), ('integrantes', 'castillo', 'repuso', '“los'), ('castillo', 'repuso', '“los', 'nombres'), ('interrogaba', 'añadió', '“te', 'voy'), ('presenta', 'igualmente', 'brumoso', 'pues'), ('igualmente', 'brumoso', 'pues', 'aquello'), ('señor', 'castillo', 'parecería', 'sugerirle'), ('mensaje', 'debería', 'ser', 'claro'), ('debería', 'ser', 'claro', 'directo'), ('complejidad', 'humana', 'utilizando', 'perspectivas'), ('humana', 'utilizando', 'perspectivas', 'unidimensionales'), ('unas', 'cuantas', 'ideas', 'fuerza'), ('pueda', 'buscar', 'explicaciones', 'parciales'), ('primeras', 'posiciones', 'sostenían', '–en'), ('posiciones', 'sostenían', '–en', 'diferentes'), ('sostenían', '–en', 'diferentes', 'medidas–'), ('perú', 'libre', '–quien', 'pocas'), ('libre', '–quien', 'pocas', 'semanas'), ('–quien', 'pocas', 'semanas', 'atrás'), ('precariedad', 'económica', '–si', 'bien'), ('dirigente', 'sindical', 'hace', 'falta'), ('sindical', 'hace', 'falta', 'mayor'), ('hace', 'falta', 'mayor', 'presencia'), ('áncash', 'apurímac', 'arequipa', 'cajamarca'), ('apurímac', 'arequipa', 'cajamarca', 'cusco'), ('arequipa', 'cajamarca', 'cusco', 'junín'), ('cajamarca', 'cusco', 'junín', 'moquegua'), ('promedio', 's1830', 'millones', 'cada'), ('s1830', 'millones', 'cada', 'año'), ('contraloría', 'existen', '294', 'obras'), ('suman', 'casi', 's5000', 'millones ...

# %%
tetragramsCount_dict_EC = Counter(tetraWords_EC_clean) #generate counter

# Turn bigramsCount_dict  into dataframe, naming columns
tetragramsCount_EC = pd.DataFrame(tetragramsCount_dict_EC.most_common(),
                        columns=['tetragrama', 'peso'])
tetragramsCount_EC
# Out:
#                                      tetragrama  peso
# 0                (perú, libre, pedro, castillo)     2
# 1            (keiko, fujimori, fuerza, popular)     2
# 2    (otorgado, podrían, sentirse, defraudados)     1
# 3       (comunicado, divulgado, ayer, ¿debemos)     1
# 4         (divulgado, ayer, ¿debemos, entender)     1
# ..                                          ...   ...
# 285      (contenidos, “basura”, ¿qué, entrañan)     1
# 286    (“basura”, ¿qué, entrañan, precisamente)     1
# 287    (propone, salvaguardar, ¿qué, garantiza)     1
# 288         (ningún, demócrata, debería, abrir)     1
# 289            (vladimir, lenin, fidel, castro)     1
#
# [290 rows x 2 columns]

# %%
type(tetragramsCount_EC)
# Out:
# pandas.core.frame.DataFrame

# %%
tetragramsCount_EC['palabra 1'], tetragramsCount_EC['palabra 2'], tetragramsCount_EC['palabra 3'], tetragramsCount_EC['palabra 4'] = zip(*tetragramsCount_EC['tetragrama'])
tetragramsCount_EC
# Out:
#                                      tetragrama  peso   palabra 1  \
# 0                (perú, libre, pedro, castillo)     2        perú
# 1            (keiko, fujimori, fuerza, popular)     2       keiko
# 2    (otorgado, podrían, sentirse, defraudados)     1    otorgado
# 3       (comunicado, divulgado, ayer, ¿debemos)     1  comunicado
# 4         (divulgado, ayer, ¿debemos, entender)     1   divulgado
# ..                                          ...   ...         ...
# 285      (contenidos, “basura”, ¿qué, entrañan)     1  contenidos
# 286    (“basura”, ¿qué, entrañan, precisamente)     1    “basura”
# 287    (propone, salvaguardar, ¿qué, garantiza)     1     propone
# 288         (ningún, demócrata, debería, abrir)     1      ningún
# 289            (vladimir, lenin, fidel, castro)     1    vladimir
#
#         palabra 2 palabra 3     palabra 4
# 0           libre     pedro      castillo
# 1        fujimori    fuerza       popular
# 2         podrían  sentirse   defraudados
# 3       divulgado      ayer      ¿debemos
# 4            ayer  ¿debemos      entender
# ..            ...       ...           ...
# 285      “basura”      ¿qué      entrañan
# 286          ¿qué  entrañan  precisamente
# 287  salvaguardar      ¿qué     garantiza
# 288     demócrata   debería         abrir
# 289         lenin     fidel        castro
#
# [290 rows x 6 columns]

# %%
# Supongamos que tetragramsCount_EC tiene las columnas 'palabra 1', 'palabra 2', 'palabra 3', 'palabra 4', 'peso'
# Filtramos los tetragramas por un peso mínimo de 3
filtered_tetragrams = tetragramsCount_EC[tetragramsCount_EC['peso'] == 2]

# Crea un grafo vacío
G_tetragram_EC = nx.Graph()

# Añadir aristas al grafo basadas en cada fila del dataframe filtrado
for idx, row in filtered_tetragrams.iterrows():
    G_tetragram_EC.add_edge(row['palabra 1'], row['palabra 2'], weight=row['peso'])
    G_tetragram_EC.add_edge(row['palabra 2'], row['palabra 3'], weight=row['peso'])
    G_tetragram_EC.add_edge(row['palabra 3'], row['palabra 4'], weight=row['peso'])

# Dibujar el grafo
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
nx.draw_networkx(G_tetragram_EC, with_labels=True, node_color='skyblue', edge_color='#FF5733', font_size=10, font_weight='bold')
plt.title("Red de Tetragramas con Peso igual a 2")
plt.show()

# %%
# Creamos un grafo vacío
G_tetragram_EC = nx.Graph()

# Añadir aristas al grafo basadas en cada fila del dataframe filtrado
for idx, row in tetragramsCount_EC.iterrows():
    G_tetragram_EC.add_edge(row['palabra 1'], row['palabra 2'], weight=row['peso'])
    G_tetragram_EC.add_edge(row['palabra 2'], row['palabra 3'], weight=row['peso'])
    G_tetragram_EC.add_edge(row['palabra 3'], row['palabra 4'], weight=row['peso'])

# Dibujar el grafo
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
nx.draw_networkx(G_tetragram_EC, with_labels=True, node_color='skyblue', edge_color='#FF5733', font_size=10, font_weight='bold')
plt.title("Red de tetragramas")
plt.show()
